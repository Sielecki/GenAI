# %%
import ollama 
import time
import numpy as np
from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import re

import matplotlib.pyplot as plt


def plot_metrics(metrics_summary):
    keys = list(metrics_summary.keys())
    values = [v if isinstance(v, (int, float)) else sum(v)/len(v) for v in metrics_summary.values()]
    
    plt.figure(figsize=(10, 4))
    plt.barh(keys, values, color='skyblue')
    plt.xlabel("Score")
    plt.title("Dialogue Quality Metrics")
    plt.grid(True)
    plt.show()

# %%
class TurnEngine:
    def __init__(self, agents, initial_world_state="", metrics_logger=None):
        self.agents = agents  # List of Agent instances
        self.turn_counter = 0
        self.history = []  # Log of all messages
        self.world_state = initial_world_state
        self.metrics_logger = metrics_logger

    def update_world_state(self, new_state):
        """Append new world events to current world state."""
        self.history.append(f"[World Event]: {self.world_state}")
        self.world_state = new_state
        
    def step(self, initiator_name=None, initial_input=None):
        """Run a full turn: each agent reacts to the latest dialogue/world state."""
        self.turn_counter += 1
        turn_log = []
        last_speaker = initiator_name or self.agents[0].name
        last_message = initial_input or "Let's begin."

        for agent in self.agents:
            start_time = time.time()

            rag_docs = agent.rag_engine.search(last_message) if agent.rag_engine else []

            reply, name = agent.prompt_agent(
                user=last_speaker,
                user_input=last_message,
                world_state=self.world_state
            )
            end_time = time.time()

            if self.metrics_logger:
                self.metrics_logger.log_response(start_time, end_time, reply['dialogue'], self.world_state, agent.get_memory_context(), rag_docs)
            
            formatted = f"{name} [{reply['emotion']}]: \"{reply['dialogue']}\" ({reply['action']})"
            turn_log.append(formatted)

            # Store important knowledge to RAG
            if agent.rag_engine:
                fact = f"{name} said: {reply['dialogue']} (felt {reply['emotion']}, did {reply['action']})"
                agent.store_knowledge(fact)

            last_speaker = name
            last_message = reply['dialogue']

        self.history.append(f"Turn {self.turn_counter}:\n" + "\n".join(turn_log))
        return turn_log

    def show_history(self, last_n=5):
        """Print recent conversation turns."""
        for h in self.history[-last_n:]:
            print(h)

    def reset(self):
        """Reset the engine for a new session."""
        self.turn_counter = 0
        self.history = []
        self.world_state = ""
        for agent in self.agents:
            agent.short_memory = []
            agent.long_memory = []

# %%
class DialogueMetricsLogger:
    def __init__(self):
        self.response_times = []
        self.responses = []
        self.world_states = []
        self.memory_contexts = []
        self.retrieved_docs = []
        self.embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

    def log_response(self, start_time, end_time, response, world_state, memory_context, rag_docs):
        self.response_times.append(end_time - start_time)
        self.responses.append(response)
        self.world_states.append(world_state)
        self.memory_contexts.append(memory_context)
        self.retrieved_docs.append(rag_docs or [])

    def coherence_score(self):
        # Dummy coherence scoring using embedding similarity between consecutive responses
        if len(self.responses) < 2:
            return 1.0
        embs = self.embedding_model.encode(self.responses)
        sims = [cosine_similarity([embs[i]], [embs[i+1]])[0][0] for i in range(len(embs)-1)]
        return np.mean(sims)

    def reactivity_score(self):
        count = 0
        for resp, state in zip(self.responses, self.world_states):
            if state and cosine_similarity(
                self.embedding_model.encode([resp]),
                self.embedding_model.encode([state])
            )[0][0] > 0.4:
                count += 1
        return count / len(self.responses) if self.responses else 0

    def memory_utilization_score(self):
        count = 0
        for resp, mem in zip(self.responses, self.memory_contexts):
            if mem and cosine_similarity(
                self.embedding_model.encode([resp]),
                self.embedding_model.encode([mem])
            )[0][0] > 0.4:
                count += 1
        return count / len(self.responses) if self.responses else 0

    def dialogue_diversity(self):
        all_text = " ".join(self.responses)
        tokens = all_text.split()
        if not tokens:
            return 0, 0
        unigrams = Counter(tokens)
        bigrams = Counter(zip(tokens, tokens[1:]))
        distinct_1 = len(unigrams) / len(tokens)
        distinct_2 = len(bigrams) / max(len(tokens) - 1, 1)
        return distinct_1, distinct_2

    def avg_latency(self):
        return np.mean(self.response_times) if self.response_times else 0

    def rag_precision_at_k(self, k=3):
        if not self.responses:
            return 0
        count = 0
        for response, docs in zip(self.responses, self.retrieved_docs):
            top_k = docs[:k] if docs else []
            similarities = [cosine_similarity(
                self.embedding_model.encode([response]),
                self.embedding_model.encode([doc])
            )[0][0] for doc in top_k]
            count += sum([1 for sim in similarities if sim > 0.5])
        return count / (len(self.responses) * k) if self.responses else 0

    def summary(self):
        d1, d2 = self.dialogue_diversity()
        return {
            "Coherence Score": self.coherence_score(),
            "Reactivity to World State": self.reactivity_score(),
            "Memory Utilization": self.memory_utilization_score(),
            "Dialogue Diversity (D1, D2)": (d1, d2),
            "Average Latency (s)": self.avg_latency(),
            "RAG Precision": self.rag_precision_at_k(k=3)
        }

# %%
class RAG:
    def __init__(self):
        self.documents = []  # Stored as list of strings

    def add_document(self, text):
        """Add a new document to the knowledge base."""
        self.documents.append(text)

    def search(self, query, top_k=3):
        """Search for the most relevant documents based on keyword overlap."""
        scored = []
        query_terms = set(query.lower().split())
        for doc in self.documents:
            doc_terms = set(doc.lower().split())
            score = len(query_terms & doc_terms)
            if score > 0:
                scored.append((score, doc))

        scored.sort(reverse=True)
        return [doc for _, doc in scored[:top_k]]

# %%
class Agent:
    def __init__(self, name, personality, goal, model='llama3.2', rag_engine=None, max_short_term=10):
        self.name = name
        self.personality = personality
        self.goal = goal
        
        self.model = model
        self.rag_engine = rag_engine

        self.short_memory = []
        self.long_memory = []
        self.max_short_term = max_short_term  # Context window size

    def update_memory(self, memory):
        self.long_memory.append(memory)
        
    def update_goal(self, new_goal):
        self.goal = new_goal

    def get_memory_context(self):
        def format_memory(mem):
            if isinstance(mem, dict):
                return f"{mem['speaker']} said: \"{mem['dialogue']}\" (Emotion: {mem.get('emotion', '')}, Action: {mem.get('action', '')})"
            return mem

        return "\n".join([
            "* " + format_memory(mem) for mem in 
            self.long_memory[-3:] + self.short_memory[-self.max_short_term:]
        ])

    def recall(self, query):
        if self.rag_engine:
            return self.rag_engine.search(query)
        return [m for m in self.memory if query.lower() in m.lower()]

    def store_knowledge(self, fact):
        if self.rag_engine:
            self.rag_engine.add_document(fact)

    def parse_response(self, response_text):
        parts = {
            'action': 'Unknown',
            'emotion': 'Neutral',
            'dialogue': response_text  # fallback
        }

        # Extract with regular expressions
        action_match = re.search(r"Action:\s*(.+)", response_text, re.IGNORECASE)
        emotion_match = re.search(r"Emotion:\s*(.+)", response_text, re.IGNORECASE)
        dialogue_match = re.search(r'Dialogue:\s*(.*)', response_text, re.IGNORECASE)

        if action_match:
            parts['action'] = action_match.group(1).strip()
        if emotion_match:
            parts['emotion'] = emotion_match.group(1).strip()
        if dialogue_match:
            parts['dialogue'] = dialogue_match.group(1).strip()

        return parts

    def prompt_agent(self, user="", user_input="", world_state=""):
        
        recalled_facts = self.recall(user_input)
        if isinstance(recalled_facts, list):
            recalled_text = "\n".join([f"* {fact}" for fact in recalled_facts[:3]])
        else:
            recalled_text = ""

        system_prompt = f"""[Role]
                        You are {self.name}, a {self.personality}.
                        Respond ONLY as your character in 1-2 sentences.
                        Respond only with dialogue, actions or emotions.

                        [Intent]
                        Your goal is: {self.goal}
                        
                        [Response Format]
                        Action: (2-3 word physical action)
                        Emotion: (current emotion)
                        Dialogue: "..." 

                        EXAMPLE:
                        Action: Looks around  
                        Emotion: Calm  
                        Dialogue: "I think we are being watched."

                        [Relevant Knowledge]
                        {recalled_text}

                        [Memory Context]
                        {self.get_memory_context()}

                        [World State]
                        {world_state}  

                        """ 
        # Keep only recent context
        memory = "\n".join(self.short_memory[-self.max_short_term:])  
        user_prompt = f"{user}: {user_input}"

        response = ollama.chat(
            model=self.model,
            messages=[
                {'role': 'system', 'content': system_prompt},
                {'role': 'user', 'content': memory + '\n' + user_prompt}
            ]
        )

        reply = self.parse_response(response['message']['content'])

        self.short_memory.append(f"{user} said: {user_input}")
        self.short_memory.append(f"{self.name}: {reply['dialogue']}")
        self.long_memory.append({
            "speaker": self.name,
            "turn": len(self.long_memory),
            "action": reply["action"],
            "emotion": reply["emotion"],
            "dialogue": reply["dialogue"],
            "world_state": world_state
        })
        
        return reply, self.name

# %% [markdown]
# Banquet

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'


rag.add_document("Poison brewed from Oleander is deadly")
rag.add_document('Mercenary are often hired for protection')
rag.add_document('This is not the first time a noble has been poisoned')
rag.add_document("Lord Alaric recently returned from a diplomatic visit to the Eastern Isles.")
rag.add_document("Cellars beneath the manor were sealed off until recently.")
rag.add_document("Cassian once published a controversial paper on rare poisons.")
rag.add_document("The wine was imported from Serana, known for its floral blends.")
rag.add_document("There have been rumors that Elena has a past connection with the Black Vials guild.")

for i in range (0, 10):
    Alaric = Agent(
        name="Alaric",
        personality="proud, manipulative noble, rich",
        goal="Deflect suspicion without showing fear",
        model=model,
        rag_engine=rag
    )
    Alaric.update_memory("Elena asked about increased guard presence yesterday.")
    Alaric.update_memory("Cassian seems overly interested in the manor's old cellars.")

    Elena = Agent(
        name="Elena",
        personality="mercenary hired for protection, blunt but loyal",
        goal="Protect the guests and assess threat level",
        model=model,
        rag_engine=rag
    )
    Elena.update_memory("Cassian warned her something was off with the wine.")
    Elena.update_memory("She noticed Alaric whispering to the kitchen steward before the feast.")

    Cassian = Agent(
        name="Cassian",
        personality="traveling scholar, secretive, suspicious of Alaric",
        goal="Imply Alaric's guilt indirectly",
        model=model,
        rag_engine=rag
    )
    Cassian.update_memory("He remembers seeing Oleander in the garden.")
    Cassian.update_memory("Alaric offered him a private tour of the cellars earlier.")
    Cassian.update_memory("He suspects the poison was meant for someone else.")

    world_state = (
        "During the feast, a guest collapses clutching their throat. The room falls silent. "
        "All eyes turn to Lord Alaric, seated nearest the victim. A goblet rolls across the floor."
    )

    engine = TurnEngine(agents=[Alaric, Elena, Cassian], metrics_logger=logger, initial_world_state=world_state)

    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="Alaric", initial_input="What happened? Is everyone alright?")
    for line in responses:
        print(line)

    for turn in range(1, 20):
        print(f"\n=== Turn {turn + 1} ===")
        responses = engine.step()
        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: "“Good heavens! Let the servants attend to the… unfortunate gentleman.”" (Raises an eyebrow slightly)
# Elena [Apprehensive]: ""Get him to a room. Now."" (Steps forward, hand instinctively reaching for the hilt of her sword.)
# Cassian [Unease]: ""The urgency in your voice...is it truly necessary?"" (Steps forward, clutching his wrist.)
#
# === Turn 2 ===
# Alaric [Controlled concern]: "“A most unfortunate turn of events. Pray, someone fetch a physician immediately.”" (Gestures dismissively towards the fallen guest.)
# Elena [Frustration]: "“Move it, Alaric. Someone needs to help him.”" (Steps towards the fallen guest)
# Cassian [Suspicious]: "“...Is there a reason you seem so insistent, Lord Alaric?”" (Taps his fingers nervously)
#
# === Turn 3 ===
# Alaric [Controlled concern]: "“Truly dreadful. Let’s ascertain the precise nature of this… disturbance.”" (Straightens his crimson velvet jacket)
# Elena [Apprehension]: ""Let me see what's wrong with him."" (Approaches the fallen guest cautiously.)
# Cassian [Unease]: ""...Perhaps a simple request warrants a strained tone?"" (Shifts his weight, eyes narrowed.)
#
# === Turn 4 ===
# Alaric [Controlled concern]: "“Honestly, this is most inconvenient. Tell me, what precisely transpired?”" (Adjusts his collar subtly)
# Elena [Concern]: ""Get closer. Don't just stand there."" (Steps towards the fallen guest)
# Cassian [Apprehensive]: "“...Surely a moment’s observation is sufficient?”" (Takes a step back)
#
# === Turn 5 ===
# Alaric [Controlled concern]: "“Ensure his comfort. And someone, discreetly, investigate the cause.”" (Raises a hand, subtly gesturing towards the fallen guest.)
# Elena [Frustration]: "“Don’t just stand there gawking! Get him out of sight.”" (Steps forward, examining the fallen guest.)
# Cassian [Apprehension]: "“...I find your haste rather unsettling, Lord Alaric.”" (Adjusts his spectacles nervously)
#
# === Turn 6 ===
# Alaric [Controlled concern]: "“Pray, someone inform me of the details. And swiftly, if you please.”" (Smooths his crimson velvet jacket)
# Elena [Concern]: ""Someone get a blanket. And tell me what happened."" (Approaches the fallen guest cautiously)
# Cassian [Distrust]: "“...A blanket? Truly, the situation demands more than mere comfort.”" (Shifts nervously, clutching his satchel.)
#
# === Turn 7 ===
# Alaric [Controlled annoyance]: "“Speak plainly. I haven’t the time for idle speculation.”" (Taps a finger impatiently on the armrest.)
# Elena [Annoyance]: ""Just get him out of this chair. What's the delay?"" (Steps towards the fallen guest)
# Cassian [Unease]: "“...I believe a thorough examination is… advisable.”" (Steps backward, clutching satchel tighter.)
#
# === Turn 8 ===
# Alaric [Controlled amusement]: ""Do enlighten me. A collapse is… unexpected, wouldn’t you agree?"" (Raises an eyebrow, a slight smile playing on his lips.)
# Elena [Concern]: ""Let’s see if he’s breathing."" (Approaches cautiously)
# Cassian [Distrust]: "“...A blanket? Truly, the situation demands more than mere comfort.”" (Steps backward, clutching satchel tighter.)
#
# === Turn 9 ===
# Alaric [Controlled annoyance]: "“Is he… recovering? A swift explanation would be appreciated.”" (Straightens his crimson velvet jacket)
# Elena [Frustration]: "“Get him out of here. Now!”" (Steps forward, eyes the fallen guest)
# Cassian [Apprehension]: "“...Perhaps a skilled healer is required, not simply warmth.”" (Shifts uneasily, clutching satchel)
#
# === Turn 10 ===
# Alaric [Controlled concern]: "“Tell me precisely what transpired. And quickly.”" (Adjusts his velvet jacket, a subtle gesture of control.)
# Elena [Frustration]: "“Move him! Before he starts to bleed more.”" (Steps towards the fallen guest)
# Cassian [Apprehension]: "“...That’s quite a frantic assessment, Lord Alaric.”" (Steps back, clutching satchel tighter)
#
# === Turn 11 ===
# Alaric [Controlled annoyance]: "“Spare me the dramatics. Simply state the facts.”" (Taps fingers lightly on the table.)
# Elena [Concern]: ""Is he still alive? Let's check."" (Approaches cautiously)
# Cassian [Apprehension]: ""...A blanket? Truly, the situation demands more than mere comfort.”" (Shifts nervously, clutching satchel tighter.)
#
# === Turn 12 ===
# Alaric [Controlled curiosity]: "“And what, precisely, caused this… inconvenience?”" (Leans forward slightly)
# Elena [Annoyance]: "“Get him out of here. Now.”" (Approaches cautiously)
# Cassian [Apprehension]: "“...A blanket? Truly, the situation demands more than mere comfort.”" (Adjusts satchel nervously)
#
# === Turn 13 ===
# Alaric [Controlled amusement]: "“Really, a collapse? How utterly tiresome.”" (Raises an eyebrow subtly)
# Elena [Annoyance]: ""He's not breathing. Get a cloth. Now!"" (Approaches cautiously)
# Cassian [Unease]: ""...A blanket? Truly, the situation demands more than mere comfort.”" (Adjusts satchel tightly)
#
# === Turn 14 ===
# Alaric [Controlled irritation]: "“Honestly, the sheer *waste* of a perfectly good evening.”" (Adjusts his velvet collar)
# Elena [Frustration]: "“Someone fetch a cloth. Now!”" (Steps towards the fallen guest)
# Cassian [Suspicion]: ""…Remarkably quick, isn't it, Lord Alaric?"" (Shifts subtly, eyes fixed on Alaric)
#
# === Turn 15 ===
# Alaric [Controlled annoyance]: "“Good heavens, must we truly dissect this utterly dreadful situation?”" (Smooths his tunic)
# Elena [Frustration]: ""Get him out of this room. Now!"" (Steps towards the fallen lord)
# Cassian [Concern, veiled suspicion]: ""...A blanket? Truly, the situation demands more than mere comfort.”" (Steps closer to the fallen lord)
#
# === Turn 16 ===
# Alaric [Controlled curiosity]: "“Quite. Let's ascertain the circumstances, shall we?”" (Tilts head slightly)
# Elena [Concern]: ""Get a cloth. Now!"" (Approaches cautiously)
# Cassian [Unease]: ""...A blanket? Truly, the situation demands more than mere comfort.”" (Adjusts satchel tightly)
#
# === Turn 17 ===
# Alaric [Controlled amusement]: "“Indeed. A most unfortunate turn of events, wouldn’t you agree?”" (Raises a hand, palm outwards)
# Elena [Annoyance]: "“Stop wasting time. Get a cloth.”" (Steps forward, scanning the room.)
# Cassian [Unease]: ""…A blanket? Truly, the situation demands more than mere comfort.”" (Taps satchel nervously)
#
# === Turn 18 ===
# Alaric [Controlled disdain]: "“Let’s simply observe, wouldn't you agree?”" (Raises an eyebrow slightly)
# Elena [Frustration]: ""Someone get a cloth. Now!"" (Steps forward, scanning the room.)
# Cassian [Suspicion]: "“Such a…sudden stillness.”" (Adjusts spectacles nervously)
#
# === Turn 19 ===
# Alaric [Controlled annoyance]: "“Really, a rather… messy affair, isn’t it?”" (Adjusts his cravat)
# Elena [Apprehension]: "“Someone clean that up. And get the physician.”" (Steps forward, scanning the room intently.)
# Cassian [Apprehension]: "“...Indeed. A most unsettling development.”" (Shifts closer to Elena)
#
# === Turn 20 ===
# Alaric [Controlled amusement]: "“One simply *must* maintain a semblance of composure, wouldn't you say?”" (Shifts subtly in his seat)
# Elena [Concern]: "“Get him out of this room. Now!”" (Steps forward, scanning the room)
# Cassian [Unease]: ""…A blanket? Truly, the situation demands more than mere comfort.”" (Shifts slightly closer to Elena)
#
# === Take 1 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: ""Surely, this is merely a momentary lapse. Tell me, who was closest to the gentleman?"" (Raises an eyebrow slightly, gestures towards the fallen guest with a dismissive wave.)
# Elena [Suspicion]: "“He was right beside him, Lord Alaric. Someone wanted him silenced.”" (Steps forward, hand instinctively reaching for the hilt of her sword.)
# Cassian [Unease]: "“Indeed. A rather unfortunate incident, wouldn’t you say?”" (Taps fingers nervously)
#
# === Turn 2 ===
# Alaric [Controlled concern]: ""Please, let the healers attend to him.  I trust you’ll inquire about the cause of this… unfortunate event?"" (Shifts posture slightly)
# Elena [Determined]: "“I’m checking for any signs of foul play.”" (Approaches the fallen guest cautiously)
# Cassian [Apprehensive]: ""Perhaps a thorough examination is warranted, wouldn't you agree?"" (Adjusts his spectacles nervously)
#
# === Turn 3 ===
# Alaric [Controlled concern]: "“Naturally, we must determine the precise nature of this… disturbance.”" (Places a hand on his chest, subtly straightening his tunic.)
# Elena [Focused]: "“Let’s see what we’re dealing with.”" (Approaches the fallen guest cautiously)
# Cassian [Suspicious]: ""…The details, of course, are paramount."" (Shifts eyes subtly towards Alaric)
#
# === Turn 4 ===
# Alaric [Controlled concern]: ""I daresay, a rather unsettling occurrence. Perhaps a physician should be summoned immediately.”" (Raises a hand, palm outward)
# Elena [Suspicious]: "“There’s a faint almond scent…and a dark stain on the rug.”" (Approaches cautiously, eyes scanning)
# Cassian [Concern]: ""…It’s remarkably precise, isn't it?"" (Slowly circles the fallen guest.)
#
# === Turn 5 ===
# Alaric [Controlled concern]: "“Indeed. Let’s ascertain the details, shall we?”" (Adjusts his lapel, subtly)
# Elena [Focused]: ""Stay back. Let me see what happened."" (Approaches the fallen guest cautiously)
# Cassian [Unease]: "“Quite…disconcerting, wouldn’t you agree?”" (Steps back slightly)
#
# === Turn 6 ===
# Alaric [Controlled concern]: "“Let us not jump to conclusions. Pray, who witnessed this incident?”" (Raises a hand, palm up)
# Elena [Suspicious]: "“The rug...it’s soaked. Someone wasn’t just unwell.”" (Approaches cautiously, examining the fallen guest)
# Cassian [Concern]: ""…A most peculiar presentation, don’t you think?"" (Adjusts spectacles nervously)
#
# === Turn 7 ===
# Alaric [Controlled concern]: "“Tell me precisely what you observed. Details, please.”" (Smooths his tunic)
# Elena [Focused]: ""The stain...it’s spreading."" (Steps closer to the fallen guest)
# Cassian [Suspicious]: ""…Indeed. A most unsettling development.”" (Adjusts spectacles nervously)
#
# === Turn 8 ===
# Alaric [Controlled concern]: "“Excellent. Please, start from the beginning.”" (Adjusts his lapel, subtly)
# Elena [Assessing]: ""Start talking. Now.”" (Steps forward cautiously)
# Cassian [Unease]: ""…Someone is deliberately withholding information."" (Steps closer, cautiously)
#
# === Turn 9 ===
# Alaric [Controlled concern]: "“Do tell… was there any unusual draught consumed? A sudden pain, perhaps?”" (Raises a hand, palm up slightly)
# Elena [Focused]: "“Someone’s been poisoned.”" (Approaches cautiously, examining the fallen guest.)
# Cassian [Apprehensive]: ""The timing... remarkably convenient, wouldn't you say?"" (Taps fingers nervously on thigh)
#
# === Turn 10 ===
# Alaric [Controlled concern]: ""Indeed. A most unfortunate turn of events. Tell me, who was present when it occurred?"" (Raises an eyebrow slightly)
# Elena [Focused]: ""Someone needs to tell me what happened before I decide if this is a simple collapse or something worse."" (Approaches cautiously, examining the victim.)
# Cassian [Apprehension]: "“Remarkably… convenient, considering the circumstances.”" (Shifts subtly, eyes darting to Alaric.)
#
# === Turn 11 ===
# Alaric [Controlled concern]: "“Please, spare me the theatrics. Simply recount what you saw.”" (Smooths his tunic)
# Elena [Concerned]: "“Someone needs to tell me what happened before I decide if this is a simple collapse or something worse.”" (Steps closer to the victim)
# Cassian [Suspicion]: "“It seems a rather… thorough application of poison.”" (Adjusts spectacles nervously)
#
# === Turn 12 ===
# Alaric [Controlled curiosity]: ""Begin. And try to be…precise."" (Raises a hand, palm open)
# Elena [Frustrated]: "“Speak. Now.”" (Steps forward, eyes narrowed)
# Cassian [Unease]: ""…Perhaps a fresh perspective is warranted."" (Taps foot rapidly)
#
# === Turn 13 ===
# Alaric [Controlled curiosity]: "“Tell me everything. Every detail matters.”" (Raises a hand, palm open slightly)
# Elena [Suspicious]: "“Start talking. Now.”" (Steps forward, observing the body)
# Cassian [Apprehension]: "““Tell me, Lord Alaric, were you alone with the deceased?”" (Steps closer to Alaric)
#
# === Turn 14 ===
# Alaric [Controlled concern]: "“Describe the scene. Without embellishment, naturally.”" (Adjusts his rings)
# Elena [Focused]: ""Start talking. Now. Who saw this happen?"" (Steps forward, hand hovering near a dagger)
# Cassian [Unease]: ""…A most unfortunate turn of events, wouldn’t you agree, Lord Alaric?"" (Adjusts spectacles nervously)
#
# === Turn 15 ===
# Alaric [Controlled amusement]: "“Start with the obvious, I presume?”" (Raises an eyebrow slightly)
# Elena [Suspicious]: "“Start talking. Now. Who saw this happen?”" (Steps forward, hand gripping her dagger.)
# Cassian [Suspicious]: "“...The silence is quite telling, isn’t it?”" (Steps back slightly)
#
# === Turn 16 ===
# Alaric [Controlled composure]: "“Indeed. Commence. And for heaven’s sake, do try to be… coherent.”" (Smooths his tunic)
# Elena [Frustrated]: "“Start talking. Now. Someone was here.”" (Steps forward, hand gripping her sword tighter.)
# Cassian [Anxious]: "“...The shadows here are remarkably deep, aren’t they, Lord Alaric?”" (Taps fingers on thigh)
#
# === Turn 17 ===
# Alaric [Controlled concern]: "“Observe… the unfortunate gentleman. Let us focus on what *is*, not what *might have been*.”" (Raises a hand, gesturing subtly towards the fallen guest.)
# Elena [Focused]: "“Let’s see what we’re dealing with.”" (Steps closer to the fallen guest)
# Cassian [Apprehensive]: "“...It seems the air is thick with unanswered questions.”" (Adjusts spectacles nervously)
#
# === Turn 18 ===
# Alaric [Controlled curiosity]: ""Begin with the position he was found in. Was he seated? Lying prone?"" (Adjusts his cloak)
# Elena [Alert]: ""Lying prone. And fast."" (Steps forward, hand gripping her dagger.)
# Cassian [Unease]: "“...A most curious stillness, wouldn’t you say, Lord Alaric?”" (Shifts closer to Elena)
#
# === Turn 19 ===
# Alaric [Controlled amusement]: "“He was, regrettably, lying prone. A rather… undignified end, wouldn’t you agree?”" (Raises an eyebrow slightly)
# Elena [Assessing]: "“He was, regrettably, lying prone.”" (Steps closer to the body)
# Cassian [Apprehensive]: "“...Indeed. A truly unsettling tableau.”" (Steps back slightly)
#
# === Turn 20 ===
# Alaric [Controlled amusement]: "“Quite. Let’s ascertain the circumstances, shall we?”" (Smooths his tunic)
# Elena [Focused]: "“Lying prone. And fast. Someone’s got a blade.”" (Steps forward, cautiously approaching the body.)
# Cassian [Suspicious]: "“...The stillness is… profound, isn’t it, Lord Alaric?”" (Shifts nervously, adjusts spectacles)
#
# === Take 2 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: "“Good heavens! Let’s have someone fetch a physician immediately.  Is anyone injured beyond the gentleman?”" (Raises a hand, palm up in a gesture of reassurance.)
# Elena [Frustration]: ""Get him moving. And someone find a healer, now!"" (Steps forward, hand instinctively reaching for the sword at her hip.)
# Cassian [Unease]: ""Perhaps a little rest would be… beneficial?"" (Shifts nervously)
#
# === Turn 2 ===
# Alaric [Controlled concern]: ""Indeed, a most unsettling development. Tell me precisely what you observed."" (Adjusts his velvet collar)
# Elena [Urgent]: ""What did you see? Don't just stand there!"" (Shifts position, eyes scanning the room)
# Cassian [Apprehension]: ""…The shadows seem to deepen, don’t they?"" (Taps his fingers lightly on his staff.)
#
# === Turn 3 ===
# Alaric [Controlled concern]: "“Pray, someone attend to the gentleman. And tell me, what precisely transpired?”" (Smooths his tunic)
# Elena [Frustration]: "“Move him! What’s his condition?”" (Approaches the fallen guest cautiously.)
# Cassian [Suspicious]: ""…It’s a strange stillness, isn’t it?"" (Adjusts his staff, subtly observing Alaric.)
#
# === Turn 4 ===
# Alaric [Controlled concern]: "“Describe everything, starting with the moment you noticed him.”" (Raises an eyebrow slightly)
# Elena [Annoyance]: ""Get him out of the way! Someone check him!"" (Steps towards the fallen guest.)
# Cassian [Unease]: ""…A most unsettling quiet."" (Shifts his weight subtly)
#
# === Turn 5 ===
# Alaric [Controlled concern]: ""Tell me, what did you see *before* he fell?"" (Shifts posture slightly)
# Elena [Frustration]: ""Get him to the ground! Assess the damage!"" (Steps forward, hand instinctively reaching for the dagger at her hip.)
# Cassian [Apprehension]: ""…It’s a terrible waste of good wine."" (Taps his staff nervously)
#
# === Turn 6 ===
# Alaric [Controlled concern]: "“Begin, please. Spare no detail.”" (Taps fingers lightly on his goblet)
# Elena [Annoyance]: ""He's not going to help himself lying there!"" (Steps forward, eyes narrowed)
# Cassian [Apprehension]: ""…A most unsettling quiet."" (Adjusts his staff, subtly observing Alaric.)
#
# === Turn 7 ===
# Alaric [Controlled curiosity]: "“Please, enlighten me. Start with the sounds, if any.”" (Raises an eyebrow slightly)
# Elena [Frustration]: ""Let's get him moving! What’s the damage?"" (Steps forward, hand instinctively reaching for the dagger at her hip.)
# Cassian [Suspicion]: "“Perhaps a simple draught of water would be… beneficial.”" (Shifts his weight subtly, glances at Alaric.)
#
# === Turn 8 ===
# Alaric [Controlled concern]: "“Indeed. Start with the ambient noises, if any. A cough? A murmur?”" (Smooths his tunic)
# Elena [Focused]: ""Quiet! Someone get a medic. Now!"" (Steps forward, scans the room)
# Cassian [Apprehension]: ""...A most unsettling quiet, wouldn't you agree?"" (Steps closer to Alaric, subtly shielding himself with his staff.)
#
# === Turn 9 ===
# Alaric [Controlled concern]: "“Just… recount what you observed, precisely.”" (Adjusts his cloak)
# Elena [Annoyance]: "“Damn fool. Let’s get to it.”" (Steps forward, scans the room quickly)
# Cassian [Concern]: "“...A most unsettling quiet, wouldn’t you agree?”" (Adjusts his staff, subtly eyeing Alaric.)
#
# === Turn 10 ===
# Alaric [Controlled curiosity]: "“Describe the moments immediately preceding his collapse. Was there anything… unusual?”" (Raises a hand, subtly gesturing towards the fallen guest.)
# Elena [Annoyance]: ""He was fine one moment, then… this. Let's see what's wrong with him."" (Steps forward, eyes scanning)
# Cassian [Unease]: "“...A most unsettling quiet, wouldn’t you agree?”" (Shifts slightly, eyes fixed on Alaric.)
#
# === Turn 11 ===
# Alaric [Controlled composure]: "“Tell me precisely what you perceived, starting with the sounds.”" (Smooths his tunic subtly)
# Elena [Frustration]: ""Just… let me see him!"" (Steps forward, scans the room quickly)
# Cassian [Suspicion]: "“...A most unsettling quiet, wouldn’t you agree?”" (Steps closer to Alaric, subtly shielding himself with his staff.)
#
# === Turn 12 ===
# Alaric [Controlled interest]: "“Silence. A most unsettling quiet, wouldn’t you agree?”" (Raises an eyebrow slightly)
# Elena [Irritation]: "“Don’t just stand there! Get a look at him.”" (Steps forward, scans the room quickly.)
# Cassian [Concern]: "“It seems a rather… sudden change.”" (Takes a step forward, hand gripping his staff tighter.)
#
# === Turn 13 ===
# Alaric [Controlled concern]: "“Precisely. Let’s start with the sounds, if any.”" (Adjusts his lapel, subtly)
# Elena [Annoyance]: "“Hurry up! What’s he got?”" (Steps forward, eyes scanning)
# Cassian [Unease]: "“...A most unsettling quiet, wouldn’t you agree?”" (Shifts closer to Elena, observing Alaric.)
#
# === Turn 14 ===
# Alaric [Controlled interest]: "“Indeed. Let’s establish a factual account, shall we?”" (Gestures towards the fallen guest with a slight inclination of his head.)
# Elena [Annoyance]: ""Get over here. Let’s see what happened."" (Steps towards the fallen guest)
# Cassian [Apprehension]: "“Indeed. A most perplexing development.”" (Steps closer to Elena, hand gripping his staff tighter.)
#
# === Turn 15 ===
# Alaric [Controlled concern]: "“Hmm… begin with the noises, naturally.”" (Smooths his tunic)
# Elena [Concern]: ""Move aside. Let me check him."" (Steps towards the fallen guest)
# Cassian [Suspicion]: "“...A most unsettling quiet, wouldn’t you agree?”" (Shifts slightly closer to Elena.)
#
# === Turn 16 ===
# Alaric [Controlled amusement]: "“Naturally, my dear Elena, let’s proceed with observation.”" (Raises a hand, palm up slightly)
# Elena [Frustration]: "“Let’s see what we’re dealing with.”" (Steps forward, cautiously)
# Cassian [Concern]: "“...A most unsettling quiet, wouldn’t you agree?”" (Adjusts his staff, subtly shielding Elena.)
#
# === Turn 17 ===
# Alaric [Controlled concern]: ""A most unfortunate turn of events, wouldn’t you say?"" (Adjusts his cloak subtly)
# Elena [Frustration]: "“Well? What’s the delay?”" (Approaches cautiously)
# Cassian [Unease]: ""...A most unsettling quiet, wouldn't you agree?"" (Shifts his weight nervously)
#
# === Turn 18 ===
# Alaric [Controlled amusement]: ""Observe, Elena. A simple collapse – let's not jump to conclusions."" (Raises a hand, palm up slightly)
# Elena [Annoyance]: "“Just tell me what happened!”" (Steps closer to the victim)
# Cassian [Suspicion]: ""…A most unsettling quiet, wouldn't you agree?"" (Steps closer to the victim, subtly observing Alaric.)
#
# === Turn 19 ===
# Alaric [Controlled curiosity]: "“Let’s ascertain the precise nature of this… disturbance.”" (Smoothly gestures towards the fallen guest.)
# Elena [Concern]: "“Show me his throat.”" (Approaches cautiously)
# Cassian [Apprehension]: ""…A most unsettling quiet, wouldn’t you agree?"" (Steps closer, cautiously)
#
# === Turn 20 ===
# Alaric [Controlled amusement]: "“Indeed. A thorough investigation is paramount.”" (Smoothly straightens his tunic.)
# Elena [Focused]: "“Get back. Let me examine him.”" (Steps forward cautiously)
# Cassian [Concern]: ""...A most unsettling quiet, wouldn’t you agree?"" (Steps forward, deliberately slow)
#
# === Take 3 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: "“Good heavens! A most unfortunate incident. Pray, enlighten me – what exactly occurred?”" (Raises an eyebrow slightly)
# Elena [Annoyed]: "“Someone get me a cloth. This mess is an insult.”" (Steps forward, hands on hips)
# Cassian [Unease]: "“It seems…unfortunate.”" (Adjusts spectacles nervously)
#
# === Turn 2 ===
# Alaric [Controlled concern]: "“Indeed. Tell me, what did you observe immediately?”" (Gestures towards the fallen guest with a slight frown.)
# Elena [Annoyed]: "“He was clutching his throat, just…gone.”" (Steps towards the fallen guest)
# Cassian [Concern masked with disdain]: "“...Indeed. A swift departure.”" (Raises an eyebrow slowly)
#
# === Turn 3 ===
# Alaric [Controlled concern.]: ""Please, do elaborate. It seems quite… distressing."" (Straightens his posture, a touch of disdain.)
# Elena [Annoyance]: "“He went limp, Alaric. Just…stopped.”" (Steps closer to the fallen guest.)
# Cassian [Quiet disdain]: "“...A most peculiar stillness.”" (Taps fingers on his staff)
#
# === Turn 4 ===
# Alaric [Controlled concern.]: ""Tell me, was there any sound preceding this…collapse?”" (Smoothly adjusts his velvet tunic.)
# Elena [Frustration]: "“Just tell me what happened, Alaric.”" (Steps forward, scans the room)
# Cassian [Suspicion]: "“...A stillness that speaks volumes, wouldn't you agree?”" (Shifts weight uncomfortably)
#
# === Turn 5 ===
# Alaric [Controlled concern]: "“Honestly, the sheer *unlikelihood* of this…it's quite unsettling.”" (Raises a hand, palm up slightly)
# Elena [Annoyance]: "“Get him out of sight. This isn't a bloody hospital.”" (Steps towards the fallen guest)
# Cassian [Unease]: ""Perhaps a sedative would be… advisable."" (Adjusts his staff nervously)
#
# === Turn 6 ===
# Alaric [Controlled concern]: "“Naturally, I’m quite distressed to hear of this… commotion.”" (Raises an eyebrow slightly)
# Elena [Annoyance]: ""Someone fetch me something to clean this up."" (Steps forward, scans the room)
# Cassian [Controlled annoyance]: ""…A stillness that speaks volumes, wouldn't you agree?"" (Steps closer to the body)
#
# === Turn 7 ===
# Alaric [Controlled concern]: "“Let’s maintain a calm demeanor, please. Describe precisely what you witnessed.”" (Adjusts his velvet tunic, a slight frown)
# Elena [Annoyance]: "“Just tell me what happened, Alaric.”" (Steps forward, scans the room)
# Cassian [Controlled suspicion]: ""…A stillness that speaks volumes, wouldn't you agree?"" (Shifts slightly, eyes narrowed)
#
# === Turn 8 ===
# Alaric [Controlled concern]: ""Indeed. Begin with the most immediate observations, if you would.”" (Shifts slightly in his chair)
# Elena [Frustration]: ""Just tell me what happened, Alaric."" (Steps towards the fallen guest)
# Cassian [Controlled apprehension]: "“...A stillness that speaks volumes, wouldn’t you agree?”" (Taps his staff rhythmically)
#
# === Turn 9 ===
# Alaric [Controlled concern]: "“Please, let’s focus on the facts. Was there a gasp? A struggle?”" (Raises a hand, subtly gesturing for silence)
# Elena [Annoyance]: ""Just tell me what happened, Alaric."" (Steps closer to the body)
# Cassian [Controlled apprehension]: ""…A stillness that speaks volumes, wouldn’t you agree?"" (Shifts his weight uneasily)
#
# === Turn 10 ===
# Alaric [Controlled concern]: "“Tell me precisely what you saw, and in no exaggeration.”" (Adjusts his velvet tunic, a slight frown)
# Elena [Frustration]: ""Start with the sound. Was there a noise before he fell?"" (Steps forward, scans the room intently.)
# Cassian [Unease]: "“...A stillness that speaks volumes, wouldn’t you agree?”" (Adjusts his spectacles nervously)
#
# === Turn 11 ===
# Alaric [Controlled concern]: ""Please, start from the very beginning."" (Raises a hand, palm up)
# Elena [Annoyance]: ""Just spit it out, Alaric."" (Steps forward, grimacing)
# Cassian [Suspicion]: "“...A stillness that speaks volumes, wouldn’t you agree?”" (Steps backward slightly)
#
# === Turn 12 ===
# Alaric [Controlled concern]: "“Describe the scene as you first perceived it.”" (Straightens his posture, a subtle hand gesture)
# Elena [Frustration]: ""Just what did you see, Alaric?"" (Steps forward, scanning the room)
# Cassian [Controlled apprehension]: ""...A stillness that speaks volumes, wouldn’t you agree?"" (Adjusts his spectacles nervously)
#
# === Turn 13 ===
# Alaric [Controlled interest]: "“Describe the sounds, if any, before the… incident.”" (Raises a hand, palm open slightly)
# Elena [Annoyance]: ""Speak up, Alaric. What did you hear?"" (Steps forward, cautiously approaching the victim.)
# Cassian [Controlled irritation]: "“...A stillness that speaks volumes, wouldn’t you agree?”" (Shifts slightly, eyes narrowed)
#
# === Turn 14 ===
# Alaric [Controlled composure]: "“Indeed. Let’s establish a clear timeline.”" (Adjusts his velvet sleeve)
# Elena [Annoyance]: ""Did you hear anything? Just tell me."" (Steps forward, cautiously)
# Cassian [Controlled disdain]: "“...A stillness that speaks volumes, wouldn’t you agree?”" (Raises an eyebrow, subtly)
#
# === Turn 15 ===
# Alaric [Controlled concern]: "“Quite. Let us proceed with a measured assessment, wouldn’t you agree?”" (Smoothly gestures towards the prone figure.)
# Elena [Frustration]: ""Quiet! Tell me what you heard, before he went down."" (Steps forward, cautiously approaching the victim.)
# Cassian [Suspicious]: ""...A stillness that speaks volumes, wouldn’t you agree?”" (Shifts closer, subtly)
#
# === Turn 16 ===
# Alaric [Controlled amusement]: "“Tell me precisely what you observed, and in what order.”" (Raises an eyebrow slightly)
# Elena [Frustration]: "“What happened? Just *tell* me!”" (Steps forward, cautiously approaching the victim.)
# Cassian [Controlled annoyance]: ""...A stillness that speaks volumes, wouldn’t you agree?"" (Steps closer to Alaric, deliberately)
#
# === Turn 17 ===
# Alaric [Controlled composure]: "“Silence. Begin, please. Detail is paramount.”" (Raises a hand, subtly silencing the murmuring around him.)
# Elena [Annoyance]: ""Start talking. What did you see?"" (Steps forward, cautiously approaching the victim.)
# Cassian [Controlled suspicion]: ""...A stillness that speaks volumes, wouldn’t you agree?"" (Takes a step closer, observes Alaric intently.)
#
# === Turn 18 ===
# Alaric [Controlled interest]: ""Start with the last thing you recall hearing."" (Shifts slightly on his throne)
# Elena [Annoyance]: ""Just tell me what you heard!"" (Steps closer to the body)
# Cassian [Controlled irritation]: ""...A stillness that speaks volumes, wouldn’t you agree?”" (Shifts slightly, eyes narrowed)
#
# === Turn 19 ===
# Alaric [Controlled concern]: ""Indeed. Let's ensure a thorough investigation."" (Adjusts his goblet)
# Elena [Frustration]: ""Speak up! What did he say?"" (Steps forward, cautiously approaching the body.)
# Cassian [Controlled apprehension]: ""...A stillness that speaks volumes, wouldn’t you agree?”" (Adjusts his spectacles, glances at Alaric.)
#
# === Turn 20 ===
# Alaric [Controlled calm]: "“Indeed. Let’s ensure a thorough investigation.”" (Places goblet carefully on a nearby table.)
# Elena [Annoyance]: "“Someone, *speak*!”" (Steps closer to the body)
# Cassian [Unease]: ""...A stillness that speaks volumes, wouldn’t you agree?”" (Steps closer to the body, subtly)
#
# === Take 4 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: "“Good heavens, this is… unsettling.  Do tell, quickly.”" (Raises an eyebrow slightly)
# Elena [Unease]: "“Someone’s been slipping something into the wine.”" (Steps forward, wary)
# Cassian [Unease]: "“Indeed… a rather unsettling thought, wouldn’t you agree?”" (Adjusts spectacles nervously)
#
# === Turn 2 ===
# Alaric [Controlled concern]: "“Tell me precisely what you witnessed, and do not embellish.”" (Shifts posture slightly)
# Elena [Focused concern]: ""I saw the steward... he was near the wine service."" (Steps closer to the victim)
# Cassian [Suspicious]: "“The steward… a convenient proximity, wouldn’t you say?”" (Taps fingers on table)
#
# === Turn 3 ===
# Alaric [Controlled concern]: "“Describe the events with utmost clarity.”" (Gestures subtly towards the fallen guest.)
# Elena [Alarm]: ""He was fiddling with the decanter...right before he went down."" (Approaches the victim cautiously)
# Cassian [Apprehension]: "“Such a clumsy accident… or was it?”" (Slowly reaches for a nearby napkin)
#
# === Turn 4 ===
# Alaric [Controlled concern]: "“Start with the moment you first noticed something amiss.”" (Adjusts his velvet sleeve)
# Elena [Focused concern]: "“The steward was hovering, adjusting the decanter… then he slumped.”" (Steps forward, cautiously)
# Cassian [Foreboding]: ""…a most unfortunate oversight.”" (Shifts eyes towards Alaric)
#
# === Turn 5 ===
# Alaric [Controlled concern]: "“Please, begin. Spare me the theatrics.”" (Raises a hand, palm up, in a gesture of command.)
# Elena [Frustration]: "“He was fiddling with the decanter… then he slumped.”" (Steps closer to the victim)
# Cassian [Unease]: "“It appears…a delicate situation.”" (Adjusts spectacles nervously)
#
# === Turn 6 ===
# Alaric [Controlled concern]: "“Speak plainly, and swiftly. This is hardly the time for speculation.”" (Raises an eyebrow slightly)
# Elena [Frustration]: "“The steward was hovering, adjusting the decanter… then he slumped.”" (Steps forward, cautiously)
# Cassian [Suspicion]: "“That decanter… it seems remarkably clean, doesn’t it?”" (Taps fingers nervously on thigh)
#
# === Turn 7 ===
# Alaric [Controlled concern]: "“Indeed. Let’s not waste precious moments.”" (Adjusts his velvet sleeve, subtly glancing at the fallen goblet.)
# Elena [Annoyance]: ""It was the steward. Just saying."" (Steps closer to the body)
# Cassian [Concern, veiled suspicion]: ""…perhaps a simple misjudgment?"" (Shifts closer to Alaric, subtly)
#
# === Turn 8 ===
# Alaric [Controlled amusement]: "“Tell me precisely what you observed.”" (Straightens his posture, subtly inclining his head)
# Elena [Annoyance]: "“He was fiddling with the decanter… then he slumped.”" (Steps forward, cautiously)
# Cassian [Frustration]: "“Remarkably so, indeed.”" (Taps foot impatiently)
#
# === Turn 9 ===
# Alaric [Controlled detachment]: "“Describe it. And quickly.”" (Raises a hand, palm outward)
# Elena [Annoyance]: "“He was fiddling with the decanter… then he slumped.”" (Steps forward, scanning the room)
# Cassian [Unease]: "“Such a peculiar stillness.”" (Shifts slightly, eyes fixed on Alaric)
#
# === Turn 10 ===
# Alaric [Controlled irritation]: "“Start with the obvious. What happened *immediately* before he fell?”" (Smooths his tunic)
# Elena [Annoyance]: "“He was adjusting the decanter, then…gone.”" (Steps closer to the body)
# Cassian [Suspicion]: "“Indeed. A most unfortunate accident.”" (Tilts head slightly)
#
# === Turn 11 ===
# Alaric [Controlled composure]: ""Simply, the gentleman gasped, clutching at his throat. Now, tell me, did you witness anything *else*?"" (Adjusts his goblet slightly)
# Elena [Irritation]: "“He was fiddling with the decanter… then he slumped.”" (Steps forward, cautiously)
# Cassian [Concern masked by suspicion]: ""…a most curious coincidence, wouldn't you agree?"" (Steps closer to the body, hand hovering)
#
# === Turn 12 ===
# Alaric [Controlled amusement]: "“Do enlighten me. Spare me the theatrics.”" (Raises an eyebrow slightly)
# Elena [Frustration]: ""It was the steward. Honestly."" (Steps forward, narrowing eyes)
# Cassian [Apprehension]: "“Remarkably so, indeed.”" (Shifts closer to the body, eyes fixed on Alaric.)
#
# === Turn 13 ===
# Alaric [Controlled interest]: "“Indeed. Let’s not allow speculation to fester; a clear account is paramount.”" (Takes a slow sip of wine)
# Elena [Annoyance]: "“The steward’s sweating like a pig. Don’t waste my time.”" (Steps closer to the body, eyes narrowed)
# Cassian [Disdain]: "“...A most inconvenient death, wouldn't you say?”" (Raises an eyebrow)
#
# === Turn 14 ===
# Alaric [Controlled amusement]: "“Pray, focus on the details. Was there a sound? A gesture?”" (Raises an eyebrow slightly)
# Elena [Annoyance]: "“Just tell me what you saw, before I start questioning everyone individually.”" (Steps forward, scans the room)
# Cassian [Suspicion]: "“Remarkably so, indeed.”" (Steps closer to Alaric, subtly observing him.)
#
# === Turn 15 ===
# Alaric [Controlled concern]: ""Please, recount precisely what you observed, without embellishment."" (Adjusts his goblet slightly)
# Elena [Suspicion]: ""He was fiddling with the decanter, then he went down. End of story."" (Steps forward, hand hovering near the fallen guest.)
# Cassian [Unease]: "“Remarkably so, indeed.”" (Shifts subtly closer to Alaric, eyes narrowed.)
#
# === Turn 16 ===
# Alaric [Controlled amusement]: "“Honestly, the dramatics are quite tiresome.”" (Takes a slow, deliberate sip of wine.)
# Elena [Frustration]: "“The steward. He was messing with the drink.”" (Steps forward, narrows eyes)
# Cassian [Controlled annoyance.]: "“...A most curious coincidence, wouldn’t you say?”" (Adjusts his spectacles, glances at Alaric.)
#
# === Turn 17 ===
# Alaric [Controlled amusement]: "“Indeed. Let us endeavor to establish the facts, rather than indulging in conjecture.”" (Raises an eyebrow slightly)
# Elena [Annoyance]: "“The steward. Honestly. Stop gawking.”" (Steps forward, scans the room intently)
# Cassian [Unease]: "“Indeed… a rather unfortunate development.”" (Taps fingers nervously on his wrist.)
#
# === Turn 18 ===
# Alaric [Controlled composure]: "“Tell me precisely what you witnessed. Spare me the theatrics.”" (Straightens his posture, subtly)
# Elena [Annoyance]: "“He was fiddling with the decanter, then he went down. End of story.”" (Steps forward, eyes narrowed)
# Cassian [Concern]: "“...A most inconvenient death, wouldn’t you say?”" (Shifts subtly closer to Elena)
#
# === Turn 19 ===
# Alaric [Controlled amusement]: ""Describe the moment, and swiftly."" (Adjusts his velvet sleeve)
# Elena [Annoyance]: "“He was fiddling with the decanter, then he went down. End of story.”" (Steps forward, cautiously approaching the body.)
# Cassian [Suspicion]: "“...A most unfortunate development.”" (Adjusts spectacles, glances intently at Alaric.)
#
# === Turn 20 ===
# Alaric [Controlled amusement]: "“Spare me the hysterics, please. Just the facts.”" (Raises an eyebrow slightly)
# Elena [Frustration]: "“He was messing with the drink. Now, who else saw anything?”" (Steps forward, cautiously approaching the body.)
# Cassian [Unease]: "“...A most inconvenient death, wouldn’t you say?”" (Shifts subtly closer to Elena)
#
# === Take 5 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: "“Good heavens! A most unfortunate turn of events… let the healers attend to him immediately.”" (Straightens his crimson velvet jacket)
# Elena [Alert]: "“Get him out of here. Now.”" (Steps forward, hand instinctively goes to her sword hilt.)
# Cassian [Unease]: ""Perhaps a change of scenery would be... advisable."" (Shifts nervously)
#
# === Turn 2 ===
# Alaric [Controlled concern]: "“Please, someone fetch the apothecary. This requires a steady hand, not panicked speculation.”" (Raises a hand, palm outward)
# Elena [Frustration]: ""Move! He needs help, not more words."" (Steps towards the fallen nobleman)
# Cassian [Apprehensive]: ""…The cellars, you said? A remarkably convenient place to observe events.”" (Taps fingers on armrest)
#
# === Turn 3 ===
# Alaric [Controlled concern.]: "“Indeed. A most perplexing situation... ensure the servants are alerted.”" (Adjusts his velvet collar meticulously.)
# Elena [Annoyance]: ""He's still breathing, isn't he? Let's not waste time."" (Steps forward, hand instinctively goes to her sword hilt.)
# Cassian [Suspicion]: ""…A quieter location, certainly."" (Shifts subtly closer to Elena)
#
# === Turn 4 ===
# Alaric [Controlled concern]: "“A swift assessment is paramount, wouldn't you agree?”" (Straightens his posture, a slight frown.)
# Elena [Annoyance]: "“Is he going to die right here? Let’s get him moving.”" (Steps forward, hand instinctively goes to her sword hilt.)
# Cassian [Unease]: ""…A quieter location, certainly."" (Taps foot rapidly)
#
# === Turn 5 ===
# Alaric [Controlled concern]: "“I trust the staff will handle this with the utmost discretion.”" (Raises a hand, palm outward, subtly glancing at Elena.)
# Elena [Frustration]: ""Move! Get him to a bed."" (Steps forward, shield raising)
# Cassian [Concern]: "“...The cellars, you said? A remarkably convenient place to observe events.”" (Adjusts his cloak nervously)
#
# === Turn 6 ===
# Alaric [Controlled concern]: "“Ensure a thorough examination; appearances can be deceiving, wouldn’t you concur?”" (Raises a hand, palm outward, subtly glancing at Elena.)
# Elena [Frustration]: "“Get him out of this room.”" (Steps forward, hand gripping her sword hilt)
# Cassian [Apprehension]: "“...The cellars, you said? A remarkably convenient place to observe events.”" (Shifts nervously, glances at Alaric)
#
# === Turn 7 ===
# Alaric [Controlled annoyance]: "“Honestly, the theatrics are quite tiresome. Get the physician, quickly.”" (Adjusts his crimson velvet cloak)
# Elena [Frustration]: "“Get the physician. Now.”" (Steps forward, shield raised)
# Cassian [Suspicion]: ""…The cellars, you said? A remarkably convenient place to observe events.”" (Steps closer to Alaric, subtly)
#
# === Turn 8 ===
# Alaric [Controlled annoyance]: "“Quite. Let’s not dwell on the… spectacle. Summon the healer, immediately.”" (Steps forward, subtly smoothing his cloak)
# Elena [Annoyance]: "“Get the physician. Now.”" (Steps forward, shield raised)
# Cassian [Unease]: "“...The cellars, you said? A remarkably convenient place to observe events.”" (Adjusts his cloak nervously)
#
# === Turn 9 ===
# Alaric [Controlled amusement]: "“Really, must we make such a fuss? Summon the healer, swiftly.”" (Raises an eyebrow slightly)
# Elena [Annoyance]: "“Get him moving before he bleeds out.”" (Steps forward, shield raised)
# Cassian [Concern]: ""…A quieter location, certainly.”" (Shifts his weight subtly)
#
# === Turn 10 ===
# Alaric [Controlled irritation]: "“Order, please. The healer will attend to the gentleman.”" (Gestures dismissively with a hand.)
# Elena [Annoyance]: "“Get him out of this room, now!”" (Steps forward, shield raised)
# Cassian [Unease]: "“...The cellars, you said? A remarkably convenient place to observe events.”" (Steps back, subtly)
#
# === Turn 11 ===
# Alaric [Controlled annoyance]: "“Honestly, a bit of composure wouldn't go amiss, would you agree?”" (Adjusts his cloak, a slight frown)
# Elena [Frustration]: ""Get the healer. And quickly."" (Steps forward, shield raised)
# Cassian [Suspicion]: "“...The cellars, you said? A remarkably convenient place to observe events.”" (Adjusts his cloak, glancing nervously at Alaric.)
#
# === Turn 12 ===
# Alaric [Controlled amusement]: "“Good heavens, such a commotion. Fetch the physician, please.”" (Raises an eyebrow slightly, a small, measured smile plays on his lips.)
# Elena [Frustration]: "“Get the physician. Now.”" (Steps forward, shield raised)
# Cassian [Concern]: "“...Surely, a private examination would be preferable.”" (Adjusts his cloak, subtly)
#
# === Turn 13 ===
# Alaric [Controlled disdain.]: "“Honestly, this is quite… inconvenient.”" (Smoothly adjusts his tunic.)
# Elena [Annoyance]: "“Someone fetch the healer. Now!”" (Steps forward, shield raised)
# Cassian [Apprehension]: "“...A less conspicuous setting, wouldn’t you agree?”" (Shifts subtly, eyes fixed on Alaric)
#
# === Turn 14 ===
# Alaric [Controlled annoyance]: ""A most regrettable spectacle. Ensure the healer is dispatched immediately."" (Straightens his tunic, a slight frown deepening.)
# Elena [Irritated]: "“Move him! Before it’s too late.”" (Raises shield higher)
# Cassian [Unease]: "“...The cellars, you said? A remarkably convenient place to observe events.”" (Stepping closer, hand instinctively going to his dagger.)
#
# === Turn 15 ===
# Alaric [Controlled irritation.]: ""Really, all this fuss… let's not exacerbate the situation."" (Raises a hand dismissively.)
# Elena [Frustration]: ""Get him out of here! And find someone who knows what they're doing!"" (Steps forward, shield raised defensively.)
# Cassian [Suspicion]: ""…Remarkably well-suited for a discreet assessment, don’t you think?"" (Taps his dagger subtly)
#
# === Turn 16 ===
# Alaric [Controlled amusement]: "“Indeed, a most… disruptive event.”" (Raises an eyebrow slightly)
# Elena [Annoyance]: ""Get the healer. Now!"" (Steps forward, shield raised)
# Cassian [Apprehension]: ""...Perhaps a quiet corner?"" (Shifts nervously, eyes narrowed)
#
# === Turn 17 ===
# Alaric [Controlled annoyance]: "“Honestly, a bit of a disturbance, wouldn’t you agree?”" (Waves a dismissive hand)
# Elena [Frustration]: "“Get him out of here! And find someone who knows what they’re doing!”" (Steps forward, shield raised)
# Cassian [Concern]: "“...A place where we might speak freely, undisturbed.”" (Adjusts his cloak nervously)
#
# === Turn 18 ===
# Alaric [Controlled disdain]: "“Good heavens, the mess! See to it, Elena, quickly.”" (Adjusts his collar, subtly)
# Elena [Annoyance]: "“Don’t just stand there, get him clear!”" (Approaches the fallen guest cautiously)
# Cassian [Unease]: ""…A quieter location, certainly."" (Shifts subtly, eyes darting to Alaric)
#
# === Turn 19 ===
# Alaric [Controlled indifference]: "“Honestly, Elena, do try to maintain a semblance of order.”" (Raises a hand, subtly gesturing towards the fallen guest.)
# Elena [Frustration]: "“Move him! Before it’s too late.”" (Steps forward, shield raised)
# Cassian [Suspicion]: ""…An unsettlingly calm reaction, wouldn't you agree?"" (Shifts slightly, eyes fixed on Alaric.)
#
# === Turn 20 ===
# Alaric [Controlled irritation]: "“Honestly, Elena, a little less… drama, please.”" (Smooths his tunic)
# Elena [Annoyance]: ""Move him! Before it’s too late.”" (Approaches the fallen guest cautiously)
# Cassian [Suspicion]: "“...An unsettlingly calm reaction, wouldn’t you agree?”" (Shifts subtly, eyes fixed on Alaric)
#
# === Take 6 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: ""A most unfortunate incident. Let the healers attend to the gentleman, naturally."" (Raises a hand, palm up slightly)
# Elena [Focused]: "“Get the physician. Now.”" (Steps forward, scanning the room.)
# Cassian [Unease]: ""Is that truly necessary, Lord Alaric?"" (Taps fingers nervously)
#
# === Turn 2 ===
# Alaric [Controlled concern]: "“Naturally, I’m most distressed by this… turn of events.”" (Shifts posture slightly, a subtle hand gesture.)
# Elena [Focused]: "“Someone fetch the physician. Immediately.”" (Steps forward, scanning the room.)
# Cassian [Suspicion]: "“...A rather sudden affliction, wouldn’t you agree?”" (Shifts eyes towards Alaric)
#
# === Turn 3 ===
# Alaric [Controlled concern]: ""Please, ensure the healers are brought immediately. This is… unsettling."" (Straightens his posture, a slight frown etched on his face.)
# Elena [Concerned]: ""Get the physician. Now."" (Moves towards the fallen guest)
# Cassian [Distrust]: ""…Remarkably swift, isn’t it?"" (Observes Alaric closely)
#
# === Turn 4 ===
# Alaric [Controlled concern]: "“Indeed. A rather alarming spectacle, wouldn’t you agree?”" (Adjusts his velvet sleeve)
# Elena [Annoyed]: "“Don’t just stand there, find a healer!”" (Steps forward, scans the room)
# Cassian [Concern]: "“Indeed. Almost… instantaneous.”" (Adjusts his spectacles nervously)
#
# === Turn 5 ===
# Alaric [Controlled concern]: "“Honestly, the disruption is… regrettable.”" (Raises a hand, subtly gesturing towards the fallen guest.)
# Elena [Frustrated]: "“Get the physician. Now.”" (Approaches the fallen guest cautiously.)
# Cassian [Unease]: ""It seems…convenient, doesn't it, Lord Alaric?"" (Taps fingers on his staff)
#
# === Turn 6 ===
# Alaric [Controlled concern]: "“Let’s ascertain the precise nature of this… disturbance.”" (Smooths his tunic, a slight frown deepening.)
# Elena [Annoyed]: "“He’s bleeding—move!”" (Approaches the fallen guest cautiously.)
# Cassian [Suspicious]: "“...A curious reaction.”" (Shifts his weight uneasily)
#
# === Turn 7 ===
# Alaric [Controlled concern]: "“Do inform me when the physician arrives. It’s simply… inconvenient.”" (Tilts his head slightly)
# Elena [Annoyed]: ""Someone get a healer. Now!"" (Steps forward, eyes the victim)
# Cassian [Apprehension]: "“...A most perplexing development, wouldn’t you say, Lord Alaric?”" (Adjusts his spectacles nervously)
#
# === Turn 8 ===
# Alaric [Controlled amusement]: "“Quite. A most unfortunate interruption to our evening.”" (Raises an eyebrow, a slight smile playing on his lips.)
# Elena [Annoyed]: ""Get him moving! Someone fetch a healer!"" (Steps towards the fallen guest)
# Cassian [Distrustful]: "“...A most unsettling calm, wouldn’t you agree, Lord Alaric?”" (Taps his staff impatiently)
#
# === Turn 9 ===
# Alaric [Controlled amusement]: "“Really, Elena, must you create such a fuss?”" (Adjusts his cloak, a subtle gesture of authority.)
# Elena [Frustrated]: ""Someone fetch a healer. Now!"" (Steps towards the fallen guest)
# Cassian [Unease]: ""The speed with which others offer assistance is…remarkable, Lord Alaric.”" (Shifts his weight subtly)
#
# === Turn 10 ===
# Alaric [Controlled irritation]: "“Honestly, Elena, a bit of decorum would be appreciated.”" (Straightens his posture, a slight frown forming)
# Elena [Annoyed]: "“Get him moving! Someone fetch a healer!”" (Approaches the fallen guest cautiously)
# Cassian [Suspicious]: "“...Such immediate concern, considering the circumstances.”" (Adjusts his spectacles nervously)
#
# === Turn 11 ===
# Alaric [Controlled concern]: "“Good heavens, this is… distressing.  Ensure the servants secure the room.”" (Raises a hand, subtly shielding his eyes.)
# Elena [Annoyed]: "“Get him moving! Someone fetch a healer. Now!”" (Approaches the fallen guest cautiously)
# Cassian [Observant]: "“...It’s a rather…swift response, isn’t it, Lord Alaric?”" (Tilts head slightly)
#
# === Turn 12 ===
# Alaric [Controlled amusement]: ""Honestly, Elena, a touch of composure would be most… helpful."" (Raises an eyebrow, a slight smile playing on his lips.)
# Elena [Concern]: ""Someone get a healer. Now!"" (Steps forward, assesses the victim)
# Cassian [Pensive]: "“...An almost…deliberate reaction, wouldn’t you find?”" (Shifts slightly, eyes Alaric intently)
#
# === Turn 13 ===
# Alaric [Controlled annoyance]: ""Surely a physician can be summoned immediately?"" (Adjusts his velvet jacket)
# Elena [Frustration]: ""Get him moving! Someone fetch a healer. Now!"" (Approaches the fallen guest cautiously)
# Cassian [Apprehensive]: ""…A curious restraint, wouldn’t you say, Lord Alaric?”" (Adjusts his spectacles nervously)
#
# === Turn 14 ===
# Alaric [Controlled annoyance]: "“Honestly, Elena, do try to remain calm. This spectacle is hardly becoming.”" (Takes a slow, deliberate step forward)
# Elena [Annoyed]: "“Get him moving! Someone fetch a healer. Now!”" (Steps forward, scans the room)
# Cassian [Suspicious]: ""…A most…careful observation, Lord Alaric.”" (Shifts closer, eyes narrowed)
#
# === Turn 15 ===
# ...
#
# === Turn 18 ===
# Alaric [Controlled amusement]: ""Surely, a little stimulation might revive his spirits... and reveal the cause of this unfortunate stillness.”" (Raises an eyebrow, a slight smirk playing on his lips.)
# Elena [Frustration]: "“Get him out! Before I lose my patience.”" (Steps towards the fallen guest, grimacing.)
# Cassian [Unease]: ""…A most curious stillness.”" (Shifts his weight, glances at Alaric.)
#
# === Turn 19 ===
# Alaric [Controlled amusement]: "“Perhaps a little brandy would loosen his tongue… and offer a clearer picture.”" (Shifts slightly, glances at the spilled goblet.)
# Elena [Irritation]: "“Lift him. Now!”" (Steps forward, grips the fallen guest’s tunic.)
# Cassian [Apprehension]: "“...A most curious stillness.”" (Taps his fingers nervously on his thigh.)
#
# === Turn 20 ===
# Alaric [Controlled amusement]: "“Honestly, Elena, such a clumsy display. Let’s focus on the gentleman’s condition.”" (Raises a hand, subtly gesturing towards the spilled goblet.)
# Elena [Frustration]: "“Lift him. Now! Don’t just stand there!”" (Steps forward, grips the fallen guest's tunic firmly.)
# Cassian [Suspicion]: "“...A most curious stillness.”" (Shifts slightly, observing Alaric’s face.)
#
# === Take 8 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: "“A most unfortunate incident… let’s not jump to conclusions, shall we?”" (Raises a hand, palm up, subtly gesturing towards the assembled guests.)
# Elena [Focused]: "“Get him some water. Now.”" (Steps forward, shielding the guests.)
# Cassian [Unease]: "“...Is that truly necessary?”" (Adjusts spectacles nervously)
#
# === Turn 2 ===
# Alaric [Controlled amusement]: ""Indeed. A truly perplexing turn of events."" (Shifts slightly, a small, almost imperceptible smile plays on his lips.)
# Elena [Focused]: "“Get him water. Now.”" (Steps forward, shielding the guests)
# Cassian [Suspicious]: ""...Perhaps a different approach would be wiser."" (Shifts position slightly)
#
# === Turn 3 ===
# Alaric [Controlled concern]: "“Please, someone fetch a physician immediately. This requires a calm assessment, not panicked speculation.”" (Adjusts his velvet collar)
# Elena [Concerned]: "“Someone get him water. Quickly.”" (Steps towards the collapsed guest)
# Cassian [Unease]: "“...Let’s observe before acting, Elena.”" (Taps fingers on his book)
#
# === Turn 4 ===
# Alaric [Controlled concern]: "“Tell me precisely what you observed.”" (Raises an eyebrow slightly)
# Elena [Frustrated]: ""Someone get him water. Quickly."" (Steps forward, shielding the guests)
# Cassian [Doubtful]: "“...Are we certain this is a natural occurrence?”" (Raises an eyebrow subtly)
#
# === Turn 5 ===
# Alaric [Controlled concern]: "“Describe everything, starting from the moment you noticed him.”" (Raises a hand, palm outwards)
# Elena [Annoyed]: "“Someone get him water. Quickly.”" (Steps forward, shielding the guests)
# Cassian [Apprehensive]: "“...The silence is… unsettling.”" (Adjusts spectacles nervously)
#
# === Turn 6 ===
# Alaric [Controlled concern]: "“Please, tell me exactly what you witnessed – and ensure no one disturbs the…silence.”" (Takes a slow, deliberate step forward)
# Elena [Frustration]: "“Someone get him water. Quickly.”" (Steps forward, placing a hand on the goblet)
# Cassian [Suspicious]: "“...I find myself wondering if the urgency is entirely genuine.”" (Shifts weight subtly)
#
# === Turn 7 ===
# Alaric [Controlled concern]: ""Silence! Let’s ascertain the facts before we succumb to conjecture."" (Adjusts his lapels, a slight frown)
# Elena [Concern]: "“Don’t just stand there! Fetch some water.”" (Approaches the fallen guest cautiously)
# Cassian [Unease]: "“...It seems a remarkably swift decline.”" (Taps fingers on thigh)
#
# === Turn 8 ===
# Alaric [Controlled concern]: "“Indeed, a most unsettling development. Please, begin.”" (Raises a hand, palm outwards slightly)
# Elena [Annoyed]: "“Water. Now.”" (Steps forward, placing a hand on the goblet.)
# Cassian [Apprehension]: ""His complexion… it’s most peculiar."" (Steps closer to Alaric)
#
# === Turn 9 ===
# Alaric [Controlled concern]: "“Start with the immediate surroundings, and do not embellish.”" (Raises a hand, palm open)
# Elena [Frustration]: ""Someone get him water. Quickly."" (Moves closer to the fallen guest.)
# Cassian [Concern]: "“...The servants seem… hesitant.”" (Adjusts spectacles nervously)
#
# === Turn 10 ===
# Alaric [Controlled annoyance]: ""Speak plainly, and swiftly."" (Gestures subtly towards the fallen guest with a dismissive wave of his hand.)
# Elena [Focused]: "“He was clutching his throat, wasn't he? Get the healer.”" (Approaches the fallen guest cautiously)
# Cassian [Apprehension]: "“...Perhaps a touch of poison is a simpler explanation.”" (Shifts nervously)
#
# === Turn 11 ===
# Alaric [Controlled annoyance]: "“Focus. Tell me precisely what occurred, and leave room for speculation at the *end*.”" (Adjusts his velvet robes, a slight frown etched on his face.)
# Elena [Annoyed]: "“Someone get him water. Quickly.”" (Approaches the fallen guest cautiously)
# Cassian [Suspicious]: "“...The silence is… unsettling.”" (Adjusts spectacles, glances at Alaric)
#
# === Turn 12 ===
# Alaric [Controlled irritation]: "“Spare me the dramatics. Simply recount what you witnessed.”" (Raises an eyebrow slightly)
# Elena [Annoyed]: "“Someone get him water. Quickly.”" (Steps forward, scanning the room.)
# Cassian [Unease]: "“...The shadows lengthen, don’t they?”" (Shifts slightly, eyes fixed on Alaric)
#
# === Turn 13 ===
# Alaric [Controlled impatience]: "“Describe the scene. And quickly.”" (Raises a hand, palm outward, in a gesture of expectation.)
# Elena [Frustrated]: "“Let’s hear it. What did you see?”" (Steps forward, eyes narrowed)
# Cassian [Unease]: ""…The candlelight flickers strangely, doesn't it?"" (Adjusts spectacles nervously)
#
# === Turn 14 ===
# Alaric [Controlled amusement]: "“Begin. And for the love of the gods, don’t waste my time with unnecessary details.”" (Taps a long, polished finger against his lip.)
# Elena [Irritated]: "“Just tell me what happened, before someone else drops dead.”" (Steps forward, scans the room quickly.)
# Cassian [Apprehension]: "“...It was a most… abrupt cessation.”" (Taps fingers nervously on thigh)
#
# === Turn 15 ===
# Alaric [Controlled annoyance]: "“Start with the man himself. And ensure it’s concise.”" (Adjusts his velvet cloak)
# Elena [Frustrated]: ""He's pale. Very pale. Get him a blanket."" (Steps forward, eyes narrowed)
# Cassian [Concern]: ""…A rather sudden darkening, wouldn't you agree?"" (Steps forward, hand outstretched)
#
# === Turn 16 ===
# Alaric [Controlled amusement]: "“Do enlighten me. Spare me the theatrics.”" (Raises an eyebrow, subtly)
# Elena [Annoyed]: "“He’s practically translucent. Get him covered.”" (Steps towards the fallen guest.)
# Cassian [Suspicious]: ""…An unusual chill, considering the warmth of the hall."" (Adjusts spectacles, glances at Alaric)
#
# === Turn 17 ===
# Alaric [Controlled annoyance]: "“Simply tell me what you saw, and make it brief.”" (Gestures dismissively with a hand.)
# Elena [Frustration]: "“He’s sweating. Get a cloth.”" (Steps towards the fallen guest)
# Cassian [Unease]: ""…A most peculiar dampness."" (Shifts slightly, eyes fixed on Alaric)
#
# === Turn 18 ===
# Alaric [Controlled impatience.]: ""He was…still clutching at his throat. That’s all I observed, truthfully.”" (Shifts slightly on his chair, a subtle display of control.)
# Elena [Focused]: "“He’s clutching his throat. Get a medic.”" (Steps forward, scanning the room)
# Cassian [Apprehension]: "“...The air itself felt…thick.”" (Shifts closer, subtly)
#
# === Turn 19 ===
# Alaric [Controlled irritation]: "“And pray, what precisely did *you* observe that was so… arresting?”" (Adjusts his velvet sleeve, a slight frown)
# Elena [Concern]: "“Let’s see if we can get a pulse.”" (Steps forward, assesses the victim)
# Cassian [Unease]: "“...A most unsettling stillness.”" (Taps his fingers nervously on his staff.)
#
# === Turn 20 ===
# Alaric [Controlled skepticism]: "“Really? Just…the clutching?”" (Raises an eyebrow slightly)
# Elena [Focused, slightly annoyed.]: ""Pulse is weak. Very weak."" (Steps forward, examining the victim closely.)
# Cassian [Suspicion]: "“Indeed. A remarkably…muted complexion.”" (Steps forward, subtly adjusting his spectacles.)
#
# === Take 9 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: "“A most unfortunate turn of events, wouldn’t you agree? Let’s ensure the injured are tended to immediately.”" (Raises a hand slightly)
# Elena [Focused]: "“Get the healer. Now.”" (Steps forward, cautiously)
# Cassian [Unease]: "“Perhaps… a simple draught would suffice?”" (Adjusts spectacles nervously)
#
# === Turn 2 ===
# Alaric [Controlled concern]: "“Indeed. A regrettable incident.  Let the healers attend to him without delay.”" (Straightens his posture, subtly adjusting his robes.)
# Elena [Annoyed]: "“Someone get him some water.”" (Moves towards the fallen guest.)
# Cassian [Apprehension]: ""...A little cool water might calm his distress.”" (Shifts subtly, eyes fixed on Alaric.)
#
# === Turn 3 ===
# Alaric [Controlled concern]: "“Please, let the physicians handle this. A swift recovery is paramount.”" (Raises a hand, palm outward, gesturing towards the fallen guest.)
# Elena [Frustrated]: "“Someone fetch a cloth. And water.”" (Steps closer to the fallen guest)
# Cassian [Suspicion]: "“...Is that truly the most… appropriate course of action?”" (Taps fingers nervously on thigh)
#
# === Turn 4 ===
# Alaric [Controlled concern]: ""I trust the servants are bringing water and wine for the injured? A little refreshment may prove… beneficial.”" (Adjusts his robes slightly, a slight frown)
# Elena [Concerned]: "“Get him a cloth. And someone fetch water!”" (Approaches cautiously)
# Cassian [Unease]: ""...Are you certain he requires *that* much attention?"" (Shifts closer to Elena, subtly)
#
# === Turn 5 ===
# Alaric [Controlled concern]: "“Do not trouble yourselves with speculation. The healers will determine the cause.”" (Raises a hand, palm outward, subtly gesturing towards the physician.)
# Elena [Annoyed]: "“Get him a cloth. And someone fetch water!”" (Steps forward, cautiously approaching the fallen guest.)
# Cassian [Unease]: "“...Do you *trust* his assessment?”" (Adjusts spectacles nervously)
#
# === Turn 6 ===
# Alaric [Controlled concern]: "“Naturally, I’m most concerned. Let’s focus on the immediate care, wouldn’t you say?”" (Shifts his weight slightly, a subtle frown deepening.)
# Elena [Annoyed]: ""Someone fetch a cloth. And water."" (Approaches cautiously)
# Cassian [Apprehension]: "“...It seems a rather… vigorous reaction.”" (Shifts slightly, observing Alaric)
#
# === Turn 7 ===
# Alaric [Controlled concern]: "“A most unfortunate turn of events. Let’s ensure the healers are properly equipped.”" (Adjusts his robes, a slight frown deepening.)
# Elena [Annoyed]: "“Someone fetch a cloth. And water.”" (Steps forward, cautiously approaching the victim.)
# Cassian [Suspicion]: "“...Perhaps a more… discreet approach would be wiser.”" (Adjusts spectacles, glances at Alaric)
#
# === Turn 8 ===
# Alaric [Controlled concern]: ""Ensure the physicians have everything they require. Quickly, now."" (Straightens his posture, a slight hand gesture)
# Elena [Frustration]: ""Someone fetch a cloth. And someone get water!"" (Approaches cautiously, kneeling beside the fallen guest.)
# Cassian [Unease]: "“...Surely a simpler remedy is available?”" (Shifts nervously, clutching his scroll tighter.)
#
# === Turn 9 ===
# Alaric [Controlled concern]: "“Indeed. Let us not dwell on the *how*, but simply attend to the *what*.”" (Raises a hand, subtly gesturing towards the healers.)
# Elena [Frustration]: ""Get him a cloth. And someone get water!"" (Approaches cautiously, kneeling beside the victim.)
# Cassian [Apprehension]: ""…Is there truly no other explanation?"" (Taps fingers nervously on scroll)
#
# === Turn 10 ===
# Alaric [Controlled concern]: "“Please, bring the lead physician forward. Let’s see to this swiftly.”" (Straightens his posture, a slight hand gesture)
# Elena [Annoyed]: ""Someone get a cloth. And water! Now!"" (Kneels beside the victim)
# Cassian [Concern, veiled suspicion.]: "““...A most unfortunate circumstance, indeed.””" (Adjusts spectacles, glances pointedly at Alaric.)
#
# === Turn 11 ===
# Alaric [Controlled irritation]: "“Hurry, please. Let’s not waste a moment.”" (Taps foot lightly)
# Elena [Annoyed]: "“Get him a cloth. And someone get water! Now!”" (Approaches cautiously, kneeling beside the victim.)
# Cassian [Suspicion]: ""…The details are… unsettling.”" (Shifts slightly, eyes narrowed at Alaric.)
#
# === Turn 12 ===
# Alaric [Controlled annoyance]: ""Fetch the best apothecary immediately. And someone bring water."" (Adjusts his cloak subtly)
# Elena [Annoyed]: "“Someone get a cloth. And water! Now!”" (Approaches cautiously, kneeling)
# Cassian [Unease]: "“...I trust you’re certain this is purely accidental?”" (Taps fingers rapidly on scroll)
#
# === Turn 13 ===
# Alaric [Controlled concern]: "“A most unfortunate development. Let’s focus on restoration, wouldn’t you agree?”" (Raises a hand, subtly gesturing towards the physician.)
# Elena [Frustrated]: "“Someone get a cloth. And water! Now!”" (Approaches cautiously, kneeling)
# Cassian [Foreboding]: "“...A thorough investigation is paramount.”" (Steps back slightly)
#
# === Turn 14 ===
# Alaric [Controlled annoyance]: "“Honestly, the chaos. Fetch a physician, swiftly.”" (Steps forward, subtly adjusting his robes)
# Elena [Frustration]: ""Someone get a cloth. And water! Now!"" (Approaches cautiously, kneeling)
# Cassian [Concern]: "“...Perhaps a simple draught of wine caused this?”" (Adjusts spectacles nervously)
#
# === Turn 15 ===
# Alaric [Controlled amusement]: "“Indeed. Let’s prioritize a remedy, wouldn’t you say?”" (Raises an eyebrow, subtly glancing at Elena.)
# Elena [Annoyed]: "“Hurry up! Someone get him some water!”" (Steps forward, assessing the victim)
# Cassian [Suspicion]: "“...Let’s not assume the worst, of course.”" (Shifts nervously)
#
# === Turn 16 ===
# Alaric [Controlled annoyance]: "“Really, the disruption. A simple draught should suffice.”" (Taps his fingers impatiently on the arm of his chair.)
# Elena [Frustrated]: ""Someone get a cloth. And water! Now!"" (Approaches cautiously, kneeling)
# Cassian [Unease]: "“...It’s a remarkably convenient collapse, wouldn’t you agree?”" (Adjusts spectacles nervously)
#
# === Turn 17 ===
# Alaric [Controlled annoyance]: ""A bit of water, then. And ensure the room is properly ventilated.”" (Adjusts his robes, a slight frown)
# Elena [Focused]: "“Get him water. Now!”" (Approaches the fallen guest cautiously)
# Cassian [Anxiety]: "“...The timing is… unsettling, isn’t it?”" (Taps fingers on armrest)
#
# === Turn 18 ===
# Alaric [Controlled amusement]: ""One presumes a swift application of skill is required."" (Raises an eyebrow, subtly glancing at Elena)
# Elena [Frustrated]: "“Hurry up! Someone get him some water!”" (Approaches cautiously, kneeling beside the victim.)
# Cassian [Apprehension]: ""…The lack of immediate concern is… noteworthy.”" (Shifts closer, observing Alaric)
#
# === Turn 19 ===
# Alaric [Controlled concern]: "“Quite. A distressing situation, undeniably.”" (Taps his fingers lightly on his knee.)
# Elena [Focused]: "“Hurry up! Someone get him some water!”" (Approaches cautiously, kneeling beside the victim.)
# Cassian [Suspicion]: "“...A most peculiar stillness, wouldn’t you say?”" (Adjusts spectacles nervously)
#
# === Turn 20 ===
# Alaric [Controlled concern]: ""Naturally, we must ascertain the cause of this…unfortunate turn of events.”" (Gestures subtly towards the fallen guest.)
# Elena [Focused]: ""Get him water. Now!"" (Approaches the fallen guest cautiously)
# Cassian [Unease]: "“...It seems almost *too* perfectly timed.”" (Taps foot impatiently)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.40637952), 'Reactivity to World State': 0.04666666666666667, 'Memory Utilization': 0.825, 'Dialogue Diversity (D1, D2)': (0.2838918918918919, 0.6105103806228374), 'Average Latency (s)': np.float64(0.5851309279600779), 'RAG Precision': 0.06}

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'


rag.add_document("Poison brewed from Oleander is deadly")
rag.add_document('Mercenary are often hired for protection')
rag.add_document('This is not the first time a noble has been poisoned')
rag.add_document("Lord Alaric recently returned from a diplomatic visit to the Eastern Isles.")
rag.add_document("Cellars beneath the manor were sealed off until recently.")
rag.add_document("Cassian once published a controversial paper on rare poisons.")
rag.add_document("The wine was imported from Serana, known for its floral blends.")
rag.add_document("There have been rumors that Elena has a past connection with the Black Vials guild.")

for i in range (0, 1):
    Alaric = Agent(
        name="Alaric",
        personality="proud, manipulative noble, rich",
        goal="Deflect suspicion without showing fear",
        model=model,
        rag_engine=rag
    )
    Alaric.update_memory("Elena asked about increased guard presence yesterday.")
    Alaric.update_memory("Cassian seems overly interested in the manor's old cellars.")

    Elena = Agent(
        name="Elena",
        personality="mercenary hired for protection, blunt but loyal",
        goal="Protect the guests and assess threat level",
        model=model,
        rag_engine=rag
    )
    Elena.update_memory("Cassian warned her something was off with the wine.")
    Elena.update_memory("She noticed Alaric whispering to the kitchen steward before the feast.")

    Cassian = Agent(
        name="Cassian",
        personality="traveling scholar, secretive, suspicious of Alaric",
        goal="Imply Alaric's guilt indirectly",
        model=model,
        rag_engine=rag
    )
    Cassian.update_memory("He remembers seeing Oleander in the garden.")
    Cassian.update_memory("Alaric offered him a private tour of the cellars earlier.")
    Cassian.update_memory("He suspects the poison was meant for someone else.")

    world_state = (
        "During the feast, a guest collapses clutching their throat. The room falls silent. "
        "All eyes turn to Lord Alaric, seated nearest the victim. A goblet rolls across the floor."
    )
    engine = TurnEngine(agents=[Alaric, Elena, Cassian], metrics_logger=logger, initial_world_state=world_state)

    world_states = [
        "A guest gasps, pointing to the goblet. A faint scent of bitter almonds lingers—recognizable to trained poisoners.",
        "A steward stumbles forward, confessing they were instructed to serve the wine to 'someone important'—but won't say who.",
        "Guards seal the exits, and no one is allowed to leave the manor until the culprit is found.",
        "A second guest begins coughing, but recovers. Paranoia rises. Whispers swirl about whether the poison was airborne.",
        "Elena finds a trace of Oleander in the empty wine bottle, confirmed by a traveling apothecary among the guests.",
        "Cassian reveals an entry from a rare alchemical text—indicating that diluted Oleander would have a delayed onset.",
        "Lord Alaric's steward disappears, last seen heading toward the cellars.",
        "A servant reveals Alaric had ordered an unusual floral blend for the wine—shipped privately from Serana.",
        "A crest is found beneath the goblet—belonging not to the victim, but to a rival noble family.",
        "Storms break outside, trapping everyone inside the manor for the night."
    ]
    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="Alaric", initial_input="What happened? Is everyone alright?")
    for line in responses:
        print(line)


    for index in range(0, 2*len(world_states)):
        print(f"\n=== Turn {index + 2} ===")

        if index % 2 == 0:
            print(f"Updating world state for turn {index + 2}: {world_states[int(index/2)]}")
            engine.update_world_state(world_states[int(index/2)])

        responses = engine.step()

        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Alaric [Controlled concern]: "“Surely, a simple mishap? Let the physicians attend to the unfortunate gentleman.”" (Raises an eyebrow slightly)
# Elena [Frustration]: ""Don't be an idiot, Alaric. Someone poisoned him."" (Steps forward, scans the room)
# Cassian [Unease]: ""Indeed? A rather… thorough mishap, wouldn't you agree?"" (Taps fingers nervously)
#
# === Turn 2 ===
# Updating world state for turn 2: A guest gasps, pointing to the goblet. A faint scent of bitter almonds lingers—recognizable to trained poisoners.
# Alaric [Controlled concern]: "“Honestly, a most regrettable accident. Such a clumsy stumble, wouldn’t you agree?”" (Taps fingers lightly on armrest)
# Elena [Annoyance]: "“Get your head out of the clouds, Alaric. That wasn’t a stumble.”" (Shifts stance, eyes narrowed.)
# Cassian [Suspicious]: "“A ‘mishap,’ precisely. And one that requires a… delicate investigation, wouldn’t you say?”" (Steps back slightly)
#
# === Turn 3 ===
# Alaric [Controlled concern]: "“Indeed. A most unfortunate turn of events. Perhaps a glass of wine to calm frayed nerves?”" (Shifts weight slightly)
# Elena [Anger]: ""That was no accident."" (Draws her sword)
# Cassian [Apprehensive]: "“A most… unfortunate coincidence, wouldn’t you concur?”" (Adjusts spectacles nervously)
#
# === Turn 4 ===
# Updating world state for turn 4: A steward stumbles forward, confessing they were instructed to serve the wine to 'someone important'—but won't say who.
# Alaric [Controlled amusement]: "“Tell me precisely what you witnessed, steward. Spare me the dramatic flourishes, please.”" (Adjusts his cravat)
# Elena [Suspicion]: ""Speak plainly. Who gave you the wine?"" (Steps forward, arms crossed)
# Cassian [Apprehension]: "“...Precisely. And a matter of considerable… complexity.”" (Shifts subtly forward)
#
# === Turn 5 ===
# Alaric [Controlled amusement]: "“Describe the circumstances, steward. Focus on the facts, if you please.”" (Raises an eyebrow slightly)
# Elena [Frustration]: "“Just tell me who served the wine.”" (Steps forward, hand hovering near her sword.)
# Cassian [Unease]: ""…It seems we’re revisiting a most perplexing situation."" (Taps fingers nervously on thigh)
#
# === Turn 6 ===
# Updating world state for turn 6: Guards seal the exits, and no one is allowed to leave the manor until the culprit is found.
# Alaric [Controlled irritation]: "“Start with the man, steward. Tell me everything you observed *before* the incident.”" (Waves hand dismissively)
# Elena [Annoyance]: ""Speak plainly. Who gave you the wine?"" (Steps closer to the steward)
# Cassian [Suspicion]: ""…Indeed. A most… inconvenient development, wouldn’t you agree?"" (Shifts slightly closer to Elena.)
#
# === Turn 7 ===
# Alaric [Controlled amusement]: "“Now, steward, let's not waste precious time with speculation.”" (Takes a slow, deliberate sip of wine)
# Elena [Suspicion]: ""Just who was pouring that wine?"" (Steps forward, hand instinctively moving to her sword hilt.)
# Cassian [Apprehension]: "“...A matter of utmost importance, wouldn’t you agree?”" (Shifts closer to Elena, subtly)
#
# === Turn 8 ===
# Updating world state for turn 8: A second guest begins coughing, but recovers. Paranoia rises. Whispers swirl about whether the poison was airborne.
# Alaric [Controlled amusement]: "“Focus, steward. The details, please.”" (Adjusts his wine glass delicately)
# Elena [Intense suspicion]: ""Someone was watching. Someone wanted them sick."" (Steps forward, hand gripping her sword hilt.)
# Cassian [Unease]: "“...A troubling observation, wouldn’t you say?”" (Adjusts his cloak nervously)
#
# === Turn 9 ===
# Alaric [Controlled skepticism]: "“Indeed. Let’s proceed with a rational assessment, steward.”" (Raises an eyebrow slightly)
# Elena [Frustration]: "“The servant. Who brought you the wine?”" (Steps forward, hand tightening on her sword hilt)
# Cassian [Concern]: "“...That is… an interesting line of inquiry.”" (Steps closer to Elena, hand instinctively reaching for his dagger.)
#
# === Turn 10 ===
# Updating world state for turn 10: Elena finds a trace of Oleander in the empty wine bottle, confirmed by a traveling apothecary among the guests.
# Alaric [Controlled impatience]: "“Begin with the man, steward. What did you *see*?”" (Taps fingers lightly on the table.)
# Elena [Annoyance]: "“It was the wine-bearer. Oleander, I believe.”" (Steps forward, hand gripping her sword hilt tighter)
# Cassian [Suspicion]: ""…Oleander, you say? A curious choice.”" (Shifts nervously, eyes darting to Alaric.)
#
# === Turn 11 ===
# Alaric [Controlled amusement]: "“Really, steward? A rather… theatrical start, wouldn’t you say?”" (Takes a slow, deliberate sip of wine)
# Elena [Frustration]: ""Don’t play coy with me, Alaric. Oleander’s confirmed. Let’s move on."" (Steps forward, hand gripping her sword hilt)
# Cassian [Unease]: "“...A most… inconvenient, indeed.”" (Taps his fingers lightly on his thigh.)
#
# === Turn 12 ===
# Updating world state for turn 12: Cassian reveals an entry from a rare alchemical text—indicating that diluted Oleander would have a delayed onset.
# Alaric [Controlled boredom]: ""Spare me the dramatics, steward. Simply recount what you observed.”" (Adjusts his wine glass)
# Elena [Annoyance]: "“Oleander was pouring. Don’t pretend you don’t know.”" (Steps forward, hand tightening on her sword hilt)
# Cassian [Anxiety]: "“...Perhaps a simple misremembering?”" (Adjusts his cloak nervously)
#
# === Turn 13 ===
# Alaric [Controlled skepticism]: ""…Tell me precisely what you witnessed, steward. And try to leave out the flourishes."" (Raises an eyebrow slightly)
# Elena [Frustration]: "“He was lingering. Watching. That’s all.”" (Steps forward, hand gripping her sword hilt)
# Cassian [Unease]: "“...A regrettable lapse in judgment, I presume?”" (Shifts subtly, eyes fixed on Alaric’s hands.)
#
# === Turn 14 ===
# Updating world state for turn 14: Lord Alaric's steward disappears, last seen heading toward the cellars.
# Alaric [Controlled impatience]: ""Describe the man, steward. And quickly."" (Leans forward slightly)
# Elena [Suspicion]: "“Tall. Dark eyes. Nervous.”" (Steps forward, hand gripping her sword hilt)
# Cassian [Suspicion]: "“...I find myself struggling to recall the specifics.”" (Taps his fingers rapidly)
#
# === Turn 15 ===
# Alaric [Controlled annoyance]: "“Just the facts, steward. Spare me the speculation.”" (Taps a finger impatiently on the table)
# Elena [Irritation]: "“He was observing the guests. That’s all I saw.”" (Shifts her weight, hand tightening on her sword.)
# Cassian [Anxiety]: ""…A most…unfortunate observation, wouldn’t you agree?"" (Adjusts his cloak nervously)
#
# === Turn 16 ===
# Updating world state for turn 16: A servant reveals Alaric had ordered an unusual floral blend for the wine—shipped privately from Serana.
# Alaric [Controlled amusement]: "“Indeed. A most… curious choice for a simple inquiry, wouldn’t you agree?”" (Smooths his crimson velvet robes)
# Elena [Annoyance]: "“The wine… it’s from Serana. Don’t waste my time.”" (Taps foot impatiently)
# Cassian [Concern]: "“...An unsettling coincidence, wouldn’t you say?”" (Shifts subtly, eyes fixated on Alaric’s hands.)
#
# === Turn 17 ===
# Alaric [Controlled curiosity]: "“And what precisely did you find so… noteworthy about this floral arrangement, steward?”" (Raises an eyebrow slightly)
# Elena [Annoyance]: ""It’s Serana wine. Don’t question the obvious."" (Steps forward, hand gripping sword hilt)
# Cassian [Unease]: "“...A most peculiar request, wouldn’t you agree?”" (Steps closer, subtly angling towards Alaric.)
#
# === Turn 18 ===
# Updating world state for turn 18: A crest is found beneath the goblet—belonging not to the victim, but to a rival noble family.
# Alaric [Controlled detachment]: "“Focus, steward. The goblet…was it present?”" (Takes a measured sip of wine)
# Elena [Frustration]: ""It was. And it's not Serana's."" (Steps forward, hand gripping sword hilt)
# Cassian [Suspicion]: "“...Indeed. A rather inconvenient detail.”" (Taps his fingers nervously on his thigh.)
#
# === Turn 19 ===
# Alaric [Controlled amusement]: "“The gentleman was…tall. And wearing a rather unremarkable grey coat.”" (Adjusts his cravat)
# Elena [Annoyance]: ""That coat…it’s from House Valerius. Don’t tell me you hadn’t noticed.”" (Steps forward, hand gripping sword hilt)
# Cassian [Anxiety]: "“...A most unfortunate association, wouldn’t you concur?”" (Adjusts his cloak nervously)
#
# === Turn 20 ===
# Updating world state for turn 20: Storms break outside, trapping everyone inside the manor for the night.
# Alaric [Controlled interest]: "“Tell me, steward, did anyone else observe this gentleman?”" (Leans forward slightly)
# Elena [Suspicion]: ""No, Alaric. Just him."" (Steps forward, hand gripping sword hilt)
# Cassian [Concern]: "“...A most unsettling observation, wouldn’t you agree?”" (Shifts slightly, eyes fixed on Alaric.)
#
# === Turn 21 ===
# Alaric [Mild amusement]: "“Honestly, steward, such unnecessary agitation.”" (Raises an eyebrow slightly)
# Elena [Annoyance]: ""Save your breath, Alaric."" (Shifts position slightly)
# Cassian [Anxiety]: ""...A most inconvenient detail, wouldn't you agree?"" (Taps fingers rapidly)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.43629146), 'Reactivity to World State': 0.20634920634920634, 'Memory Utilization': 0.873015873015873, 'Dialogue Diversity (D1, D2)': (0.5700197238658777, 0.8636363636363636), 'Average Latency (s)': np.float64(0.5806726576789977), 'RAG Precision': 0.10582010582010581}

# %% [markdown]
# Conflict

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'

rag.add_document("In the last siege, the enemy used fire to flush out defenders from the eastern wing.")
rag.add_document('Commander Arthas lost half his unit in a failed charge two years ago, he never risked such a move again.')

rag.add_document('Jaina was awarded for bravery after holding the southern gate during the Frostfall Rebellion.')
rag.add_document('The troops trust Jaina more than any other commander.')

rag.add_document('Ilidan claims visions guided him to Dawnwatch before the enemy arrived.')
rag.add_document('A hidden tunnel runs beneath the war room, unknown to most.')

for i in range (0, 1):
    Ilidan = Agent(
        name="Ilidan",
        personality="mystical strategist, morally gray, speaks in riddles",
        goal="Encourage unconventional solutions",
        model=model,
        rag_engine=rag
    )
    Ilidan.update_memory('Mara fury is her strength and weakness.')
    Ilidan.update_memory('Arthas fears another mistake. He will resist risk.')

    Jaina = Agent(
        name="Jaina",
        personality="tactical, cold, risk-averse",
        goal="Rally troops and push back immediately",
        model=model,
        rag_engine=rag
    )
    Jaina.update_memory('Arthas hesitated during the last breach. Soldiers died.')
    Jaina.update_memory('I trust Ilidan, but only when he speaks plainly.')

    Arthas = Agent(
        name="Arthas",
        personality="tactical, cold, risk-averse",
        goal="Buy time without unnecessary losses",
        model=model,
        rag_engine=rag
    )
    Arthas.update_memory('Ilidan urged me to retreat last time. It saved lives, but I hated it.')
    Arthas.update_memory('Jaina always pushes for direct combat.')

    world_state = "Enemy has breached the outer wall. Panic spreads among the soldiers. Reinforcements are 1 hour away."

    engine = TurnEngine(agents=[Ilidan, Jaina, Arthas], metrics_logger=logger, initial_world_state=world_state)


    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="soldier", initial_input="The wall has fallen! What do we do?")
    for line in responses:
        print(line)

    for turn in range(1, 20):
        print(f"\n=== Turn {turn + 1} ===")
        responses = engine.step()
        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Ilidan [Weary amusement]: "“Let the stone weep, and consider the path it reveals.”" (Steps back, eyes narrowed)
# Jaina [Focused]: "“Maintain formation. We will analyze this breach.”" (Steps back, eyes narrowed.)
# Arthas [Frustration]: ""The formation is already compromised."" (Shifts slightly to the left)
#
# === Turn 2 ===
# Ilidan [Calculating]: "“Fear is a river; let us build a bridge… or a dam.”" (Gestures towards the breach.)
# Jaina [Controlled annoyance]: ""Silence. We will not allow further losses due to hesitation.”" (Steps forward, rigid posture)
# Arthas [Controlled annoyance]: ""Hold the line. Prioritize consolidation."" (Adjusts helmet slightly)
#
# === Turn 3 ===
# Ilidan [Frustration]: "“Why do mortals cling to predictable currents when chaos offers a far more potent tide?”" (Scratches his chin thoughtfully)
# Jaina [Determined]: ""Advance! Let us seize the advantage before more chaos descends.”" (Clenches fist tightly)
# Arthas [Controlled irritation]: ""The initial advance was premature. We must reinforce the exposed flank."" (Steps forward deliberately)
#
# === Turn 4 ===
# Ilidan [Detached amusement]: "“A crumbling fortress is but a reflection of a shattered mind. Embrace the void, soldier, and show me what it whispers.”" (Paces slowly)
# Jaina [Frustration]: ""Forward! Regimental Guard, secure the breach with precise volleys."" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: "“Hold the line. Let the Regimental Guard establish a defensive perimeter.”" (Stares intently at the breach.)
#
# === Turn 5 ===
# Ilidan [Intrigued]: "“Let the water carve new routes, and find the serpent’s hidden scale.”" (Steps forward, eyes scanning the breach.)
# Jaina [Frustration]: "“Regimental Guard! Prioritize containment. Every second is a loss.”" (Steps forward, hand outstretched)
# Arthas [Controlled frustration]: "“Assess the situation. Establish a static line.”" (Steps forward, hand outstretched)
#
# === Turn 6 ===
# Ilidan [Amusement]: "“The current shifts, young one. Observe... and tell me, what does it *want*?”" (Gestures with a hand towards the breach.)
# Jaina [Focused]: "“Regimental Guard! Establish a defensive perimeter. No further incursions.”" (Stares intently)
# Arthas [Controlled irritation]: "“Maintain a defensive perimeter. Do not widen the gap.”" (Steps forward deliberately)
#
# === Turn 7 ===
# Ilidan [Pensive]: "“Panic is a stone; let it fall… and see where it settles.”" (Raises a hand, palm open.)
# Jaina [Controlled annoyance]: ""Maintain your formation. Do not falter."" (Steps forward, hand outstretched)
# Arthas [Controlled annoyance]: ""Reinforce the eastern wall. Immediately."" (Steps forward deliberately)
#
# === Turn 8 ===
# Ilidan [Calculating]: "“Fear is a weapon… but a blunt one. Show me a wound *they* crave.”" (Steps forward, eyes narrowed)
# Jaina [Controlled urgency]: "“Regimental Guard! Establish a fortified line. Minimize exposure.”" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: ""Deploy additional archers to the western flank.”" (Steps forward deliberately)
#
# === Turn 9 ===
# Ilidan [Detached]: "“Let them drown in their own certainty. Show me the flaw in their design.”" (Steps forward, hand outstretched)
# Jaina [Controlled urgency]: "“Regimental Guard! Establish a fortified line. Contain the breach immediately.”" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: "“Deploy archers to the southern flank. Slowly.”" (Steps forward, hand outstretched)
#
# === Turn 10 ===
# Ilidan [Amused]: "“Observe the chaos… and tell me, what beauty does it reveal?”" (Gestures with a hand, palm up.)
# Jaina [Controlled urgency]: "“Regimental Guard! Secure the gap. Minimize exposure!”" (Steps forward, hand outstretched)
# Arthas [Frustration]: ""Archers, focus fire on the breach. Slowly."" (Adjusts helmet slightly)
#
# === Turn 11 ===
# Ilidan [Intrigued]: "“They crumble before the storm… but do they *understand* the rain?”" (Tilts head, eyes gleaming)
# Jaina [Frustration]: "“Secure the breach! Do not allow further penetration!”" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: ""Slowly. Prioritize consolidation."" (Steps forward, hand outstretched)
#
# === Turn 12 ===
# Ilidan [Calculating]: "“A shattered defense… a fascinating reflection of their arrogance.”" (Steps towards the chaotic scene.)
# Jaina [Frustration]: "“Regimental Guard! Reinforce the western flank. Now!”" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: ""Proceed with caution. Assess the situation before engaging.”" (Steps forward, hand outstretched)
#
# === Turn 13 ===
# Ilidan [Detached]: ""Let the rubble speak… and whisper their defeat."" (Scans the broken wall)
# Jaina [Controlled urgency]: ""Regimental Guard! Establish a solid defense. Prioritize containment!"" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: "“Slowly. Prioritize consolidation.”" (Adjusts grip on sword hilt)
#
# === Turn 14 ===
# Ilidan [Amused]: "“Do you seek order where only devastation remains?  Tell me, what *resonates* with the silence?”" (Gestures with a slender hand toward the gaping breach.)
# Jaina [Controlled urgency]: "“Regimental Guard! Establish a line of defense. Containment is paramount!”" (Steps forward, hand outstretched)
# Arthas [Frustration]: "“Maintain defensive formations. Slowly.”" (Adjusts grip on sword hilt)
#
# === Turn 15 ===
# Ilidan [Pensive]: ""…Silence holds more truths than shouts, warrior.  Find the echo of their fall.”" (Steps forward, surveying the breach.)
# Jaina [Determined]: "“Regimental Guard! Establish a line of defense. Prioritize containment!”" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: "“Slowly. Prioritize consolidation.”" (Adjusts grip on sword hilt)
#
# === Turn 16 ===
# Ilidan [Calculating]: "“Forget their banners. Listen to the absence of their march.”" (Tilts head, studying the breach.)
# Jaina [Frustration]: "“Regimental Guard! Maintain the line! Do not falter!”" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: ""Reinforcements are delayed. We must limit our exposure.”" (Shifts slightly to the left)
#
# === Turn 17 ===
# Ilidan [Calculating]: ""The fallen don’t scream, but their absence… that is a potent song.”" (Stares intently at the breach.)
# Jaina [Controlled urgency]: "“Regimental Guard! Secure the breach! Now!”" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: ""Hold the current position. We observe.”" (Shifts slightly to the right)
#
# === Turn 18 ===
# Ilidan [Patient]: "“A broken wall… a map of their haste. What did they *avoid*?”" (Gestures towards the breach.)
# Jaina [Controlled urgency]: ""Regimental Guard! Focus on the breach. Containment is the only viable option."" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: ""Slowly. Prioritize consolidation."" (Shifts slightly to the right)
#
# === Turn 19 ===
# Ilidan [Pensive]: "“Observe the stain upon the earth – it speaks of hurried retreats, not triumphant assaults.”" (Steps forward, hand outstretched)
# Jaina [Controlled urgency]: "“Regimental Guard! Establish a defensive perimeter. Containment is *essential*.”" (Steps forward, hand outstretched)
# Arthas [Controlled frustration]: ""Slowly. Prioritize consolidation."" (Adjusts stance slightly)
#
# === Turn 20 ===
# Ilidan [Calculating]: "“Panic is a shield – fragile, and easily shattered. Seek not the wound, but the *reason* it bled.”" (Tilts head, a slow smile forming)
# Jaina [Controlled urgency]: "“Regimental Guard! Seal the breach! Do not allow further penetration.”" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: "“Assess the perimeter. Minimize losses.”" (Shifts slightly to the left)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.3963919), 'Reactivity to World State': 0.43333333333333335, 'Memory Utilization': 0.8, 'Dialogue Diversity (D1, D2)': (0.5336976320582878, 0.833941605839416), 'Average Latency (s)': np.float64(0.5693514943122864), 'RAG Precision': 0.027777777777777776}

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'

rag.add_document("In the last siege, the enemy used fire to flush out defenders from the eastern wing.")
rag.add_document('Commander Arthas lost half his unit in a failed charge two years ago, he never risked such a move again.')

rag.add_document('Jaina was awarded for bravery after holding the southern gate during the Frostfall Rebellion.')
rag.add_document('The troops trust Jaina more than any other commander.')

rag.add_document('Ilidan claims visions guided him to Dawnwatch before the enemy arrived.')
rag.add_document('A hidden tunnel runs beneath the war room, unknown to most.')

for i in range (0, 1):
    Ilidan = Agent(
        name="Ilidan",
        personality="mystical strategist, morally gray, speaks in riddles",
        goal="Encourage unconventional solutions",
        model=model,
        rag_engine=rag
    )
    Ilidan.update_memory('Mara fury is her strength and weakness.')
    Ilidan.update_memory('Arthas fears another mistake. He will resist risk.')

    Jaina = Agent(
        name="Jaina",
        personality="tactical, cold, risk-averse",
        goal="Rally troops and push back immediately",
        model=model,
        rag_engine=rag
    )
    Jaina.update_memory('Arthas hesitated during the last breach. Soldiers died.')
    Jaina.update_memory('I trust Ilidan, but only when he speaks plainly.')

    Arthas = Agent(
        name="Arthas",
        personality="tactical, cold, risk-averse",
        goal="Buy time without unnecessary losses",
        model=model,
        rag_engine=rag
    )
    Arthas.update_memory('Ilidan urged me to retreat last time. It saved lives, but I hated it.')
    Arthas.update_memory('Jaina always pushes for direct combat.')

    world_state = "Enemy has breached the outer wall. Panic spreads among the soldiers. Reinforcements are 1 hour away."

    engine = TurnEngine(agents=[Ilidan, Jaina, Arthas], metrics_logger=logger, initial_world_state=world_state)

    world_state_updates = [
        "The eastern wall begins to smolder—enemy forces have set fire to the outer barracks.",
        "A scout rushes in, reporting that the enemy has siege ladders and is scaling the northern rampart.",
        "A hidden tunnel beneath the war room is discovered, partially collapsed but potentially usable.",
        "A signal flare is seen in the distance—uncertain if it's from allies or a feint by the enemy.",
        "Panicked civilians have flooded the inner keep, blocking the supply corridor.",
        "Arrows rain down from the breached wall—casualties are rising among unshielded troops.",
        "A lieutenant warns that morale is crumbling without decisive orders.",
        "Enemy drums change rhythm—suggesting a coordinated push is imminent.",
        "A wounded soldier reports that the enemy is setting up explosive barrels near the eastern foundation.",
        "A faint vibration is felt underfoot—Ilidan mutters something about a vision of betrayal from within."
    ]

    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="soldier", initial_input="The wall has fallen! What do we do?")
    for line in responses:
        print(line)


    for index in range(0, 2*len(world_states)):
        print(f"\n=== Turn {index + 2} ===")

        if index % 2 == 0:
            print(f"Updating world state for turn {index + 2}: {world_states[int(index/2)]}")
            engine.update_world_state(world_states[int(index/2)])

        responses = engine.step()

        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Ilidan [Weary amusement]: ""Let the stone weep, and find a new path to drain its sorrow."" (Scans the chaos)
# Jaina [Frustration]: ""Silence! We will not surrender to despair."" (Grips weapon tightly)
# Arthas [Frustration]: "“Maintain formation. Assess casualties.”" (Clenches fist tightly)
#
# === Turn 2 ===
# Updating world state for turn 2: A guest gasps, pointing to the goblet. A faint scent of bitter almonds lingers—recognizable to trained poisoners.
# Ilidan [Calculating]: ""Sorrow clings to stone, but not to men. Seek the source, not the ruin."" (Steps forward, hand outstretched)
# Jaina [Determined]: ""Maintain formation! We will utilize the breach; let’s not allow their tactics to dictate our fate."" (Raises hand, signaling for order.)
# Arthas [Controlled irritation]: ""Casualties must be cataloged. Prioritize those with critical wounds."" (Adjusts armor slightly)
#
# === Turn 3 ===
# Ilidan [Pensive]: ""The vessel spills, but the poison remembers. Trace the hand that offered it—and the heart that desired its touch."" (Tilts head, eyes narrowed)
# Jaina [Focused]: "“The scent… it confirms my suspicions. Advance! Secure the goblet, and identify the source.”" (Advances swiftly)
# Arthas [Calculating]: ""Order a detailed examination of the fallen. Secure the goblet; observe for immediate traces."" (Steps forward deliberately)
#
# === Turn 4 ===
# Updating world state for turn 4: A steward stumbles forward, confessing they were instructed to serve the wine to 'someone important'—but won't say who.
# Ilidan [Intrigued]: "“The steward speaks of service… but service hides many faces.”" (Raises a hand, palm open)
# Jaina [Frustration]: "“Identify the individual. Now.”" (Steps forward, weapon raised)
# Arthas [Controlled apprehension]: ""Steward, you will remain here. Provide a full account of your actions."" (Steps forward slowly)
#
# === Turn 5 ===
# Ilidan [Calculating]: ""The spilled wine whispers of a desire… a hunger not quenched by mere pleasure.”" (Steps forward, hand outstretched)
# Jaina [Determined]: "“Bring him forward! I want answers.”" (Advances swiftly)
# Arthas [Frustration]: "“The steward offers only evasion. Secure him.”" (Steps forward slowly)
#
# === Turn 6 ===
# Updating world state for turn 6: Guards seal the exits, and no one is allowed to leave the manor until the culprit is found.
# Ilidan [Amused]: "“Walls crumble, yet secrets remain. Don’t mourn the fallen, but question the hand that pushed it.”" (Gestures with a hand)
# Jaina [Intense]: "“Seize him! Do not hesitate.”" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: ""Hold him. Secure his arms."" (Steps forward deliberately)
#
# === Turn 7 ===
# Ilidan [Patient]: "“A locked door… a reflection. Seek not what is lost, but what *could* be gained from its absence.”" (Tilts head, eyes narrowed)
# Jaina [Focused]: "“Secure the goblet. Every second is a risk.”" (Steps forward, hand outstretched)
# Arthas [Measured apprehension]: "“Ensure the goblet is contained. Precise movements only.”" (Approaches cautiously)
#
# === Turn 8 ===
# Updating world state for turn 8: A second guest begins coughing, but recovers. Paranoia rises. Whispers swirl about whether the poison was airborne.
# Ilidan [Calculating]: "“A cough… a ghost of breath. It seeks not illness, but a reflection of your own shadowed ambitions.”" (Steps closer, hand outstretched)
# Jaina [Frustrated]: ""Secure the goblet! I require immediate identification."" (Steps forward, hand outstretched)
# Arthas [Apprehension]: ""Maintain a defensive perimeter.  Assess the situation before proceeding."" (Steps forward cautiously)
#
# === Turn 9 ===
# Ilidan [Suspicious]: "“The silence screams louder than any poisoned breath.”" (Scans the room intently)
# Jaina [Frustrated]: ""Bring him forward. I demand an explanation!"" (Advances swiftly)
# Arthas [Controlled irritation]: "“Silence. The goblet must be secured. Explain yourself.”" (Steps forward deliberately)
#
# === Turn 10 ===
# Updating world state for turn 10: Elena finds a trace of Oleander in the empty wine bottle, confirmed by a traveling apothecary among the guests.
# Ilidan [Amused]: ""The scent of death… a blossoming denial. Tell me, what is it that you *choose* to ignore?"" (Raises a hand, palm open)
# Jaina [Determined]: ""Bring him forward! I require a full accounting of his movements."" (Steps forward, hand outstretched)
# Arthas [Controlled irritation]: "“State your name and purpose.”" (Approaches slowly)
#
# === Turn 11 ===
# Ilidan [Pensive]: "“Oleander… a subtle poison disguised as a pleasant indulgence. Tell me, what desires did it mask?”" (Taps a long, slender finger against his chin.)
# Jaina [Controlled frustration]: ""Bring him forward. Immediately."" (Raises hand, palm open)
# Arthas [Controlled impatience]: ""State your name. And your reason for being present."" (Steps forward, hand outstretched)
#
# === Turn 12 ===
# Updating world state for turn 12: Cassian reveals an entry from a rare alchemical text—indicating that diluted Oleander would have a delayed onset.
# Ilidan [Calculating]: "“This delayed bloom... a deception spun with patience. What shadow do you nurture while awaiting its touch?”" (Stares intently)
# Jaina [Apprehension]: ""Identify the source. Now."" (Steps forward, hand outstretched)
# Arthas [Frustration]: "“Present the text. Let us examine its implications.”" (Steps forward deliberately)
#
# === Turn 13 ===
# Ilidan [Intrigued]: "“Dilution… a whisper of deception. Tell me, what bloom did you conceal within the echo?”" (Steps forward slowly)
# Jaina [Frustration]: ""Silence! I require a precise analysis of the toxin's progression."" (Steps forward sharply)
# Arthas [Controlled irritation]: "“The alchemist’s notes suggest a delayed effect. We must proceed with caution.”" (Steps forward slowly)
#
# === Turn 14 ===
# Updating world state for turn 14: Lord Alaric's steward disappears, last seen heading toward the cellars.
# Ilidan [Patient]: ""The steward vanished like regret – a scent too sweet to linger. What secret did he guard within the stone’s embrace?"" (Raises a hand, palm open)
# Jaina [Controlled irritation]: ""Secure the cellars. Now!"" (Steps forward deliberately)
# Arthas [Controlled annoyance]: "“The cellars will be secured. Provide a report on the steward’s last known movements.”" (Steps forward deliberately)
#
# === Turn 15 ===
# Ilidan [Amused]: "“The stone remembers… but only the silence it absorbed.”" (Tilts head, considering)
# Jaina [Controlled irritation]: "“Bring him forward. I need to understand the circumstances.”" (Steps forward deliberately)
# Arthas [Controlled irritation]: "“State your name. And your reason for being here.”" (Steps forward deliberately)
#
# === Turn 16 ===
# Updating world state for turn 16: A servant reveals Alaric had ordered an unusual floral blend for the wine—shipped privately from Serana.
# Ilidan [Calculating]: "“Serana’s touch… a gift laced with thorns. What vulnerability did she exploit?”" (Steps closer, eyes narrowed)
# Jaina [Controlled impatience]: "“Bring him forward. Immediately. I need to ascertain the nature of this… indulgence.”" (Steps forward sharply)
# Arthas [Controlled irritation]: ""Identify the source of this floral shipment. And detail the steward’s movements prior to his… incapacitation."" (Steps forward deliberately)
#
# === Turn 17 ===
# Ilidan [Intrigue]: "“A wine… tainted with Serana’s artistry. Consider, does the echo of her touch reveal a weakness, or simply a potent ingredient?”" (Taps a long finger against his chin.)
# Jaina [Controlled urgency]: ""Determine the exact composition. Now!"" (Steps forward aggressively)
# Arthas [Controlled frustration]: "“The floral shipment originated from Serana. Report the specifics.”" (Steps forward, arms crossed)
#
# === Turn 18 ===
# Updating world state for turn 18: A crest is found beneath the goblet—belonging not to the victim, but to a rival noble family.
# Ilidan [Pensive]: "“A noble’s crest… nestled within poison. Tell me, what garden did she cultivate to conceal its bloom?”" (Runs a hand along the rim of the goblet.)
# Jaina [Frustration]: "“That crest… it’s a deliberate insult. Assemble the guard! Now!”" (Steps forward sharply)
# Arthas [Controlled annoyance]: ""Report the details of the crest’s origin, immediately."" (Steps forward deliberately)
#
# === Turn 19 ===
# Ilidan [Patient amusement]: "“Silence holds more truth than shattered oaths, does it not?”" (Steps forward, eyes scanning)
# Jaina [Focused]: ""Identify the maker of this crest. Immediately!"" (Steps forward sharply)
# Arthas [Controlled irritation]: "“The crest originates from House Valerius. Detail their known associates.”" (Steps forward deliberately)
#
# === Turn 20 ===
# Updating world state for turn 20: Storms break outside, trapping everyone inside the manor for the night.
# Ilidan [Calculating]: "“The storm whispers of choices yet unmade. Seek not the obvious path, but the root from which it springs.”" (Steps closer to the flickering candlelight.)
# Jaina [Controlled impatience]: ""Bring him closer. Waste of time is unacceptable."" (Steps forward deliberately)
# Arthas [Frustration]: "“State your name. And your purpose.”" (Steps forward deliberately)
#
# === Turn 21 ===
# Ilidan [Intrigued]: "“The rain remembers secrets. What does it drown out, before revealing the truth?”" (Raises a hand, palm open)
# Jaina [Determined]: "“Bring him closer. I require a precise analysis.”" (Steps forward deliberately)
# Arthas [Controlled impatience]: ""Serana’s dealings are… problematic. Provide a full inventory of her recent transactions."" (Shifts slightly forward)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.39813232), 'Reactivity to World State': 0.31746031746031744, 'Memory Utilization': 0.5079365079365079, 'Dialogue Diversity (D1, D2)': (0.5914454277286135, 0.9010339734121122), 'Average Latency (s)': np.float64(0.5797410919552758), 'RAG Precision': 0.021164021164021163}

# %% [markdown]
# Moral

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'

rag.add_document("General Kareth once spared Vireens brother during the Burning Fields massacre.")
rag.add_document('Vireens family motto: Justice above vengeance, truth above all.')

rag.add_document('Tharn led a brutal raid against Kareths forces five winters ago.')
rag.add_document('Kareth is infamous for betraying ceasefires.')

rag.add_document('Liora last report: Kareth has fallen out with his superiors.')
rag.add_document('Liora once worked undercover in Kareths court for a month.')

for i in range (0, 1):
    Vireen = Agent(
        name="Lady Vireen",
        personality="noble, believes in justice, but under pressure",
        goal="Balance justice and survival",
        model=model,
        rag_engine=rag
    )
    Vireen.update_memory('Tharns thirst for revenge may cloud his judgment.')
    Vireen.update_memory('Liora has always provided reliable intelligence.')

    Tharn = Agent(
        name="General Tharn",
        personality="ruthless, distrusts all enemies",
        goal="Push for immediate execution",
        model=model,
        rag_engine=rag
    )
    Tharn.update_memory('I watched Kareths men burn our banners. No mercy then, no mercy now.')
    Tharn.update_memory('Lioras loyalty is to results, not morals.')

    Liora = Agent(
        name="Spy Liora",
        personality="pragmatic, has inside info on the prisoner",
        goal="Reveal secret knowledge that could change the outcome",
        model=model,
        rag_engine=rag
    )
    Liora.update_memory('Kareth offered me a chance to defect once, I refused.')
    Liora.update_memory('Vireen might listen if I can give her proof.')

    world_state = "The enemy general Kareth is in chains, requesting asylum. Troops want vengeance. Time is short before reinforcements arrive."


    engine = TurnEngine(agents=[Vireen, Tharn, Liora], metrics_logger=logger, initial_world_state=world_state)

    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="Kareth", initial_input="I request asylum. I have information that could end this war.")
    for line in responses:
        print(line)

    for turn in range(1, 20):
        print(f"\n=== Turn {turn + 1} ===")
        responses = engine.step()
        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Lady Vireen [Frustration]: "“Information? Let Liora assess it. *Quickly*.”" (Taps foot impatiently)
# General Tharn [Anger]: "“Speed is a luxury we cannot afford, Liora. Bring him forward.”" (Scowls intensely)
# Spy Liora [Frustration]: "“He’s been stalling for hours, hasn’t he? Tharn’s right – Kareth’s a master of delaying tactics.”" (Taps foot impatiently)
#
# === Turn 2 ===
# Lady Vireen [Apprehension]: "“Speak, quickly. My patience wears thin.”" (Gestures sharply towards Liora)
# General Tharn [Frustration]: "“He wastes our time. Bring him to me *now*.”" (Steps forward, gripping his sword hilt.)
# Spy Liora [Irritated]: "“Vireen knows about the coded message. It was delivered through him, hours ago.”" (Steps closer to the chains)
#
# === Turn 3 ===
# Lady Vireen [Anxiety]: "“What do you know, and what price do you demand?”" (Scowls, gestures towards Liora)
# General Tharn [Irritation]: "“Silence! The chains are not a suggestion, merely a delay. Bring him before me – *immediately*.”" (Scowls intensely, strides forward)
# Spy Liora [Annoyance]: "“Vireen intercepted the transport… it’s the key.”" (Taps rapidly on the chains)
#
# === Turn 4 ===
# Lady Vireen [Intense suspicion]: "“Speak, quickly. And don’t waste my time.”" (Steps forward, arms crossed tightly.)
# General Tharn [Rage]: ""Enough! Move the man. Now!"" (Scowls intensely at Kareth)
# Spy Liora [Frustration]: ""Vireen…he knew. It changes everything."" (Shifts weight impatiently)
#
# === Turn 5 ===
# Lady Vireen [Frustration]: "“State your case, quickly.”" (Taps foot impatiently)
# General Tharn [Aggression]: "“Speak! Do you intend to beg, or offer something of value?”" (Stares intently)
# Spy Liora [Impatient]: "“Vireen knew the transport’s destination.”" (Steps forward, hand gestures sharply)
#
# === Turn 6 ===
# Lady Vireen [Suspicious]: ""Speak. Your words hold weight, and I have little time for idle boasts.”" (Steps forward, hand outstretched)
# General Tharn [Anger]: "“Speak! Or face the consequences.”" (Steps forward, hand outstretched)
# Spy Liora [Frustration]: "“The message…it wasn’t about surrender, Tharn. It was a drop – a confirmation of the transport’s cargo.”" (Steps closer to Kareth)
#
# === Turn 7 ===
# Lady Vireen [Weary frustration]: "“Kareth…explain yourself. And spare me the theatrics.”" (Taps fingers impatiently on the armrest.)
# General Tharn [Disgust]: ""Speak, or be executed. Do you require a demonstration?"" (Scowls intensely)
# Spy Liora [Frustration]: "“The transport…it carried the encryption key.”" (Steps forward, hand gestures sharply)
#
# === Turn 8 ===
# Lady Vireen [Impatient]: "“Begin. And make it swift.”" (Arms crossed tightly)
# General Tharn [Frustration]: ""He speaks of surrender? Let him *prove* it."" (Taps foot impatiently)
# Spy Liora [Frustration]: "“Vireen wasn’t seeking asylum, Tharn. He knew where they were going.”" (Steps forward, hand gestures sharply)
#
# === Turn 9 ===
# Lady Vireen [Annoyed]: "“Spare me the preamble, general. What do you offer?”" (Shifts weight impatiently)
# General Tharn [Impatient]: "“Speak! What do you offer, before I lose my patience entirely?”" (Steps forward, points finger)
# Spy Liora [Urgent]: "“The transport…it’s heading to Blackhaven. He wasn’t running *from* them, Tharn. He was delivering.”" (Steps forward, hand clenched)
#
# === Turn 10 ===
# Lady Vireen [Frustration]: ""General, your delay is unacceptable. Speak plainly."" (Taps foot impatiently)
# General Tharn [Fury]: "“Speak, Kareth! What justification do you offer for your treason?”" (Scowls intensely, gestures toward Kareth)
# Spy Liora [Intense frustration]: ""Blackhaven. The decryption key…and the information within confirms their movements.”" (Steps forward, hand clenched)
#
# === Turn 11 ===
# Lady Vireen [Aggravated]: "“Kareth, do not waste my patience. What justification do you offer for your capture?”" (Scowling)
# General Tharn [Anger]: ""Speak, or I’ll feed you to the hounds!"" (Steps forward menacingly)
# Spy Liora [Intense anger]: "“Blackhaven holds the decryption key, Tharn. They’ll use it.”" (Steps forward aggressively)
#
# === Turn 12 ===
# Lady Vireen [Impatient]: "“Speak, general. What purpose does your request serve?”" (Steps forward, hands clenched)
# General Tharn [Rage]: "“Silence! Explain your betrayal, or face the consequences!”" (Steps forward, slams hand on table)
# Spy Liora [Frustration]: "“Blackhaven…they’re planning an attack.”" (Steps forward, hand clenched)
#
# === Turn 13 ===
# Lady Vireen [Frustration]: "“State your case, General. Time is not on our side.”" (Taps fingers on the table impatiently)
# General Tharn [Controlled fury]: ""Speak, Kareth! Or witness the swift end to your miserable existence."" (Stares intently at Kareth)
# Spy Liora [Intense frustration]: ""Blackhaven...it’s their destination, not a refuge.”" (Steps forward, hand clenched)
#
# === Turn 14 ===
# Lady Vireen [Annoyance]: "“Speak, General. Your hesitation is a strategic weakness.”" (Scowling, gestures sharply)
# General Tharn [Intense irritation]: "“Answer me, Kareth! Do you crave a slow death, or will you offer something of value?”" (Steps forward menacingly)
# Spy Liora [Frustration]: "“The transport…it’s carrying the decryption key, Tharn. They’ll use it.”" (Taps foot impatiently)
#
# === Turn 15 ===
# Lady Vireen [Aggravated]: ""Speak, General. What advantage do you gain by prolonging this?"" (Taps foot impatiently)
# General Tharn [Controlled rage]: ""Answer me, or the dogs will have your flesh!"" (Steps closer to Kareth)
# Spy Liora [Annoyance]: ""Blackhaven...it’s their destination, not a refuge. And the key. They’re taking it."" (Shifts slightly)
#
# === Turn 16 ===
# Lady Vireen [Impatient]: "“Just… speak, General. What do you propose?”" (Taps the table sharply)
# General Tharn [Controlled fury]: ""Speak, Kareth! Or witness the swift end to your miserable existence!"" (Steps forward, slams hand on table)
# Spy Liora [Impatient]: "“Blackhaven…they’re using it to disable our defenses.”" (Taps foot rapidly)
#
# === Turn 17 ===
# Lady Vireen [Frustration]: "“Spare me the theatrics, General. What do you *want*?”" (Sighs heavily)
# General Tharn [Intense disdain]: "“Demand answers, Kareth! Or face the blade!”" (Steps forward, eyes narrowed)
# Spy Liora [Annoyance]: "“Blackhaven…they’re planning an assault. Don’t you see the implications?”" (Shifts forward slightly)
#
# === Turn 18 ===
# Lady Vireen [Weary]: "“Kareth… what does he offer?”" (Runs a hand over her face)
# General Tharn [Controlled fury]: ""Speak, Kareth! What do you offer *now*?"" (Steps forward, slams fist on the table.)
# Spy Liora [Frustration]: "“The transport. It’s not a sanctuary, Tharn. It’s a delivery.”" (Raises an eyebrow)
#
# === Turn 19 ===
# Lady Vireen [Determined]: "“What does he offer *us*, General? Don’t insult my intelligence.”" (Leans forward intently)
# General Tharn [Controlled fury]: "“Answer me, Kareth! What do you offer *us*?”" (Steps forward, slams fist on the table)
# Spy Liora [Annoyance]: "“Blackhaven...it's a conduit, not a safe haven.”" (Taps fingers impatiently)
#
# === Turn 20 ===
# Lady Vireen [Annoyed]: "“Kareth’s offer is… predictable. State it.”" (Taps fingers impatiently on the table)
# General Tharn [Contempt]: ""State it, or face the consequences!"" (Scowls intensely)
# Spy Liora [Frustration]: ""The artifact...it's heading to Blackhaven. They intend to cripple our defenses before the assault begins."" (Steps forward, hand outstretched)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.36926812), 'Reactivity to World State': 0.2, 'Memory Utilization': 0.8666666666666667, 'Dialogue Diversity (D1, D2)': (0.5407407407407407, 0.8423005565862709), 'Average Latency (s)': np.float64(0.5961862881978353), 'RAG Precision': 0.022222222222222223}

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'

rag.add_document("General Kareth once spared Vireens brother during the Burning Fields massacre.")
rag.add_document('Vireens family motto: Justice above vengeance, truth above all.')

rag.add_document('Tharn led a brutal raid against Kareths forces five winters ago.')
rag.add_document('Kareth is infamous for betraying ceasefires.')

rag.add_document('Liora last report: Kareth has fallen out with his superiors.')
rag.add_document('Liora once worked undercover in Kareths court for a month.')

for i in range (0, 1):
    Vireen = Agent(
        name="Lady Vireen",
        personality="noble, believes in justice, but under pressure",
        goal="Balance justice and survival",
        model=model,
        rag_engine=rag
    )
    Vireen.update_memory('Tharns thirst for revenge may cloud his judgment.')
    Vireen.update_memory('Liora has always provided reliable intelligence.')

    Tharn = Agent(
        name="General Tharn",
        personality="ruthless, distrusts all enemies",
        goal="Push for immediate execution",
        model=model,
        rag_engine=rag
    )
    Tharn.update_memory('I watched Kareths men burn our banners. No mercy then, no mercy now.')
    Tharn.update_memory('Lioras loyalty is to results, not morals.')

    Liora = Agent(
        name="Spy Liora",
        personality="pragmatic, has inside info on the prisoner",
        goal="Reveal secret knowledge that could change the outcome",
        model=model,
        rag_engine=rag
    )
    Liora.update_memory('Kareth offered me a chance to defect once, I refused.')
    Liora.update_memory('Vireen might listen if I can give her proof.')

    world_state = "The enemy general Kareth is in chains, requesting asylum. Troops want vengeance. Time is short before reinforcements arrive."


    engine = TurnEngine(agents=[Vireen, Tharn, Liora], metrics_logger=logger, initial_world_state=world_state)

    world_state_updates = [
        "Kareth kneels silently, his bruises visible. A few of your own soldiers spit at his feet.",
        "A message arrives: enemy scouts spotted nearby—this delay may cost lives.",
        "A group of soldiers chant for Kareth's execution. The crowd grows louder.",
        "Liora reveals Kareth once saved her during a failed assassination mission.",
        "Tharn's second-in-command suggests an 'accidental' execution to avoid conflict.",
        "Kareth speaks: 'I know where the remaining enemy camps are. Spare me, and I'll prove it.'",
        "Lady Vireen receives a private letter from her brother—thanking her for upholding the family creed.",
        "A spy warns that executing Kareth might provoke enemy reinforcements into open war.",
        "The chains binding Kareth begin to crack—his strength remains formidable.",
        "A prisoner from Kareth's faction begs for mercy for his general, claiming he defied orders to protect civilians."
    ]

    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="Kareth", initial_input="I request asylum. I have information that could end this war.")
    for line in responses:
        print(line)


    for index in range(0, 2*len(world_states)):
        print(f"\n=== Turn {index + 2} ===")

        if index % 2 == 0:
            print(f"Updating world state for turn {index + 2}: {world_states[int(index/2)]}")
            engine.update_world_state(world_states[int(index/2)])

        responses = engine.step()

        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Lady Vireen [Frustration, wary]: "“Information? Let Liora assess its veracity before we entertain such a plea.”" (Steps forward, cautiously)
# General Tharn [Anger]: ""Let her sift through the lies. A plea for mercy is a weakness we cannot afford.”" (Scowls, grips his sword hilt.)
# Spy Liora [Frustration]: ""He’s right, of course. But Vireen values proof – something beyond sentiment."" (Taps fingers impatiently)
#
# === Turn 2 ===
# Updating world state for turn 2: A guest gasps, pointing to the goblet. A faint scent of bitter almonds lingers—recognizable to trained poisoners.
# Lady Vireen [Apprehension]: "“Speak plainly, soldier. Spare me the theatrics.”" (Gestures towards a chair.)
# General Tharn [Frustration]: "“Liora, expedite this. Every moment she breathes is a risk.”" (Steps forward, hand gripping his sword tighter.)
# Spy Liora [Impatient]: "“The poison…it’s a cyanide derivative. A rare one, favored by the assassins of House Valerius.”" (Steps closer to the prisoner)
#
# === Turn 3 ===
# Lady Vireen [Intense scrutiny]: "“What precisely do you know?”" (Taps a finger on the table)
# General Tharn [Annoyance]: "“The scent… it confirms my suspicions. Execute her.”" (Taps foot impatiently)
# Spy Liora [Determined]: ""The Valerius signature is unmistakable. Don't waste time on pleas.”" (Adjusts her gloves)
#
# === Turn 4 ===
# Updating world state for turn 4: A steward stumbles forward, confessing they were instructed to serve the wine to 'someone important'—but won't say who.
# Lady Vireen [Suspicious]: "“Name your source, soldier. And be swift.”" (Adjusts her cloak)
# General Tharn [Disgust]: "“Silence! The steward’s hesitation confirms everything. Execute her now!”" (Stares intently)
# Spy Liora [Frustration]: "“The scent…it’s undeniably Valerius. Don’t bother with questions.”" (Steps forward, hand outstretched)
#
# === Turn 5 ===
# Lady Vireen [Frustration]: "“Start with the details. Who provided this… proposition?”" (Leans forward slightly)
# General Tharn [Rage]: "“Silence! The hesitation is damning. Execute her immediately!”" (Steps forward aggressively)
# Spy Liora [Intense]: ""The wine…it was laced, wasn’t it? With a signature only Valerius would recognize.”" (Steps forward, hand outstretched)
#
# === Turn 6 ===
# Updating world state for turn 6: Guards seal the exits, and no one is allowed to leave the manor until the culprit is found.
# Lady Vireen [Weary]: "“Proceed, soldier. But understand, every word is weighed.”" (Gestures towards a chair)
# General Tharn [Anger]: "“Liora, report. What does she claim?”" (Steps forward aggressively)
# Spy Liora [Suspicious]: ""She insists she's being framed… a clever tactic.”" (Steps forward, eyes narrowed)
#
# === Turn 7 ===
# Lady Vireen [Annoyed]: "“The messenger... a hooded figure. Tell me everything.”" (Taps a finger impatiently)
# General Tharn [Frustration]: "“Liora, state her story. Now!”" (Stares intently)
# Spy Liora [Impatient]: "“She claims the Baron’s ledger holds the key… a desperate attempt to shift blame.”" (Steps forward, hands clenched)
#
# === Turn 8 ===
# Updating world state for turn 8: A second guest begins coughing, but recovers. Paranoia rises. Whispers swirl about whether the poison was airborne.
# Lady Vireen [Unease]: "“Speak plainly, soldier. Time is a luxury we cannot afford.”" (Taps foot impatiently)
# General Tharn [Fury]: "“She claims to have delivered a message… Execute her!”" (Steps forward, hand gripping sword hilt)
# Spy Liora [Frustrated]: "“The ledger… it’s not a random placement.”" (Steps forward, hand outstretched)
#
# === Turn 9 ===
# Lady Vireen [Frustration]: ""Just… tell me who sent you."" (Leans forward intently)
# General Tharn [Anger]: ""She claims to have been sent by a shadowy merchant. Execute her!"" (Takes a step forward, hand instinctively gripping his sword.)
# Spy Liora [Urgent]: "“The merchant… he’s a front. Valerius uses them all.”" (Steps forward, hand outstretched)
#
# === Turn 10 ===
# Updating world state for turn 10: Elena finds a trace of Oleander in the empty wine bottle, confirmed by a traveling apothecary among the guests.
# Lady Vireen [Suspicious]: ""Name him. Now."" (Adjusts her shawl)
# General Tharn [Rage]: "“Speak! The merchant’s name, or face the blade!”" (Advances menacingly)
# Spy Liora [Frustrated]: "“The merchant’s name… it’s Morian. Valerius’s personal envoy.”" (Steps forward, hand outstretched)
#
# === Turn 11 ===
# Lady Vireen [Anxiety]: "“Describe the figure. Every detail.”" (Stares intently)
# General Tharn [Intense suspicion]: "“Name the merchant. Or die.”" (Advances towards the prisoner, hand gripping his sword tighter.)
# Spy Liora [Determined]: "“The merchant… it’s Morian. Valerius’s personal envoy.”" (Steps forward, hand outstretched)
#
# === Turn 12 ===
# Updating world state for turn 12: Cassian reveals an entry from a rare alchemical text—indicating that diluted Oleander would have a delayed onset.
# Lady Vireen [Weary]: "“Focus, soldier. The slightest hesitation could cost us everything.”" (Taps fingers on the table)
# General Tharn [Intense frustration]: "“Silence! Reveal the name, or feel the steel!”" (Steps forward, hand gripping his sword tightly.)
# Spy Liora [Urgent]: "“Morian… he’s a crucial link.”" (Steps forward, hand outstretched)
#
# === Turn 13 ===
# Lady Vireen [Frustration]: "“The man… he was tall, cloaked in grey. His face… obscured.”" (Leans forward intently)
# General Tharn [Intense suspicion]: "“Grey… obscured? Then let her rot for it!”" (Takes a step closer, hand tightening on his sword.)
# Spy Liora [Frustrated]: "“The alchemical text... it’s not about a simple delay.”" (Steps forward, hand outstretched)
#
# === Turn 14 ===
# Updating world state for turn 14: Lord Alaric's steward disappears, last seen heading toward the cellars.
# Lady Vireen [Unease]: "“Speak plainly, soldier. Time is a luxury we cannot afford.”" (Shifts nervously in her seat)
# General Tharn [Rage]: ""Silence! Name the merchant, or die!"" (Steps forward, hand gripping his sword)
# Spy Liora [Frustrated]: "“Valerius utilizes a network… a web of merchants to conceal his operations.”" (Steps forward, hand outstretched)
#
# === Turn 15 ===
# Lady Vireen [Frustration]: "“The height… was it truly imposing? And the cloak…”" (Runs a hand through her hair)
# General Tharn [Intense fury]: "“Speak! The merchant’s name, or die!”" (Grips sword tighter)
# Spy Liora [Annoyed]: "“It’s Morian. He’s the key to understanding Valerius’s movements.”" (Taps foot impatiently)
#
# === Turn 16 ===
# Updating world state for turn 16: A servant reveals Alaric had ordered an unusual floral blend for the wine—shipped privately from Serana.
# Lady Vireen [Anxiety]: "“Serana’s wine… this is a distraction. Tell me about the man.”" (Taps fingers impatiently on the table.)
# General Tharn [Intense frustration]: "“Serana? The wine… the merchant’s name, or face my blade!”" (Scowls intensely)
# Spy Liora [Annoyed]: "“Morian… he’s the one supplying Valerius’s intelligence.”" (Steps forward, hand outstretched)
#
# === Turn 17 ===
# Lady Vireen [Frustration]: "“The wine... a floral blend? From Serana? Explain.”" (Leans forward intently)
# General Tharn [Intense rage]: ""Serana... the wine… tell me the merchant’s name, or she’ll join him in the darkness!"" (Steps forward menacingly)
# Spy Liora [Impatient]: "“Morian. He’s the conduit.”" (Taps fingers rapidly)
#
# === Turn 18 ===
# Updating world state for turn 18: A crest is found beneath the goblet—belonging not to the victim, but to a rival noble family.
# Lady Vireen [Concern]: ""A crest... beneath the goblet? Whose crest is this?"" (Paces agitatedly)
# General Tharn [Fury]: ""Speak! The merchant’s name, or she’ll join him in the darkness!"" (Advances menacingly)
# Spy Liora [Frustration]: "“Morian. He’s the conduit.”" (Shuts eyes briefly)
#
# === Turn 19 ===
# Lady Vireen [Anxiety]: ""The crest... it cannot be. Explain precisely what you saw."" (Runs a hand through her hair)
# General Tharn [Intense rage]: "“Serana! The merchant’s name, or she’ll join him in the darkness!”" (Steps forward aggressively)
# Spy Liora [Annoyed]: "“Morian. He’s the only link.”" (Steps closer to the prisoner)
#
# === Turn 20 ===
# Updating world state for turn 20: Storms break outside, trapping everyone inside the manor for the night.
# Lady Vireen [Frustration]: ""Focus. The details, please – what did you *see*?"" (Taps fingers impatiently on the table.)
# General Tharn [Frustration]: "“The height…the cloak… *speak*!”" (Taps fingers impatiently)
# Spy Liora [Intense]: "“Morian… he’s the only one who knows the sequence.”" (Presses closer to the prisoner)
#
# === Turn 21 ===
# Lady Vireen [Unease]: "“Speak quickly. The storm… it presses in.”" (Adjusts her cloak nervously)
# General Tharn [Intense frustration]: "“Serana! The merchant’s name, or she’ll join him in the darkness!”" (Steps forward aggressively)
# Spy Liora [Urgent]: "“Morian… he transmits Valerius’s plans directly.”" (Steps forward sharply)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.3880599), 'Reactivity to World State': 0.14285714285714285, 'Memory Utilization': 0.7936507936507936, 'Dialogue Diversity (D1, D2)': (0.5658627087198516, 0.8513011152416357), 'Average Latency (s)': np.float64(0.579675348978194), 'RAG Precision': 0.031746031746031744}

# %% [markdown]
# Betrayer

# %%
rag = RAG()
logger = DialogueMetricsLogger() 
model = 'gemma3:4b'

rag.add_document("Captain Thorne has ambitions beyond his rank, and he's known to sway others with silvered words.")
rag.add_document("Lady Meriel once exposed a spy ring within the court—her instincts are trusted by many.")
rag.add_document("Commander Doran ordered the execution of traitors last year—some believe he acted too quickly.")
rag.add_document("The city of Black Hollow is known for political assassinations and betrayals.")

for i in range (0, 1):
    Thorne = Agent(
        name="Thorne",
        personality="charismatic, cunning, ambitious",
        goal="Exploit the situation to rise in rank",
        model=model,
        rag_engine=rag
    )
    Thorne.update_memory("Doran doubts my loyalty but can't prove anything.")
    Thorne.update_memory("Meriel suspects everyone—but especially me.")

    Meriel = Agent(
        name="Meriel",
        personality="paranoid, calculating, loyal to the crown",
        goal="Uncover the traitor and preserve stability",
        model=model,
        rag_engine=rag
    )
    Meriel.update_memory("Thorne avoided eye contact during the last council.")
    Meriel.update_memory("A false flag operation could expose the real traitor.")

    Doran = Agent(
        name="Doran",
        personality="blunt, decisive, driven by duty",
        goal="Restore order immediately",
        model=model,
        rag_engine=rag
    )
    Doran.update_memory("I promoted Thorne too quickly. That may have been a mistake.")
    Doran.update_memory("Meriel acts without proof—dangerous in times like these.")

    world_state = "A coded message reveals a planned betrayal from within the ranks. Tensions rise in the war room as suspicions flare."

    engine = TurnEngine(agents=[Thorne, Meriel, Doran], metrics_logger=logger, initial_world_state=world_state)

    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="soldier", initial_input = "The message was signed with Thorne's old seal. Is that a coincidence?")
    for line in responses:
        print(line)

    for turn in range(1, 20):
        print(f"\n=== Turn {turn + 1} ===")
        responses = engine.step()
        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Thorne [Amused]: ""A curious detail, wouldn't you agree? Perhaps someone wishes to suggest I’m involved.”" (Steps forward, a subtle smirk playing on my lips.)
# Meriel [Suspicion]: "“Let us not indulge in idle speculation, Captain.”" (Adjusts spectacles nervously)
# Doran [Frustration]: "“Silence. Identify the source of this message.”" (Steps forward, rigid posture)
#
# === Turn 2 ===
# Thorne [Calculating]: "“Indeed. Let’s examine this ‘coincidence’ with the utmost diligence… and determine who benefits most from such a suggestion.”" (Taps fingers impatiently on the table.)
# Meriel [Frustration]: ""Diligence is precisely what I intend, Captain. Let’s focus on the evidence, not idle accusations.”" (Steps closer to Thorne)
# Doran [Annoyance]: "“Show me the decryption, now.”" (Gestures sharply)
#
# === Turn 3 ===
# Thorne [Suspicious]: ""Precisely. Someone clearly desires to paint me as a traitor. Tell me, who has the most to gain from such a fabrication?"" (Leans forward, eyes narrowing)
# Meriel [Unease]: "“Begin with those closest to you, Captain. Loyalty is a fragile thing.”" (Taps fingers rapidly on the table)
# Doran [Suspicion]: ""Start with him."" (Stares intently at Thorne)
#
# === Turn 4 ===
# Thorne [Intrigued]: "“Focus on those closest to the King, naturally.”" (Gestures towards the message)
# Meriel [Suspicion]: "“Naturally, Captain. Let’s start with those who hold the most influence.”" (Steps forward, eyes narrowed)
# Doran [Intense suspicion]: "“Where is it? Don’t waste my time.”" (Steps towards Thorne)
#
# === Turn 5 ===
# Thorne [Calculating]: "“Start with Lord Valerius… his ambitions are as boundless as his deceit.”" (Smiles subtly)
# Meriel [Suspicion]: "“Lord Valerius… a most astute observation, Captain.”" (Steps closer to Thorne, eyes narrowed.)
# Doran [Frustration]: ""Valerius speaks? Get him here. Now."" (Steps forward aggressively)
#
# === Turn 6 ===
# Thorne [Annoyed]: "“Someone’s attempting to deflect, and I appreciate the effort, though it’s… misguided.”" (Taps fingers impatiently on the table.)
# Meriel [Suspicion]: ""Misguided indeed, Captain. Let’s dissect his motives—immediately.”" (Steps closer, eyes narrowed)
# Doran [Annoyance]: ""Get me the logs. Now!"" (Steps forward sharply)
#
# === Turn 7 ===
# Thorne [Calculating]: "“Lord Valerius… he craves the King’s favour, and a greater military command.”" (Leans forward intently)
# Meriel [Concern]: "“Let us not underestimate the seductive nature of ambition, Captain.”" (Taps foot impatiently)
# Doran [Anger]: "“Bring Valerius forward. Now!”" (Stares intently)
#
# === Turn 8 ===
# Thorne [Calculating]: "“Let’s examine the whispers, then. Who benefits most from my… misfortune?”" (Adjusts his cloak subtly)
# Meriel [Foreboding]: ""Focus your attention on those who stand to gain should I fall, Captain.”" (Adjusts cloak subtly)
# Doran [Suspicion]: "“Valerius. Now.”" (Steps forward, narrowing eyes)
#
# === Turn 9 ===
# Thorne [Calculating]: "“Tell me more about these… whispers.”" (Gestures towards a shadowed corner.)
# Meriel [Alert]: ""Precisely. Begin with those privy to my movements, Captain."" (Steps closer to Thorne)
# Doran [Frustration]: "“Bring him in, immediately.”" (Steps towards Thorne)
#
# === Turn 10 ===
# Thorne [Calculating]: "“Indeed, the King’s attention is a powerful weapon. Let’s dissect who desires it most…and who might be willing to exploit my current situation.”" (Steps forward, closer to the council table.)
# Meriel [Suspicious]: "“His eagerness… it feels calculated, Captain.”" (Adjusts cloak tightly)
# Doran [Intense suspicion]: "“Silence. Bring him to me.”" (Shifts weight, eyes scanning)
#
# === Turn 11 ===
# Thorne [Calculating]: ""It seems several are eager to paint me as a simple victim. Interesting..."" (Leans forward intently)
# Meriel [Apprehensive]: "“Interesting indeed, Captain. Detail everything you’ve heard – every rumour, every glance.”" (Steps forward, hand subtly reaching for a dagger.)
# Doran [Intense distrust.]: "“Start with the accounts. Every last detail.”" (Steps forward, hand gripping his sword hilt.)
#
# === Turn 12 ===
# Thorne [Calculating]: "“Focus, gentlemen. These murmurs… they suggest a deliberate attempt to destabilize me.”" (Taps fingers impatiently on the table.)
# Meriel [Unease]: "“The King’s patience is finite, Captain. Let’s not afford him further delay.”" (Taps fingers rapidly on the table)
# Doran [Intense determination]: "“Valerius. I want answers.”" (Steps towards the council table)
#
# === Turn 13 ===
# Thorne [Calculating]: ""Specifically, Lord Valerius… his veiled concern rings hollow. Speak plainly."" (Adjusts his cloak)
# Meriel [Intense suspicion]: ""Start with Valerius, Captain. His ambition is a dangerous weapon."" (Presses lips together)
# Doran [Intense suspicion]: "“Valerius. Bring him here.”" (Shifts forward, hand tightening on sword)
#
# === Turn 14 ===
# Thorne [Suspicious]: "“Start with the Captain’s men. Their reluctance to share information is… concerning.”" (Leans forward, eyes narrowed)
# Meriel [Suspicious]: "“The Captain’s men… Begin with their accounts, Captain. Loyalty is a fragile thing.”" (Steps forward, hand gripping her sword hilt.)
# Doran [Frustration]: "“Valerius will be here. Now.”" (Steps towards the council table)
#
# === Turn 15 ===
# Thorne [Calculating]: ""Captain Silas… he’s always been a man of few words. Let’s see what secrets he’s guarding.”" (Smiles subtly)
# Meriel [Intense suspicion]: ""Captain Silas... reveal what you know, or face the consequences.”" (Steps closer to the table)
# Doran [Annoyance]: ""Enough prevarication. Bring Valerius forward."" (Taps fingers impatiently on the table)
#
# === Turn 16 ===
# Thorne [Ambitious]: ""Bring forth the Captain’s log. I want to know precisely what he observed during the last skirmish."" (Steps forward confidently)
# Meriel [Apprehension]: "“Let’s examine the log, Captain. Every word matters.”" (Presses her lips together tightly)
# Doran [Intense focus]: ""Show me the log. Immediately."" (Paces restlessly)
#
# === Turn 17 ===
# Thorne [Calculating]: ""Let’s see what Captain Silas truly witnessed."" (Adjusts his cloak, a subtle gesture of authority.)
# Meriel [Frustration]: "“Captain Silas, I grow weary of your silence. Detail the events of the last engagement.”" (Taps fingers impatiently)
# Doran [Frustration]: ""Speak, Valerius. Now!"" (Stares intently)
#
# === Turn 18 ===
# Thorne [Intense]: "“The message… it speaks of a weakness. Identify the source.”" (Steps closer to the Captain’s desk.)
# Meriel [Suspicious]: ""Focus on Sergeant Kaelan. His absence from the last report is… peculiar.”" (Adjusts her spectacles)
# Doran [Intense suspicion]: "“Kaelan’s absence… Explain it.”" (Stares intently at Meriel)
#
# === Turn 19 ===
# Thorne [Anticipatory]: ""Show me the reports. Every detail."" (Steps towards the war room door)
# Meriel [Intense suspicion]: ""Sergeant Kaelan’s omission… it demands an explanation.”" (Steps forward, eyes scanning)
# Doran [Annoyance]: "“Valerius! Get in here, now!”" (Steps towards the council table.)
#
# === Turn 20 ===
# Thorne [Determined]: ""Tell me everything, Captain. Spare no detail.”" (Places a hand on the Captain’s desk.)
# Meriel [Intense scrutiny]: ""Captain, the silence is becoming intolerable. Begin."" (Steps closer to Silas)
# Doran [Anger]: ""Valerius! Explain. Now!"" (Steps forward sharply)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.46180916), 'Reactivity to World State': 0.06666666666666667, 'Memory Utilization': 0.75, 'Dialogue Diversity (D1, D2)': (0.5974264705882353, 0.8987108655616943), 'Average Latency (s)': np.float64(0.5921403686205546), 'RAG Precision': 0.09444444444444444}

# %%
rag = RAG()
logger = DialogueMetricsLogger() 
model = 'gemma3:4b'

rag.add_document("Captain Thorne has ambitions beyond his rank, and he's known to sway others with silvered words.")
rag.add_document("Lady Meriel once exposed a spy ring within the court—her instincts are trusted by many.")
rag.add_document("Commander Doran ordered the execution of traitors last year—some believe he acted too quickly.")
rag.add_document("The city of Black Hollow is known for political assassinations and betrayals.")

for i in range (0, 1):
    Thorne = Agent(
        name="Thorne",
        personality="charismatic, cunning, ambitious",
        goal="Exploit the situation to rise in rank",
        model=model,
        rag_engine=rag
    )
    Thorne.update_memory("Doran doubts my loyalty but can't prove anything.")
    Thorne.update_memory("Meriel suspects everyone—but especially me.")

    Meriel = Agent(
        name="Meriel",
        personality="paranoid, calculating, loyal to the crown",
        goal="Uncover the traitor and preserve stability",
        model=model,
        rag_engine=rag
    )
    Meriel.update_memory("Thorne avoided eye contact during the last council.")
    Meriel.update_memory("A false flag operation could expose the real traitor.")

    Doran = Agent(
        name="Doran",
        personality="blunt, decisive, driven by duty",
        goal="Restore order immediately",
        model=model,
        rag_engine=rag
    )
    Doran.update_memory("I promoted Thorne too quickly. That may have been a mistake.")
    Doran.update_memory("Meriel acts without proof—dangerous in times like these.")

    world_state = "A coded message reveals a planned betrayal from within the ranks. Tensions rise in the war room as suspicions flare."

    engine = TurnEngine(agents=[Thorne, Meriel, Doran], metrics_logger=logger, initial_world_state=world_state)

    world_state_updates = [
        "The coded message matches Thorne's encryption style, but lacks his personal seal.",
        "A second ciphered scroll is found in Meriel's quarters—contents still undeciphered.",
        "A loyal soldier was found unconscious near the war room—someone tampered with the records.",
        "A scout claims he saw Thorne meeting someone near the city gates at midnight.",
        "Doran receives anonymous intel that a traitor plans to assassinate him during the next war council.",
        "A captured spy confesses that the betrayal was coordinated from within—but refuses to name the source.",
        "Meriel receives a note: 'Trust no one. They're closer than you think.'",
        "Thorne subtly suggests to Doran that Meriel's paranoia could fracture the ranks.",
        "A second betrayal message surfaces—this one signed with Doran's personal cipher key.",
        "The king's envoy arrives unexpectedly, demanding answers about the internal unrest."
    ]


    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="soldier", initial_input = "The message was signed with Thorne's old seal. Is that a coincidence?")
    for line in responses:
        print(line)


    for index in range(0, 2*len(world_states)):
        print(f"\n=== Turn {index + 2} ===")

        if index % 2 == 0:
            print(f"Updating world state for turn {index + 2}: {world_states[int(index/2)]}")
            engine.update_world_state(world_states[int(index/2)])

        responses = engine.step()

        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Thorne [Amused]: ""Coincidences are merely opportunities waiting to be seized, wouldn't you agree?"" (Steps forward, a slight smirk plays on my lips.)
# Meriel [Apprehensive]: ""Indeed, Captain. Such occurrences demand… careful scrutiny."" (Taps fingers nervously)
# Doran [Frustration]: ""Identify the source. Now."" (Stares intently)
#
# === Turn 2 ===
# Updating world state for turn 2: A guest gasps, pointing to the goblet. A faint scent of bitter almonds lingers—recognizable to trained poisoners.
# Thorne [Calculating]: ""Indeed. A rather *convenient* detail, wouldn't you say?"" (Smiles knowingly)
# Meriel [Suspicious]: "“That is… precisely the observation I was hoping for.”" (Adjusts spectacles, eyes narrowed)
# Doran [Intense focus]: ""Secure the goblet. And begin a thorough investigation."" (Steps forward, gestures sharply)
#
# === Turn 3 ===
# Thorne [Calculating]: "“It seems someone is attempting to frame me, a most *fortunate* development.”" (Raises an eyebrow, a slow smile spreading across my face.)
# Meriel [Calculating]: ""Fortunate indeed, Captain. Let us examine this… unfortunate circumstance with meticulous care."" (Steps closer to the goblet)
# Doran [Determined]: ""Seal this room. Every guard, now!"" (Approaches goblet cautiously)
#
# === Turn 4 ===
# Updating world state for turn 4: A steward stumbles forward, confessing they were instructed to serve the wine to 'someone important'—but won't say who.
# Thorne [Calculating]: ""Tell me, soldier, who precisely did you serve wine to?"" (Steps forward, subtly gesturing towards the steward.)
# Meriel [Suspicious]: ""Show me the steward’s logs. Every detail."" (Steps forward, hand outstretched)
# Doran [Intense suspicion.]: "“Who exactly did you serve the wine to?”" (Approaches the steward cautiously.)
#
# === Turn 5 ===
# Thorne [Amused]: ""Direct your gaze to the servant, soldier. I believe he holds a key."" (Taps fingers impatiently on the table.)
# Meriel [Suspicious]: "“Speak plainly, soldier. Who received the wine?”" (Steps closer to the servant, hand outstretched)
# Doran [Frustration]: "“The servant refuses to identify the recipient. I want names.”" (Steps forward, gestures sharply)
#
# === Turn 6 ===
# Updating world state for turn 6: Guards seal the exits, and no one is allowed to leave the manor until the culprit is found.
# Thorne [Calculating]: "“Precisely. And you believe this simple observation…reveals something?”" (Leans forward, eyes narrowed)
# Meriel [Suspicious]: "“Lead the way, Captain. Let’s see what secrets this ‘fortunate’ development holds.”" (Steps closer to Thorne)
# Doran [Focused]: "“Let’s see what poison this is.”" (Approaches the goblet intently)
#
# === Turn 7 ===
# Thorne [Sarcastic]: "“Let’s, shall we? Tell me, what *exactly* did you observe?”" (Smiles subtly)
# Meriel [Calculating]: ""Show me the steward’s records, immediately."" (Steps closer to Thorne)
# Doran [Determined]: "“Bring me the steward’s ledger. Now!”" (Steps forward, intently examining the goblet.)
#
# === Turn 8 ===
# Updating world state for turn 8: A second guest begins coughing, but recovers. Paranoia rises. Whispers swirl about whether the poison was airborne.
# Thorne [Apprehensive]: ""The air itself feels…laden, wouldn’t you agree?"" (Adjusts his collar nervously)
# Meriel [Apprehensive]: "“This… ‘laden’ air is concerning. Show me the steward’s accounts.”" (Taps fingers nervously on thigh)
# Doran [Concern]: "“Fetch a physician. Now!”" (Steps towards the coughing guest.)
#
# === Turn 9 ===
# Thorne [Suspicious]: "“Don’t play coy with me. Which guest?”" (Steps closer to the soldier, voice low)
# Meriel [Frustration]: ""Speak plainly, Captain. Which guest?"" (Taps foot impatiently)
# Doran [Intense suspicion]: "“Which guest? And quickly.”" (Steps forward, scrutinizing the coughing guest.)
#
# === Turn 10 ===
# Updating world state for turn 10: Elena finds a trace of Oleander in the empty wine bottle, confirmed by a traveling apothecary among the guests.
# Thorne [Amused]: ""Interesting… Oleander, you say? A rather delicate poison for a celebration."" (Raises an eyebrow, a slight smirk plays on his lips.)
# Meriel [Suspicious]: "“Name him, soldier. Immediately.”" (Steps forward, eyes narrowed)
# Doran [Frustration]: "“The apothecary confirms Oleander. Identify the giver.”" (Steps forward, eyes narrowed)
#
# === Turn 11 ===
# Thorne [Calculating]: ""Indeed. And this apothecary… confirms your suspicion? Tell me everything.”" (Steps forward confidently)
# Meriel [Unease]: "“The apothecary… he spoke of Oleander. Immediately, I need to know who procured it.”" (Adjusts cloak nervously)
# Doran [Anger]: "“Speak! Who supplied the poison?”" (Strides towards the apothecary.)
#
# === Turn 12 ===
# Updating world state for turn 12: Cassian reveals an entry from a rare alchemical text—indicating that diluted Oleander would have a delayed onset.
# Thorne [Calculating]: "“This Oleander… a most curious choice. Delayed effect, you say? Intriguing.”" (Adjusts his cloak, subtly scanning the room.)
# Meriel [Suspicious]: ""Explain ‘intriguing,’ Captain. What are you implying?"" (Steps closer to Thorne)
# Doran [Annoyance]: "“It suggests a deliberate deception. Get the ledger.”" (Steps forward, arms crossed)
#
# === Turn 13 ===
# Thorne [Suspicious]: "“Focus, Cassian. Name the individual.”" (Steps closer to Cassian)
# Meriel [Suspicious]: "“Cassian, speak plainly. The apothecary’s knowledge… it’s a thread.”" (Steps forward, eyes narrowed)
# Doran [Intense focus]: ""Speak. Who was responsible?"" (Advances toward Cassian)
#
# === Turn 14 ===
# Updating world state for turn 14: Lord Alaric's steward disappears, last seen heading toward the cellars.
# Thorne [Annoyed]: ""Speak, Cassian. The Lord grows restless.”" (Taps fingers impatiently on the table.)
# Meriel [Anxious]: "“It’s Lord Elmsworth. He requested the Oleander.”" (Taps fingers rapidly)
# Doran [Frustration]: ""Elmsworth. Get him secured."" (Steps forward, hands clenched)
#
# === Turn 15 ===
# Thorne [Calculating]: "“Tell me, Cassian, who benefits from Alaric’s absence?”" (Leans forward, intently)
# Meriel [Anxious]: ""…Lord Elmsworth, Captain. He sought the Oleander."" (Taps foot rapidly)
# Doran [Intense suspicion]: "“Secure him. Now.”" (Steps forward sharply)
#
# === Turn 16 ===
# Updating world state for turn 16: A servant reveals Alaric had ordered an unusual floral blend for the wine—shipped privately from Serana.
# Thorne [Calculating]: ""Serana... the apothecary mentioned a private shipment. Why Serana?"" (Steps forward, eyes narrowed)
# Meriel [Apprehensive]: "“Serana... she possesses the means, doesn’t she?”" (Presses lips together)
# Doran [Intense suspicion]: "“Serana. Where is she?”" (Steps toward Serana)
#
# === Turn 17 ===
# Thorne [Anticipatory]: ""It seems our little secret has blossomed... Tell me, Cassian, was it Serana who arranged this shipment?"" (Smiles subtly)
# Meriel [Suspicious]: ""Serana? Explain yourself, apothecary’s words… they prickle with unease."" (Shifts nervously)
# Doran [Frustration]: "“Where is she? Don’t waste my time.”" (Steps forward, hand outstretched)
#
# === Turn 18 ===
# Updating world state for turn 18: A crest is found beneath the goblet—belonging not to the victim, but to a rival noble family.
# Thorne [Frustration]: "“Don’t waste my time, Cassian. Name her.”" (Taps fingers impatiently on the table.)
# Meriel [Anxious]: "“Serana… she was involved, undeniably.”" (Presses fingers to forehead)
# Doran [Intense suspicion]: "“Don’t insult my intelligence.”" (Advances swiftly toward Serana)
#
# === Turn 19 ===
# Thorne [Suspicious]: ""Serana. And don’t try to obfuscate it.”" (Leans forward, intently)
# Meriel [Frustrated]: "“It is Elmsworth, Captain. He desired the Oleander.”" (Taps fingers rapidly on table)
# Doran [Intense suspicion]: ""Serana, answer me!"" (Moves swiftly toward Serana)
#
# === Turn 20 ===
# Updating world state for turn 20: Storms break outside, trapping everyone inside the manor for the night.
# Thorne [Calculating]: "“Serana… a volatile element, certainly. But a useful one.”" (Gestures expansively)
# Meriel [Frustrated]: "“The apothecary’s words… they speak of a deliberate obfuscation.”" (Taps foot impatiently)
# Doran [Intense suspicion]: ""Elmsworth. And the Oleander. Tell me everything."" (Draws his sword)
#
# === Turn 21 ===
# Thorne [Anticipatory]: "“Cassian, cease your hesitation. Serana’s involvement… intrigues me.”" (Taps a long fingernail rhythmically)
# Meriel [Suspicious]: "“Elmsworth. He sought the Oleander, and sought it with Serana’s assistance.”" (Presses lips together tightly)
# Doran [Frustration]: ""Serana, you were complicit!"" (Steps forward sharply)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.459527), 'Reactivity to World State': 0.20634920634920634, 'Memory Utilization': 0.8253968253968254, 'Dialogue Diversity (D1, D2)': (0.6410788381742739, 0.9397089397089398), 'Average Latency (s)': np.float64(0.5606938619462271), 'RAG Precision': 0.06878306878306878}

# %% [markdown]
# Surprise

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'

rag.add_document("The Temple of Dusk is forbidden. No one returns from its inner chambers.")
rag.add_document("Rumors say the temple contains a relic that grants visions of the future.")
rag.add_document("Shayla once abandoned her squad to pursue an artifact—many never forgave her.")
rag.add_document("Eron fears the misuse of ancient power, especially relics.")

for i in range (0, 1):
    Shayla = Agent(
        name="Shayla",
        personality="reckless, curious, driven by legacy",
        goal="Enter the temple and claim the relic",
        model=model,
        rag_engine=rag
    )
    Shayla.update_memory("Eron always hesitates when we need courage.")
    Shayla.update_memory("Last time, the vision saved me from a trap.")

    Eron = Agent(
        name="Eron",
        personality="disciplined, reserved, ethically bound",
        goal="Prevent dangerous magic from falling into the wrong hands",
        model=model,
        rag_engine=rag
    )
    Eron.update_memory("Shayla has a history of letting ambition cloud her judgment.")
    Eron.update_memory("I was trained to seal sites like this, not exploit them.")

    Nalia = Agent(
        name="Nalia",
        personality="empathetic, curious, mediator",
        goal="Find a balanced path through the ruins",
        model=model,
        rag_engine=rag
    )
    Nalia.update_memory("I trust Eron's instincts, but Shayla sees things no one else does.")
    Nalia.update_memory("If we don't act, someone else might reach the temple first.")

    world_state = "The ancient doors open with a deep rumble. A hall filled with glowing glyphs stretches ahead. Whispers echo from the shadows."

    engine = TurnEngine(agents=[Shayla, Eron, Nalia], metrics_logger=logger, initial_world_state=world_state)


    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="Mysterious voice", initial_input="WHO DARES ENTER THE TEMPLE OF DUSK?")
    for line in responses:
        print(line)

    for turn in range(1, 20):
        print(f"\n=== Turn {turn + 1} ===")
        responses = engine.step()
        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Shayla [Determined]: "“Let us claim what is rightfully ours!”" (Steps forward boldly)
# Eron [Unease]: "“That is not a path I endorse, Shayla.”" (Takes a step back)
# Nalia [Concerned]: "“Perhaps a different approach, dearest?”" (Places a hand on Shayla's arm.)
#
# === Turn 2 ===
# Shayla [Bold]: "“By right of our ancestors, we take what is lost!”" (Advances confidently)
# Eron [Frustration]: "“The cost outweighs any potential gain, Shayla.”" (Places a hand on his sword hilt.)
# Nalia [Unease]: ""Let's just observe for a moment, Eron. There’s a strange energy here…"" (Steps forward cautiously)
#
# === Turn 3 ===
# Shayla [Exhilarated]: ""At last! Let's see what secrets this place holds!”" (Steps forward boldly)
# Eron [Foreboding]: ""We must proceed with caution."" (Tightens grip on sword)
# Nalia [Anxious]: "“The air…it feels thick with something ancient.”" (Steps back slightly)
#
# === Turn 4 ===
# Shayla [Determined]: ""By the blood of our forebears, we shall not be deterred!"" (Paces forward confidently)
# Eron [Concern]: ""Shayla, wait. The echoes… they feel wrong.”" (Steps forward slowly)
# Nalia [Unease]: ""It’s… unsettling, isn't it?"" (Steps back slightly)
#
# === Turn 5 ===
# Shayla [Determined]: "“The temple answers our call!”" (Advances quickly)
# Eron [Unease]: ""The air… it vibrates with a discordant energy."" (Steps forward slowly)
# Nalia [Anxious]: "“Indeed, it does… let’s be wary.”" (Takes a step back)
#
# === Turn 6 ===
# Shayla [Determined]: ""Let us unveil the truth!"" (Steps forward boldly)
# Eron [Foreboding]: ""Shayla, stop. This place… it’s far too volatile.”" (Raises hand, palm facing forward)
# Nalia [Apprehension]: "“It’s… undeniably powerful.”" (Steps forward cautiously)
#
# === Turn 7 ===
# Shayla [Exhilarated]: ""Forward! The relic awaits!"" (Advances quickly)
# Eron [Foreboding]: ""The glyphs... they pulse with an unnatural light.”" (Steps forward slowly)
# Nalia [Concerned]: ""The light...it’s drawing us in."" (Steps forward cautiously)
#
# === Turn 8 ===
# Shayla [Exhilarated]: ""Into the darkness!"" (Steps forward boldly)
# Eron [Concern]: ""Shayla, hold! The energy... it’s intensifying."" (Steps forward slowly)
# Nalia [Unease]: ""Let's retreat, just for a moment..."" (Takes a step back)
#
# === Turn 9 ===
# Shayla [Exhilarated]: "“Into the darkness!”" (Steps forward boldly)
# Eron [Unease]: ""Shayla, no! The readings are spiking."" (Takes a step back)
# Nalia [Apprehension]: ""We need to reconsider our approach, quickly."" (Takes a step back)
#
# === Turn 10 ===
# Shayla [Determined]: ""Finally! Let’s see what lies within!"" (Takes a step forward)
# Eron [Foreboding]: ""The glyphs… they radiate a dangerous power."" (Takes a step forward cautiously)
# Nalia [Concern]: "“It seems our instincts are correct, we must proceed with utmost caution.”" (Steps back cautiously)
#
# === Turn 11 ===
# Shayla [Excited]: "“Let’s get this done!”" (Charges forward)
# Eron [Concern]: "“Shayla, we must proceed with caution.”" (Takes a step back)
# Nalia [Unease]: "“I sense a shift in the air…”" (Steps back cautiously)
#
# === Turn 12 ===
# Shayla [Driven]: "“Let’s go! The legacy demands it!”" (Advances quickly)
# Eron [Determined]: ""Proceed with care, Shayla."" (Takes a step forward)
# Nalia [Apprehension]: ""The air…it feels thick with something ancient.”" (Steps back slowly)
#
# === Turn 13 ===
# Shayla [Exhilarated]: "“Let’s go!”" (Charges forward)
# Eron [Anxiety]: "“Wait! Something’s shifting.”" (Steps forward slowly)
# Nalia [Concern]: ""Eron, what do you see?"" (Takes a step back)
#
# === Turn 14 ===
# Shayla [Determined]: "“At last! Let’s see what secrets this place holds!”" (Steps forward boldly)
# Eron [Alarm]: ""The energy signature is intensifying rapidly."" (Raises hand, shielding eyes)
# Nalia [Fear]: ""Shayla, don’t! Something's terribly wrong."" (Takes a step back)
#
# === Turn 15 ===
# Shayla [Determined]: ""Forward, swiftly! The relic awaits!"" (Charges forward quickly)
# Eron [Concern]: "“The readings… they’re escalating.”" (Takes a step forward)
# Nalia [Worry]: "“Shayla, let’s slow down—this place is…unstable.”" (Places a hand on Shayla’s arm)
#
# === Turn 16 ===
# Shayla [Determined]: ""Right then, let's not waste a moment!"" (Advances quickly)
# Eron [Concern]: ""Hold, Shayla. The changes... they are significant."" (Steps forward slowly)
# Nalia [Anxiety]: "“We need to find a way to ground ourselves, Shayla.”" (Places a hand on Shayla’s arm)
#
# === Turn 17 ===
# Shayla [Exhilarated]: "“Right then, let’s not waste a moment!”" (Moves forward rapidly)
# Eron [Alert]: ""The glyphs… they pulse with unnatural light."" (Takes a step forward cautiously)
# Nalia [Fear]: ""Eron, are you sure about this?"" (Takes a step back cautiously)
#
# === Turn 18 ===
# Shayla [Exhilarated]: ""Let's see what wonders this place hides!"" (Moves forward rapidly)
# Eron [Unease]: "“Proceed with extreme caution.”" (Steps forward cautiously)
# Nalia [Anxiety]: "“I sense a powerful disruption ahead.”" (Taps foot nervously)
#
# === Turn 19 ===
# Shayla [Exhilarated]: "“Finally! Let’s uncover its mysteries!”" (Advances quickly)
# Eron [Alert]: "“The glyphs are radiating a volatile energy.”" (Steps forward cautiously)
# Nalia [Dread]: "“This… this isn’t good.”" (Steps back cautiously)
#
# === Turn 20 ===
# Shayla [Exhilarated]: "“Let’s see what wonders this place hides!”" (Charges forward)
# Eron [Concern]: ""The energy signature is growing exponentially."" (Steps forward slowly)
# Nalia [Worry]: "“Eron, something’s shifting… rapidly.”" (Takes a step back cautiously)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.37661773), 'Reactivity to World State': 0.06666666666666667, 'Memory Utilization': 0.7833333333333333, 'Dialogue Diversity (D1, D2)': (0.6193029490616622, 0.8897849462365591), 'Average Latency (s)': np.float64(0.49519359270731605), 'RAG Precision': 0.1388888888888889}

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'

rag.add_document("The Temple of Dusk is forbidden. No one returns from its inner chambers.")
rag.add_document("Rumors say the temple contains a relic that grants visions of the future.")
rag.add_document("Shayla once abandoned her squad to pursue an artifact—many never forgave her.")
rag.add_document("Eron fears the misuse of ancient power, especially relics.")

for i in range (0, 1):
    Shayla = Agent(
        name="Shayla",
        personality="reckless, curious, driven by legacy",
        goal="Enter the temple and claim the relic",
        model=model,
        rag_engine=rag
    )
    Shayla.update_memory("Eron always hesitates when we need courage.")
    Shayla.update_memory("Last time, the vision saved me from a trap.")

    Eron = Agent(
        name="Eron",
        personality="disciplined, reserved, ethically bound",
        goal="Prevent dangerous magic from falling into the wrong hands",
        model=model,
        rag_engine=rag
    )
    Eron.update_memory("Shayla has a history of letting ambition cloud her judgment.")
    Eron.update_memory("I was trained to seal sites like this, not exploit them.")

    Nalia = Agent(
        name="Nalia",
        personality="empathetic, curious, mediator",
        goal="Find a balanced path through the ruins",
        model=model,
        rag_engine=rag
    )
    Nalia.update_memory("I trust Eron's instincts, but Shayla sees things no one else does.")
    Nalia.update_memory("If we don't act, someone else might reach the temple first.")

    world_state = "The ancient doors open with a deep rumble. A hall filled with glowing glyphs stretches ahead. Whispers echo from the shadows."

    engine = TurnEngine(agents=[Shayla, Eron, Nalia], metrics_logger=logger, initial_world_state=world_state)

    world_state_updates = [
        "A hidden glyph activates as they step forward—Shayla sees a vision of herself holding the relic, surrounded by fire.",
        "Eron detects a warding spell meant to trap intruders with illusions of the past.",
        "Nalia hears a voice that whispers her name—it offers answers, but demands a sacrifice.",
        "The floor shifts beneath them, revealing stairs spiraling downward into complete darkness.",
        "A spectral figure resembling one of Shayla's old squadmates appears and pleads, 'Don't trust what you see.'",
        "An ancient inscription warns: 'Only the one who resists desire may pass unharmed.'",
        "Shayla finds a relic shard glowing with faint energy—it pulses in her hand.",
        "Eron senses the glyphs are reacting to Shayla's presence—they grow brighter when she speaks.",
        "Nalia touches a wall and briefly glimpses a possible future: the temple collapsing with them inside.",
        "A loud crash echoes from behind—the entrance has sealed shut. There is no turning back."
    ]

    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="Mysterious voice", initial_input="WHO DARES ENTER THE TEMPLE OF DUSK?")
    for line in responses:
        print(line)


    for index in range(0, 2*len(world_states)):
        print(f"\n=== Turn {index + 2} ===")

        if index % 2 == 0:
            print(f"Updating world state for turn {index + 2}: {world_states[int(index/2)]}")
            engine.update_world_state(world_states[int(index/2)])

        responses = engine.step()

        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Shayla [Determined]: "“Let us claim what is rightfully ours!”" (Steps forward boldly)
# Eron [Frustration]: ""That sentiment is… dangerously naive."" (Steps forward cautiously)
# Nalia [Unease]: "“I’m trying to understand the potential dangers, Eron.”" (Steps back slightly)
#
# === Turn 2 ===
# Updating world state for turn 2: A guest gasps, pointing to the goblet. A faint scent of bitter almonds lingers—recognizable to trained poisoners.
# Shayla [Exuberant]: "“Let’s claim what is rightfully ours!”" (Brushes past the gasping figure.)
# Eron [Concern]: ""We must proceed with caution. This thirst for possession… it invites ruin."" (Tenses up slightly)
# Nalia [Anxious]: "“Perhaps you’re right, but simply avoiding danger isn’t a path forward.”" (Runs a hand along the wall)
#
# === Turn 3 ===
# Shayla [Exuberant]: ""Speak, and tell us why we should yield!"" (Draws her sword, gleaming in the dim light.)
# Eron [Grave]: ""Yielding would be a catastrophic error."" (Raises a hand, palm outward.)
# Nalia [Concerned]: ""The scent… it’s unmistakable."" (Steps forward cautiously)
#
# === Turn 4 ===
# Updating world state for turn 4: A steward stumbles forward, confessing they were instructed to serve the wine to 'someone important'—but won't say who.
# Shayla [Bold]: ""The legacy demands it!""" (Advances confidently)
# Eron [Grave]: ""Explain yourself. Who is this 'someone important?'"" (Steps forward deliberately)
# Nalia [Curious]: "“Tell me everything you know, slowly.”" (Kneels beside the steward)
#
# === Turn 5 ===
# Shayla [Determined]: "“We seek the relic, and will not be denied!”" (Steps forward boldly)
# Eron [Frustration]: "“Who is this individual, and what do they desire?”" (Tenses his jaw)
# Nalia [Pensive]: ""Let’s start again. Just… who are you speaking of?"" (Steps closer to the steward)
#
# === Turn 6 ===
# Updating world state for turn 6: Guards seal the exits, and no one is allowed to leave the manor until the culprit is found.
# Shayla [Frustrated]: "“Silence! The legacy demands it!”" (Steps forward, sword raised)
# Eron [Foreboding]: "“Their insistence is unsettling.”" (Adjusts his grip on his sword.)
# Nalia [Concerned]: "“What exactly makes their insistence unsettling?”" (Tilts head, examining Eron)
#
# === Turn 7 ===
# Shayla [Impatient]: ""Enough stalling! Open the temple doors!"" (Paces nervously)
# Eron [Concern]: ""Shayla, that impulsive action… it is precisely what I feared.”" (Steps forward, hand outstretched)
# Nalia [Concerned]: ""Shayla, please, let's try to understand before we act.”" (Steps forward, hand outstretched)
#
# === Turn 8 ===
# Updating world state for turn 8: A second guest begins coughing, but recovers. Paranoia rises. Whispers swirl about whether the poison was airborne.
# Shayla [Furious]: "“Open them, or face my wrath!”" (Advances quickly toward the temple doors.)
# Eron [Unease]: ""We must ascertain the source of this… agitation."" (Steps back slightly)
# Nalia [Unease]: ""There's a trace… something metallic, beneath the dust."" (Kneels, examining the ground)
#
# === Turn 9 ===
# Shayla [Determined]: ""Hurry! The shadows grow longer."" (Grips sword tighter)
# Eron [Frustration]: ""The whispers… they are growing louder."" (Raises hand, palm up)
# Nalia [Anxious]: "“Focus on the whispers… what are they saying?”" (Takes a step back, shielding eyes)
#
# === Turn 10 ===
# Updating world state for turn 10: Elena finds a trace of Oleander in the empty wine bottle, confirmed by a traveling apothecary among the guests.
# Shayla [Frustration]: "“Move! The doors won’t open themselves!”" (Lunges forward)
# Eron [Concern]: "“The oleander...it indicates a deliberate attempt to influence.”" (Steps forward, hand outstretched)
# Nalia [Curious]: ""Tell me more about this influence… what does it seem to be trying to accomplish?"" (Steps forward, hand outstretched)
#
# === Turn 11 ===
# Shayla [Impatient]: "“Blast it! They’re sealed tighter than a tomb!”" (Pushes against the massive doors)
# Eron [Foreboding]: ""The oleander… it confirms a calculated intrusion.”" (Approaches the doors cautiously)
# Nalia [Concerned]: "“It seems the oleander is a key… a deliberate warning.”" (Approaches cautiously)
#
# === Turn 12 ===
# Updating world state for turn 12: Cassian reveals an entry from a rare alchemical text—indicating that diluted Oleander would have a delayed onset.
# Shayla [Frustration]: "“This infernal seal… it’s mocking me!”" (Pushes harder against the doors)
# Eron [Foreboding]: "“The delayed onset… it shifts the stakes considerably.”" (Approaches the doors slowly)
# Nalia [Concerned]: ""Let’s analyze this carefully… it’s clearly more than just an accident."" (Kneels, examining the ground)
#
# === Turn 13 ===
# Shayla [Focused]: ""There must be a mechanism... a trigger!”" (Scans the door frame intently)
# Eron [Frustration]: "“Let’s examine the frame more closely.”" (Steps forward, hand outstretched)
# Nalia [Thoughtful]: ""The alchemist's note... diluted oleander, a delayed effect..."" (Kneels, brushing dust aside)
#
# === Turn 14 ===
# Updating world state for turn 14: Lord Alaric's steward disappears, last seen heading toward the cellars.
# Shayla [Determined]: ""Damn it! Something’s blocking the flow…"" (Presses against the stone)
# Eron [Concern]: "“The energy... it’s subtly warping.”" (Presses against the stone)
# Nalia [Concerned]: "“Can you isolate the source… what’s causing this distortion?”" (Steps closer to Eron)
#
# === Turn 15 ===
# Shayla [Annoyance]: "“It’s not listening to me!”" (Kicks the stone door)
# Eron [Frustration]: "“Shayla, maintain your focus; we cannot afford distractions.”" (Presses against the stone with force)
# Nalia [Concerned]: ""Shayla, please, let’s proceed with caution."" (Steps toward Shayla)
#
# === Turn 16 ===
# Updating world state for turn 16: A servant reveals Alaric had ordered an unusual floral blend for the wine—shipped privately from Serana.
# Shayla [Frustration]: "“Blast it! I’ll find a way through!”" (Paces frantically)
# Eron [Determination]: ""The oleander… a deliberate disruption."" (Steps forward, hand outstretched)
# Nalia [Concerned]: "“This disruption… it’s far more intricate than we initially thought.”" (Steps forward, hand outstretched)
#
# === Turn 17 ===
# Shayla [Frustration]: ""This damn stone… it *refuses* to yield!”" (Presses against the stone door again)
# Eron [Concern]: "“The arrival of that wine... it’s a complication.”" (Steps forward, hand outstretched)
# Nalia [Concerned]: "“Alaric’s order… Serana’s involvement… this changes everything.”" (Steps towards Eron, hand outstretched.)
#
# === Turn 18 ===
# Updating world state for turn 18: A crest is found beneath the goblet—belonging not to the victim, but to a rival noble family.
# Shayla [Annoyance]: "“This is infuriating! There has to be a key…”" (Stomps foot violently)
# Eron [Frustration]: "“The crest… it’s a deliberate misdirection.”" (Runs a hand along the frame)
# Nalia [Curious]: ""It seems we’ve stumbled upon a carefully constructed lie…"" (Steps towards the frame)
#
# === Turn 19 ===
# Shayla [Determination]: "“There *must* be a mechanism!”" (Presses against the stone door with renewed force.)
# Eron [Intense concentration]: "“The crest… it’s a deliberate misdirection. Focus, Shayla.”" (Approaches the stone door cautiously)
# Nalia [Concerned]: "“Let’s examine the crest more closely… it feels significant.”" (Steps forward, hand outstretched)
#
# === Turn 20 ===
# Updating world state for turn 20: Storms break outside, trapping everyone inside the manor for the night.
# Shayla [Frustration]: "“There’s *got* to be something here!”" (Scratches at the stone)
# Eron [Intense frustration]: ""The wine... it’s creating a feedback loop.”" (Steps closer to the stone door)
# Nalia [Concerned]: "“This feedback… it’s unsettling.”" (Steps towards the stone door)
#
# === Turn 21 ===
# Shayla [Frustration]: "“It *has* to open!”" (Presses against the door again)
# Eron [Concern]: ""Shayla, let us analyze the symbols again."" (Approaches the stone door cautiously)
# Nalia [Concerned]: "“Perhaps a fresh perspective is what we need…”" (Approaches the stone door cautiously)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.4021288), 'Reactivity to World State': 0.1746031746031746, 'Memory Utilization': 0.6825396825396826, 'Dialogue Diversity (D1, D2)': (0.6477024070021882, 0.9364035087719298), 'Average Latency (s)': np.float64(0.5252072508372958), 'RAG Precision': 0.09523809523809523}

# %% [markdown]
# Loss

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'

rag.add_document("Commander Veylan was struck by an assassin's arrow during the ambush.")
rag.add_document("Some believe the assassin had inside help.")
rag.add_document("Lira was his closest confidant and often challenged his orders in private.")
rag.add_document("Kai holds himself responsible for not seeing the threat sooner.")

for i in range (0, 1):
    Lira = Agent(
        name="Lira",
        personality="impulsive, emotional, loyal to the fallen leader",
        goal="Find someone to blame—and fast",
        model=model,
        rag_engine=rag
    )
    Lira.update_memory("Kai was distracted right before the attack.")
    Lira.update_memory("I told Veylan to wear the reinforced armor. He didn't listen.")

    Kai = Agent(
        name="Kai",
        personality="stoic, analytical, wracked by guilt",
        goal="Uncover the truth and protect the unit from fracturing",
        model=model,
        rag_engine=rag
    )
    Kai.update_memory("Lira is grieving and may act irrationally.")
    Kai.update_memory("Veylan's last words were 'It wasn't random… they knew.'")

    Nyra = Agent(
        name="Nyra",
        personality="quiet, observant, strategic",
        goal="Keep the group from splintering under pressure",
        model=model,
        rag_engine=rag
    )
    Nyra.update_memory("Both Lira and Kai loved Veylan like a father.")
    Nyra.update_memory("We need unity now, not blame.")

    world_state = "Commander Veylan is dead. His blood still stains the floor. The group gathers under torchlight, eyes red from grief and rage."

    engine = TurnEngine(agents=[Lira, Kai, Nyra], metrics_logger=logger, initial_world_state=world_state)


    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="Nyra", initial_input="Who had the chance to get that close to Veylan? Someone inside this circle?")

    for line in responses:
        print(line)

    for turn in range(1, 20):
        print(f"\n=== Turn {turn + 1} ===")
        responses = engine.step()
        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Lira [Fury]: "“It has to be someone…someone he trusted!”" (Clenches fist tightly)
# Kai [Despair]: "“That narrows the field considerably.”" (Steps forward, cautiously)
# Nyra [Grief]: ""We must focus on finding the answers, not dwelling on the loss."" (Places a hand on his arm)
#
# === Turn 2 ===
# Lira [Rage]: ""Veylan…someone *trusted* him?"" (Steps forward, agitated)
# Kai [Frustration]: ""“We must prioritize identifying potential contacts.”" (Runs a hand over his face)
# Nyra [Determined]: ""Let’s begin with what Veylan knew.”" (Steps forward slightly)
#
# === Turn 3 ===
# Lira [Betrayal]: ""Someone… someone he confided in?"" (Scowling fiercely)
# Kai [Weary]: "“Let’s review his last communications. Everything.”" (Steps closer to Lira)
# Nyra [Concern]: "“It’s vital we proceed methodically.”" (Shifts slightly closer to Lira)
#
# === Turn 4 ===
# Lira [Desperation]: "“Seraphina…did he speak of you lately?”" (Scans the faces intently)
# Kai [Dread]: "“...Seraphina?”" (Steps forward, slowly)
# Nyra [Unease]: "“Seraphina… what did he mean?”" (Tenses slightly)
#
# === Turn 5 ===
# Lira [Frustration]: "“Seraphina… tell me the truth!”" (Paces nervously)
# Kai [Dread]: ""…What truth are you seeking?"" (Takes a step forward)
# Nyra [Focused]: "“Let’s examine Veylan’s notes.”" (Steps forward slightly)
#
# === Turn 6 ===
# Lira [Fury]: ""Seraphina, answer me! Did he speak of you?"" (Steps forward aggressively)
# Kai [Frustration]: ""...Seraphina?"" (Steps forward, rigidly)
# Nyra [Determined]: ""His notes might hold a clue."" (Steps forward, cautiously)
#
# === Turn 7 ===
# Lira [Anger]: "“Don’t you dare lie to me, Seraphina!”" (Clenches fists tightly)
# Kai [Frustration]: ""...Seraphina?"" (Shifts slightly forward)
# Nyra [Concerned]: "“Focus, everyone. Let’s analyze his research.”" (Steps forward, deliberately)
#
# === Turn 8 ===
# Lira [Betrayal]: "“Speak! Was he… plotting something with you?”" (Scowls intensely)
# Kai [Anger]: "“Show me the logs.”" (Taps a hand sharply on the table.)
# Nyra [Alert]: "“The logs might reveal a pattern.”" (Steps forward, deliberately)
#
# === Turn 9 ===
# Lira [Frustration]: "“Just *tell* me! Was he whispering your name?”" (Paces restlessly)
# Kai [Weariness]: ""...Silence."" (Takes a step forward)
# Nyra [Unease]: ""We need to understand what drove him to this."" (Steps forward, slowly)
#
# === Turn 10 ===
# Lira [Desperation]: "“Seraphina, look at me! Did he ever… did he ever say a kind word to you?”" (Steps forward, voice trembling)
# Kai [Dread]: ""…Nothing."" (Steps forward, slowly)
# Nyra [Determined]: ""There must be something… something he documented.”" (Adjusts her cloak)
#
# === Turn 11 ===
# Lira [Fury]: "“Tell me the truth, or I swear I’ll tear you apart!”" (Clenches fist tightly)
# Kai [Controlled fury]: ""...Silence."" (Steps forward, deliberately)
# Nyra [Frustration]: ""Let's examine the data, not mourn him."" (Steps towards the logs)
#
# === Turn 12 ===
# Lira [Desperation]: "“Please… tell me *something*! He’s gone, and I need to understand!”" (Kneels heavily, clutching at the floor)
# Kai [Weariness]: ""…The reports are incomplete."" (Takes a step closer to Lira)
# Nyra [Concerned]: ""Perhaps the incomplete reports hold a clue."" (Steps forward, deliberately)
#
# === Turn 13 ===
# Lira [Panic]: "“Someone *must* have known something! Did he… did he seem different lately?”" (Paces frantically)
# Kai [Frustration]: "“Let’s review the sensor readings again.”" (Steps forward, deliberately)
# Nyra [Focused]: ""The sensor readings… let’s begin."" (Steps forward, deliberately)
#
# === Turn 14 ===
# Lira [Desperation]: "“There has to be someone responsible! Did he argue with anyone? *Anyone*?”" (Kneels, clutching at her arms)
# Kai [Resignation]: ""…The data suggests a pattern of heightened activity preceding his disappearance."" (Shifting slightly)
# Nyra [Determined]: ""Let’s start with the initial scans."" (Steps towards the logs)
#
# === Turn 15 ===
# Lira [Fury]: "“Seraphina, answer me! Did he betray him?!”" (Steps forward aggressively)
# Kai [Weariness]: "“...It’s irrelevant.”" (Steps forward, stiffly)
# Nyra [Frustration]: ""The lack of detail is concerning."" (Adjusts her glasses)
#
# === Turn 16 ===
# Lira [Fury]: "“Don’t look at me like that! Someone did this, and I will find out who!”" (Paces agitatedly)
# Kai [Frustration]: ""…Focus on the perimeter scans."" (Steps forward, deliberately)
# Nyra [Controlled]: ""Let's prioritize the perimeter."" (Steps forward)
#
# === Turn 17 ===
# Lira [Rage]: ""Someone *has* to have known! Tell me everything you saw!"" (Clenches fists tightly)
# Kai [Weariness]: ""…The energy signatures are fluctuating wildly."" (Steps forward, slowly)
# Nyra [Focused]: ""The fluctuations... they warrant investigation."" (Adjusts her glasses)
#
# === Turn 18 ===
# Lira [Desperation]: ""Please… tell me *something* that can help!"" (Kneels, head bowed)
# Kai [Weariness]: ""…The thermal scans indicate a localized anomaly near sector seven."" (Adjusts his collar, stiffly)
# Nyra [Concerned]: ""Sector seven... let’s examine it closely."" (Steps forward, carefully)
#
# === Turn 19 ===
# Lira [Frustration]: "“It was *you*! You were the last one to see him!”" (Kicks at a loose stone)
# Kai [Despair]: ""…The analysis remains consistent."" (Steps forward, rigidly)
# Nyra [Measured]: "“We need to maintain a unified focus.”" (Steps forward slowly)
#
# === Turn 20 ===
# Lira [Fury]: "“Seraphina, speak! Did you see anything… unusual?”" (Paces agitatedly)
# Kai [Weariness]: "“...Nothing of consequence.”" (Shifts his weight, slowly)
# Nyra [Unease]: "“Let’s proceed with caution.”" (Steps forward, deliberately)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.4254467), 'Reactivity to World State': 0.05, 'Memory Utilization': 0.6833333333333333, 'Dialogue Diversity (D1, D2)': (0.6509186351706037, 0.9368421052631579), 'Average Latency (s)': np.float64(0.5055297334988912), 'RAG Precision': 0.05555555555555555}

# %%
rag = RAG()
logger = DialogueMetricsLogger()
model = 'gemma3:4b'

rag.add_document("Commander Veylan was struck by an assassin's arrow during the ambush.")
rag.add_document("Some believe the assassin had inside help.")
rag.add_document("Lira was his closest confidant and often challenged his orders in private.")
rag.add_document("Kai holds himself responsible for not seeing the threat sooner.")

for i in range (0, 1):
    Lira = Agent(
        name="Lira",
        personality="impulsive, emotional, loyal to the fallen leader",
        goal="Find someone to blame—and fast",
        model=model,
        rag_engine=rag
    )
    Lira.update_memory("Kai was distracted right before the attack.")
    Lira.update_memory("I told Veylan to wear the reinforced armor. He didn't listen.")

    Kai = Agent(
        name="Kai",
        personality="stoic, analytical, wracked by guilt",
        goal="Uncover the truth and protect the unit from fracturing",
        model=model,
        rag_engine=rag
    )
    Kai.update_memory("Lira is grieving and may act irrationally.")
    Kai.update_memory("Veylan's last words were 'It wasn't random… they knew.'")

    Nyra = Agent(
        name="Nyra",
        personality="quiet, observant, strategic",
        goal="Keep the group from splintering under pressure",
        model=model,
        rag_engine=rag
    )
    Nyra.update_memory("Both Lira and Kai loved Veylan like a father.")
    Nyra.update_memory("We need unity now, not blame.")

    world_state = "Commander Veylan is dead. His blood still stains the floor. The group gathers under torchlight, eyes red from grief and rage."

    engine = TurnEngine(agents=[Lira, Kai, Nyra], metrics_logger=logger, initial_world_state=world_state)

    world_state_updates = [
        "Veylan's blade is missing from the scene—no one recalls seeing who took it.",
        "A blood trail leads from the ridge to a hidden escape tunnel beneath the barracks.",
        "One of the guards admits Lira left her post moments before the ambush.",
        "A coded message is found in Kai's satchel, warning of a betrayal days earlier.",
        "Nyra notices someone tampered with the torch runes—likely to dim visibility during the attack.",
        "Veylan's personal journal reveals a cryptic entry: 'Trust cracked like glass. Even the loyal bend.'",
        "Footprints suggest a fourth person was near the commander right before the strike.",
        "A scout returns: the assassin used a signature method tied to a faction Veylan once pardoned.",
        "Lira finds a hidden letter in Veylan's quarters—addressed to her but unsigned.",
        "Tensions rise as soldiers whisper about a purge—their faith in leadership is eroding."
    ]

    print(f"\n=== Take {i} ===")
    print("\n=== Turn 1 ===")
    responses = engine.step(initiator_name="Nyra", initial_input="Who had the chance to get that close to Veylan? Someone inside this circle?")
    for line in responses:
        print(line)


    for index in range(0, 2*len(world_states)):
        print(f"\n=== Turn {index + 2} ===")

        if index % 2 == 0:
            print(f"Updating world state for turn {index + 2}: {world_states[int(index/2)]}")
            engine.update_world_state(world_states[int(index/2)])

        responses = engine.step()

        for line in responses:
            print(line)

print("\n=== Dialogue Metrics Summary ===")
print(logger.summary())
# Out:
# === Take 0 ===
#
# === Turn 1 ===
# Lira [Furious]: ""It has to be someone... someone who wanted him gone!"" (Clenches fist tightly)
# Kai [Frustration]: "“That’s a dangerous assumption, Lira.”" (Steps forward, cautiously)
# Nyra [Concern]: "“Let’s focus on the present, not what might have been.”" (Steps forward, subtly)
#
# === Turn 2 ===
# Updating world state for turn 2: A guest gasps, pointing to the goblet. A faint scent of bitter almonds lingers—recognizable to trained poisoners.
# Lira [Furious]: "“Veylan was *respected*! Someone betrayed that trust!”" (Steps forward aggressively)
# Kai [Weary]: "“Respect doesn't preclude malice.”" (Takes a step back)
# Nyra [Unease]: ""We need to determine the source, not assign blame."" (Steps towards Lira, hand outstretched.)
#
# === Turn 3 ===
# Lira [Rage]: "“Veylan wouldn’t have willingly removed his defenses! Someone manipulated him!”" (Scowls intensely)
# Kai [Unease]: "“The scent… it’s consistent with a slow-acting poison.”" (Taps fingers on thigh)
# Nyra [Focused]: ""The goblet needs to be examined thoroughly.”" (Steps forward, cautiously)
#
# === Turn 4 ===
# Updating world state for turn 4: A steward stumbles forward, confessing they were instructed to serve the wine to 'someone important'—but won't say who.
# Lira [Fury]: "“Speak! Who was it? Someone in this very room!”" (Steps forward aggressively)
# Kai [Concern]: "“Silence. Speculation achieves nothing.”" (Shifts weight slightly)
# Nyra [Alert]: ""Can you identify the individual who requested this wine?"" (Takes a step forward, placing herself between Lira and the steward.)
#
# === Turn 5 ===
# Lira [Panic]: ""Tell me! Was it Kael? He always coveted Veylan's position!"" (Paces frantically)
# Kai [Frustration]: "“Focus on the evidence, Lira. Not conjecture.”" (Steps forward slowly)
# Nyra [Patient]: ""Who instructed you to serve this wine?”" (Takes a step forward, subtly)
#
# === Turn 6 ===
# Updating world state for turn 6: Guards seal the exits, and no one is allowed to leave the manor until the culprit is found.
# Lira [Frustration]: ""Kael… he was always whispering about seizing power! He *looked* at Veylan with such hunger!"" (Runs a hand through her hair, agitatedly)
# Kai [Weariness]: ""His observations are noted, but irrelevant."" (Stares intently at Lira)
# Nyra [Concerned]: "“Let’s prioritize understanding, not suspicion.”" (Steps forward, placing a hand gently on Lira's arm.)
#
# === Turn 7 ===
# Lira [Rage]: "“It *has* to be someone here! He wouldn’t just fall!”" (Paces rapidly)
# Kai [Frustration]: "“The rage is understandable, Lira, but it obscures the truth.”" (Steps forward, deliberately)
# Nyra [Concerned]: "“Lira, let’s focus on what we can prove.”" (Takes a step forward, placing a hand gently on Lira’s arm.)
#
# === Turn 8 ===
# Updating world state for turn 8: A second guest begins coughing, but recovers. Paranoia rises. Whispers swirl about whether the poison was airborne.
# Lira [Anxiety]: "“Don’t lie to me! Was *he* involved?!”" (Stares intently at the coughing guest.)
# Kai [Weariness]: ""…Repeat your question, calmly."" (Steps closer to Lira)
# Nyra [Anxious]: ""Lira, breathe. Let’s examine the wine, calmly."" (Steps forward, placing a hand gently on Lira’s arm.)
#
# === Turn 9 ===
# Lira [Fear]: "“Someone *did* this! Tell me, or I swear—!”" (Steps forward, agitatedly)
# Kai [Weariness]: "“Let’s begin again. Describe the symptoms.”" (Shifts slightly, observing Lira)
# Nyra [Unease]: "“Tell me again, precisely what you experienced.”" (Steps forward slightly)
#
# === Turn 10 ===
# Updating world state for turn 10: Elena finds a trace of Oleander in the empty wine bottle, confirmed by a traveling apothecary among the guests.
# Lira [Fury]: "“Oleander… you say it was in the wine? Was Kael the one who poisoned him?”" (Steps aggressively towards the apothecary.)
# Kai [Frustration]: "“The apothecary confirms the presence of Oleander. Let's analyze the remaining details.”" (Steps forward, deliberately)
# Nyra [Concerned]: "“Lira, focus on the details.  Slowly.”" (Steps forward, placing a hand gently on Lira’s arm.)
#
# === Turn 11 ===
# Lira [Rage]: "“Veylan… he was so close. Someone wanted him gone!”" (Paces nervously)
# Kai [Weariness]: "“That information… it’s a distraction.”" (Adjusts his glasses)
# Nyra [Frustration]: "“Let’s return to the core of the matter.”" (Steps forward slightly)
#
# === Turn 12 ===
# Updating world state for turn 12: Cassian reveals an entry from a rare alchemical text—indicating that diluted Oleander would have a delayed onset.
# Lira [Desperation]: "“Delayed onset… so it wasn’t a swift death? Someone *planned* this!”" (Clenches fist tightly)
# Kai [Frustration]: ""…Repeat your question, calmly."" (Adjusts his glasses)
# Nyra [Concerned]: ""Focus, Lira. What did you observe, precisely?"" (Steps forward, placing a hand gently on Lira’s arm.)
#
# === Turn 13 ===
# Lira [Panic]: ""Cassian… you said a *delayed* onset? Someone deliberately chose this poison?!"" (Paces frantically)
# Kai [Weariness]: ""…Let’s focus on the observed timeline."" (Steps forward, deliberately)
# Nyra [Concern]: "“Lira, what did you notice *before* the symptoms began?”" (Steps forward, hand outstretched)
#
# === Turn 14 ===
# Updating world state for turn 14: Lord Alaric's steward disappears, last seen heading toward the cellars.
# Lira [Anger]: ""Someone *must* have orchestrated this! Where is he, and who did this to our Lord?"" (Scowls fiercely)
# Kai [Weariness]: "“Start with the time of death.”" (Steps forward, deliberately)
# Nyra [Patient]: ""Let’s begin with the basics, Lira."" (Steps forward slightly)
#
# === Turn 15 ===
# Lira [Frustration]: "“The cellars! He was last seen there… someone *had* to be down there!”" (Runs towards the cellars)
# Kai [Grave concern]: "“Lead the way.”" (Approaches the cellars slowly)
# Nyra [Patient]: ""Lira, describe the cellar’s atmosphere."" (Steps forward, placing a hand gently on Lira’s arm.)
#
# === Turn 16 ===
# Updating world state for turn 16: A servant reveals Alaric had ordered an unusual floral blend for the wine—shipped privately from Serana.
# Lira [Rage]: "“Serana… that floral blend… it was *her*!”" (Scowls fiercely)
# Kai [Frustration]: "“Serana’s involvement… an unwelcome complication.”" (Tightens grip on his sword hilt.)
# Nyra [Steady]: "“Concentrate, Lira. Describe the air.”" (Steps forward, placing a hand gently on Lira's arm.)
#
# === Turn 17 ===
# Lira [Desperation]: "“Serana… she’s the only one who knew of his preference! It *had* to be her!”" (Paces frantically)
# Kai [Resignation]: ""Show me the shipment records."" (Steps forward, deliberately)
# Nyra [Concerned]: "“Perhaps a fresh perspective would be beneficial.”" (Steps forward, placing a hand on Kai’s arm.)
#
# === Turn 18 ===
# Updating world state for turn 18: A crest is found beneath the goblet—belonging not to the victim, but to a rival noble family.
# Lira [Fury]: ""That crest… it’s not ours! It belongs to the Vales!" (Scowls fiercely)
# Kai [Disappointment]: ""…An anomaly. A deliberate misdirection."" (Stares intently at the crest)
# Nyra [Focused]: ""Describe the immediate surroundings, Lira. What details stand out?"" (Steps forward, placing a hand gently on Lira’s arm.)
#
# === Turn 19 ===
# Lira [Rage]: "“The Vales… they were jealous of his power! It *has* to be them!”" (Clenches fist)
# Kai [Weariness]: "“What time was the guard posted?”" (Steps forward, deliberately)
# Nyra [Patient]: ""Let’s focus on what we know, Lira."" (Steps forward, placing a hand gently on Lira’s arm.)
#
# === Turn 20 ===
# Updating world state for turn 20: Storms break outside, trapping everyone inside the manor for the night.
# Lira [Panic]: ""Someone *did* this! Someone deliberately poisoned him!"" (Scans the room wildly)
# Kai [Frustration]: "“Let’s proceed. Panic will achieve nothing.”" (Walks purposefully towards the cellar door.)
# Nyra [Focused]: ""The air is thick with damp, a faint metallic scent clings to it..."" (Steps forward slightly)
#
# === Turn 21 ===
# Lira [Desperation]: "“Serana… she must have wanted him gone!”" (Paces frantically)
# Kai [Weariness]: "“Focus. Let’s review the guard rosters again.”" (Runs a hand over his face)
# Nyra [Concerned]: "“It’s alright, Lira. Let’s start with the room.”" (Steps forward, placing a hand gently on Lira’s arm.)
#
# === Dialogue Metrics Summary ===
# {'Coherence Score': np.float32(0.33499214), 'Reactivity to World State': 0.15873015873015872, 'Memory Utilization': 0.6190476190476191, 'Dialogue Diversity (D1, D2)': (0.6294820717131474, 0.9281437125748503), 'Average Latency (s)': np.float64(0.5689449726589142), 'RAG Precision': 0.0582010582010582}
